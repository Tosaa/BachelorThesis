# %%
import pandas as pd
import datetime
import pprint
import re
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %run HelpClasses.ipynb

# %%
columns = ["time","priority","class","message","extra"]
# date = "2021-03-26"
# date = "2021-05-17"
date = "2021-05-23"
folder = "test_23_05/"
filename_app = folder + date+".log"
filename_hci = folder + "hci-"+date+".csv"
device_macs = [mac.lower() for mac in ["24:0A:C4:61:78:D2","24:0A:C4:60:EF:3A","24:0A:C4:60:E5:D2"]]

# %%
df = pd.read_csv(filename_hci,encoding='latin1')
df["Time.1"] = pd.to_datetime(df["Time.1"],format="%Y-%m-%d %H:%M:%S,%f")+ pd.Timedelta(hours=1)
df
# Out:
#      No.        Time      Source Destination Protocol  Length  \
# 0      1    0.000000        host  controller  HCI_CMD       4
# 1      2    0.003146  controller        host  HCI_EVT       7
# 2      3    0.003418        host  controller  HCI_CMD       4
# 3      4    0.004442  controller        host  HCI_EVT      14
# 4      5    0.004711        host  controller  HCI_CMD      11
# ..   ...         ...         ...         ...      ...     ...
# 926  927  192.988043  controller        host  HCI_EVT       7
# 927  928  192.988251        host  controller  HCI_CMD       5
# 928  929  192.990420  controller        host  HCI_EVT       7
# 929  930  192.990663        host  controller  HCI_CMD       4
# 930  931  192.991465  controller        host  HCI_EVT       7
#
#      Request in Frame  RF Channel Opcode Value Handle  \
# 0                 NaN         NaN    NaN   NaN    NaN
# 1                 NaN         NaN    NaN   NaN    NaN
# 2                 NaN         NaN    NaN   NaN    NaN
# 3                 NaN         NaN    NaN   NaN    NaN
# 4                 NaN         NaN    NaN   NaN    NaN
# ..                ...         ...    ...   ...    ...
# 926               NaN         NaN    NaN   NaN    NaN
# 927               NaN         NaN    NaN   NaN    NaN
# 928               NaN         NaN    NaN   NaN    NaN
# 929               NaN         NaN    NaN   NaN    NaN
# 930               NaN         NaN    NaN   NaN    NaN
#
#                                             Info                     Time.1  \
# 0                                     Sent Reset 2021-05-23 09:37:04.634631
# 1                  Rcvd Command Complete (Reset) 2021-05-23 09:37:04.637777
# 2                          Sent Read Buffer Size 2021-05-23 09:37:04.638049
# 3       Rcvd Command Complete (Read Buffer Size) 2021-05-23 09:37:04.639073
# 4                          Sent Host Buffer Size 2021-05-23 09:37:04.639342
# ..                                           ...                        ...
# 926    Rcvd Command Complete (Write Scan Enable) 2021-05-23 09:40:17.622674
# 927                       Sent Write Scan Enable 2021-05-23 09:40:17.622882
# 928    Rcvd Command Complete (Write Scan Enable) 2021-05-23 09:40:17.625051
# 929                     Sent LE Clear White List 2021-05-23 09:40:17.625294
# 930  Rcvd Command Complete (LE Clear White List) 2021-05-23 09:40:17.626096
#
#     UUID
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# ..   ...
# 926  NaN
# 927  NaN
# 928  NaN
# 929  NaN
# 930  NaN
#
# [931 rows x 14 columns]

# %%
print('sources:%s'%list(set(df['Source'].values)))
# Out:
# sources:['HuaweiTe_27:59:79 (HUAWEI P20 Pro)', 'host', 'controller', 'Espressi_60:ef:3a (ESP32-T)']

# %%
frames = dict()
for addr in device_macs:
    addr_short = addr[-8:]
    frames[addr] = df[(df['Destination'].str.contains(addr_short))|(df['Source'].str.contains(addr_short))]
    print(addr,':',len(frames[addr]),'entries')
# Out:
# 24:0a:c4:61:78:d2 : 0 entries
# 24:0a:c4:60:ef:3a : 352 entries
# 24:0a:c4:60:e5:d2 : 0 entries

# %%
pd.set_option('display.max_rows', 100)
frames[device_macs[1]].head(100)
# Out:
#      No.        Time                              Source  \
# 417  418   81.936203  HuaweiTe_27:59:79 (HUAWEI P20 Pro)
# 420  421   82.075448         Espressi_60:ef:3a (ESP32-T)
# 421  422   82.076175  HuaweiTe_27:59:79 (HUAWEI P20 Pro)
# 423  424   82.220418         Espressi_60:ef:3a (ESP32-T)
# 424  425   82.221253  HuaweiTe_27:59:79 (HUAWEI P20 Pro)
# 425  426   82.317563         Espressi_60:ef:3a (ESP32-T)
# 426  427   82.318470  HuaweiTe_27:59:79 (HUAWEI P20 Pro)
# 428  429   82.415059         Espressi_60:ef:3a (ESP32-T)
# 429  430   82.415745  HuaweiTe_27:59:79 (HUAWEI P20 Pro)
# 431  432   82.472014         Espressi_60:ef:3a (ESP32-T)
# 432  433   82.473277  HuaweiTe_27:59:79 (HUAWEI P20 Pro)
# 434  435   82.487480         Espressi_60:ef:3a (ESP32-T)
# 435  436   82.488038  HuaweiTe_27:59:79 (HUAWEI P20 Pro)
# 436  437   82.502394         Espressi_60:ef:3a (ESP32-T)
# 437  438   82.503382  HuaweiTe_27:59:79 (HUAWEI P20 Pro)
# 439  440   82.517065         Espressi_60:ef:3a (ESP32-T)
# 440  441   82.518031  HuaweiTe_27:59:79 (HUAWEI P20 Pro)
# 441  442   82.532912         Espressi_60:ef:3a (ESP32-T)
# 442  443   82.533661  HuaweiTe_27:59:79 (HUAWEI P20 Pro)
# 444  445   82.547695         Espressi_60:ef:3a (ESP32-T)
# 445  446   82.548879  HuaweiTe_27:59:79 (HUAWEI P20 Pro)
# 446  447   82.562719         Espressi_60:ef:3a (ESP32-T)
# 447  448   82.563936  HuaweiTe_27:59:79 (HUAWEI P20 Pro)
# 449  450   82.577440         Espressi_60:ef:3a (ESP32-T)
# 450  451   82.578337  HuaweiTe_27:59:79 (HUAWEI P20 Pro)
# 451  452   82.593197         Espressi_60:ef:3a (ESP32-T)
# 452  453   82.593804  HuaweiTe_27:59:79 (HUAWEI P20 Pro)
# 454  455   82.608332         Espressi_60:ef:3a (ESP32-T)
# 455  456   82.608959  HuaweiTe_27:59:79 (HUAWEI P20 Pro)
# 456  457   82.623090         Espressi_60:ef:3a (ESP32-T)
# 457  458   82.623713  HuaweiTe_27:59:79 (HUAWEI P20 Pro)
# 459  460   82.638109         Espressi_60:ef:3a (ESP32-T)
# 460  461   82.639075  HuaweiTe_27:59:79 (HUAWEI P20 Pro)
# 461  462   82.653082         Espressi_60:ef:3a (ESP32-T)
# 462  463   82.654016  HuaweiTe_27:59:79 (HUAWEI P20 Pro)
# 464  465   82.668052         Espressi_60:ef:3a (ESP32-T)
# 465  466   82.668658  HuaweiTe_27:59:79 (HUAWEI P20 Pro)
# 466  467   82.682759         Espressi_60:ef:3a (ESP32-T)
# 467  468   82.684024  HuaweiTe_27:59:79 (HUAWEI P20 Pro)
# 469  470   82.697370         Espressi_60:ef:3a (ESP32-T)
# 470  471   82.698132  HuaweiTe_27:59:79 (HUAWEI P20 Pro)
# 471  472   82.712513         Espressi_60:ef:3a (ESP32-T)
# 472  473   82.712974  HuaweiTe_27:59:79 (HUAWEI P20 Pro)
# 474  475   82.727104         Espressi_60:ef:3a (ESP32-T)
# 478  479   91.542488  HuaweiTe_27:59:79 (HUAWEI P20 Pro)
# 479  480   91.610814         Espressi_60:ef:3a (ESP32-T)
# 481  482   94.134237  HuaweiTe_27:59:79 (HUAWEI P20 Pro)
# 482  483   94.195100         Espressi_60:ef:3a (ESP32-T)
# 484  485   96.937687  HuaweiTe_27:59:79 (HUAWEI P20 Pro)
# 485  486   97.022317         Espressi_60:ef:3a (ESP32-T)
# 486  487   97.071144         Espressi_60:ef:3a (ESP32-T)
# 487  488   97.072287  HuaweiTe_27:59:79 (HUAWEI P20 Pro)
# 493  494   99.107663  HuaweiTe_27:59:79 (HUAWEI P20 Pro)
# 494  495   99.175129         Espressi_60:ef:3a (ESP32-T)
# 496  497  100.066565  HuaweiTe_27:59:79 (HUAWEI P20 Pro)
# 497  498  100.120642         Espressi_60:ef:3a (ESP32-T)
# 499  500  101.345109  HuaweiTe_27:59:79 (HUAWEI P20 Pro)
# 500  501  101.470802         Espressi_60:ef:3a (ESP32-T)
# 502  503  110.381025  HuaweiTe_27:59:79 (HUAWEI P20 Pro)
# 503  504  110.470060         Espressi_60:ef:3a (ESP32-T)
# 505  506  112.828972  HuaweiTe_27:59:79 (HUAWEI P20 Pro)
# 506  507  112.900987         Espressi_60:ef:3a (ESP32-T)
# 507  508  112.901558  HuaweiTe_27:59:79 (HUAWEI P20 Pro)
# 509  510  112.990753         Espressi_60:ef:3a (ESP32-T)
# 510  511  114.538796  HuaweiTe_27:59:79 (HUAWEI P20 Pro)
# 511  512  114.700588         Espressi_60:ef:3a (ESP32-T)
# 512  513  114.701142  HuaweiTe_27:59:79 (HUAWEI P20 Pro)
# 514  515  114.790231         Espressi_60:ef:3a (ESP32-T)
# 515  516  116.822310  HuaweiTe_27:59:79 (HUAWEI P20 Pro)
# 516  517  116.905952         Espressi_60:ef:3a (ESP32-T)
# 517  518  116.906456  HuaweiTe_27:59:79 (HUAWEI P20 Pro)
# 519  520  116.995100         Espressi_60:ef:3a (ESP32-T)
# 524  525  125.507072  HuaweiTe_27:59:79 (HUAWEI P20 Pro)
# 525  526  125.590292         Espressi_60:ef:3a (ESP32-T)
# 527  528  127.914111  HuaweiTe_27:59:79 (HUAWEI P20 Pro)
# 528  529  127.975226         Espressi_60:ef:3a (ESP32-T)
# 529  530  127.976084  HuaweiTe_27:59:79 (HUAWEI P20 Pro)
# 531  532  128.065192         Espressi_60:ef:3a (ESP32-T)
# 532  533  128.065824  HuaweiTe_27:59:79 (HUAWEI P20 Pro)
# 533  534  128.155251         Espressi_60:ef:3a (ESP32-T)
# 535  536  129.287567  HuaweiTe_27:59:79 (HUAWEI P20 Pro)
# 536  537  129.370605         Espressi_60:ef:3a (ESP32-T)
# 537  538  129.371242  HuaweiTe_27:59:79 (HUAWEI P20 Pro)
# 539  540  129.460591         Espressi_60:ef:3a (ESP32-T)
# 540  541  129.461117  HuaweiTe_27:59:79 (HUAWEI P20 Pro)
# 541  542  129.550549         Espressi_60:ef:3a (ESP32-T)
# 543  544  130.406479  HuaweiTe_27:59:79 (HUAWEI P20 Pro)
# 544  545  130.495889         Espressi_60:ef:3a (ESP32-T)
# 545  546  130.496425  HuaweiTe_27:59:79 (HUAWEI P20 Pro)
# 547  548  130.585578         Espressi_60:ef:3a (ESP32-T)
# 548  549  130.586090  HuaweiTe_27:59:79 (HUAWEI P20 Pro)
# 549  550  130.675627         Espressi_60:ef:3a (ESP32-T)
# 551  552  134.379755  HuaweiTe_27:59:79 (HUAWEI P20 Pro)
# 552  553  134.455221         Espressi_60:ef:3a (ESP32-T)
# 554  555  136.250533  HuaweiTe_27:59:79 (HUAWEI P20 Pro)
# 555  556  136.300169         Espressi_60:ef:3a (ESP32-T)
# 556  557  136.300619  HuaweiTe_27:59:79 (HUAWEI P20 Pro)
# 558  559  136.390857         Espressi_60:ef:3a (ESP32-T)
# 559  560  136.391454  HuaweiTe_27:59:79 (HUAWEI P20 Pro)
# 560  561  136.480203         Espressi_60:ef:3a (ESP32-T)
#
#                             Destination Protocol  Length  Request in Frame  \
# 417         Espressi_60:ef:3a (ESP32-T)      ATT      16               NaN
# 420  HuaweiTe_27:59:79 (HUAWEI P20 Pro)      ATT      23             418.0
# 421         Espressi_60:ef:3a (ESP32-T)      ATT      16               NaN
# 423  HuaweiTe_27:59:79 (HUAWEI P20 Pro)      ATT      31             422.0
# 424         Espressi_60:ef:3a (ESP32-T)      ATT      16               NaN
# 425  HuaweiTe_27:59:79 (HUAWEI P20 Pro)      ATT      14               NaN
# 426         Espressi_60:ef:3a (ESP32-T)      ATT      16               NaN
# 428  HuaweiTe_27:59:79 (HUAWEI P20 Pro)      ATT      18             427.0
# 429         Espressi_60:ef:3a (ESP32-T)      ATT      16               NaN
# 431  HuaweiTe_27:59:79 (HUAWEI P20 Pro)      ATT      14               NaN
# 432         Espressi_60:ef:3a (ESP32-T)      ATT      14               NaN
# 434  HuaweiTe_27:59:79 (HUAWEI P20 Pro)      ATT      15             433.0
# 435         Espressi_60:ef:3a (ESP32-T)      ATT      14               NaN
# 436  HuaweiTe_27:59:79 (HUAWEI P20 Pro)      ATT      14               NaN
# 437         Espressi_60:ef:3a (ESP32-T)      ATT      16               NaN
# 439  HuaweiTe_27:59:79 (HUAWEI P20 Pro)      ATT      14               NaN
# 440         Espressi_60:ef:3a (ESP32-T)      ATT      16               NaN
# 441  HuaweiTe_27:59:79 (HUAWEI P20 Pro)      ATT      32             441.0
# 442         Espressi_60:ef:3a (ESP32-T)      ATT      16               NaN
# 444  HuaweiTe_27:59:79 (HUAWEI P20 Pro)      ATT      14               NaN
# 445         Espressi_60:ef:3a (ESP32-T)      ATT      14               NaN
# 446  HuaweiTe_27:59:79 (HUAWEI P20 Pro)      ATT      14               NaN
# 447         Espressi_60:ef:3a (ESP32-T)      ATT      16               NaN
# 449  HuaweiTe_27:59:79 (HUAWEI P20 Pro)      ATT      14               NaN
# 450         Espressi_60:ef:3a (ESP32-T)      ATT      16               NaN
# 451  HuaweiTe_27:59:79 (HUAWEI P20 Pro)      ATT      32             451.0
# 452         Espressi_60:ef:3a (ESP32-T)      ATT      16               NaN
# 454  HuaweiTe_27:59:79 (HUAWEI P20 Pro)      ATT      32             453.0
# 455         Espressi_60:ef:3a (ESP32-T)      ATT      16               NaN
# 456  HuaweiTe_27:59:79 (HUAWEI P20 Pro)      ATT      32             456.0
# 457         Espressi_60:ef:3a (ESP32-T)      ATT      16               NaN
# 459  HuaweiTe_27:59:79 (HUAWEI P20 Pro)      ATT      32             458.0
# 460         Espressi_60:ef:3a (ESP32-T)      ATT      16               NaN
# 461  HuaweiTe_27:59:79 (HUAWEI P20 Pro)      ATT      32             461.0
# 462         Espressi_60:ef:3a (ESP32-T)      ATT      16               NaN
# 464  HuaweiTe_27:59:79 (HUAWEI P20 Pro)      ATT      32             463.0
# 465         Espressi_60:ef:3a (ESP32-T)      ATT      16               NaN
# 466  HuaweiTe_27:59:79 (HUAWEI P20 Pro)      ATT      14               NaN
# 467         Espressi_60:ef:3a (ESP32-T)      ATT      14               NaN
# 469  HuaweiTe_27:59:79 (HUAWEI P20 Pro)      ATT      15             468.0
# 470         Espressi_60:ef:3a (ESP32-T)      ATT      14               NaN
# 471  HuaweiTe_27:59:79 (HUAWEI P20 Pro)      ATT      15             471.0
# 472         Espressi_60:ef:3a (ESP32-T)      ATT      14               NaN
# 474  HuaweiTe_27:59:79 (HUAWEI P20 Pro)      ATT      14               NaN
# 478         Espressi_60:ef:3a (ESP32-T)      ATT      16               NaN
# 479  HuaweiTe_27:59:79 (HUAWEI P20 Pro)      ATT      10             479.0
# 481         Espressi_60:ef:3a (ESP32-T)      ATT      12               NaN
# 482  HuaweiTe_27:59:79 (HUAWEI P20 Pro)      ATT      12             482.0
# 484         Espressi_60:ef:3a (ESP32-T)      ATT      16               NaN
# 485  HuaweiTe_27:59:79 (HUAWEI P20 Pro)      ATT      10             485.0
# 486  HuaweiTe_27:59:79 (HUAWEI P20 Pro)    L2CAP      21               NaN
# 487         Espressi_60:ef:3a (ESP32-T)    L2CAP      15               NaN
# 493         Espressi_60:ef:3a (ESP32-T)      ATT      12               NaN
# 494  HuaweiTe_27:59:79 (HUAWEI P20 Pro)      ATT      30             494.0
# 496         Espressi_60:ef:3a (ESP32-T)      ATT      12               NaN
# 497  HuaweiTe_27:59:79 (HUAWEI P20 Pro)      ATT      30             497.0
# 499         Espressi_60:ef:3a (ESP32-T)      ATT      12               NaN
# 500  HuaweiTe_27:59:79 (HUAWEI P20 Pro)      ATT      30             500.0
# 502         Espressi_60:ef:3a (ESP32-T)      ATT      16               NaN
# 503  HuaweiTe_27:59:79 (HUAWEI P20 Pro)      ATT      10             503.0
# 505         Espressi_60:ef:3a (ESP32-T)      ATT      12               NaN
# 506  HuaweiTe_27:59:79 (HUAWEI P20 Pro)      ATT      32             506.0
# 507         Espressi_60:ef:3a (ESP32-T)      ATT      14               NaN
# 509  HuaweiTe_27:59:79 (HUAWEI P20 Pro)      ATT      20             508.0
# 510         Espressi_60:ef:3a (ESP32-T)      ATT      12               NaN
# 511  HuaweiTe_27:59:79 (HUAWEI P20 Pro)      ATT      32             511.0
# 512         Espressi_60:ef:3a (ESP32-T)      ATT      14               NaN
# 514  HuaweiTe_27:59:79 (HUAWEI P20 Pro)      ATT      20             513.0
# 515         Espressi_60:ef:3a (ESP32-T)      ATT      12               NaN
# 516  HuaweiTe_27:59:79 (HUAWEI P20 Pro)      ATT      32             516.0
# 517         Espressi_60:ef:3a (ESP32-T)      ATT      14               NaN
# 519  HuaweiTe_27:59:79 (HUAWEI P20 Pro)      ATT      20             518.0
# 524         Espressi_60:ef:3a (ESP32-T)      ATT      16               NaN
# 525  HuaweiTe_27:59:79 (HUAWEI P20 Pro)      ATT      10             525.0
# 527         Espressi_60:ef:3a (ESP32-T)      ATT      12               NaN
# 528  HuaweiTe_27:59:79 (HUAWEI P20 Pro)      ATT      32             528.0
# 529         Espressi_60:ef:3a (ESP32-T)      ATT      14               NaN
# 531  HuaweiTe_27:59:79 (HUAWEI P20 Pro)      ATT      32             530.0
# 532         Espressi_60:ef:3a (ESP32-T)      ATT      14               NaN
# 533  HuaweiTe_27:59:79 (HUAWEI P20 Pro)      ATT      30             533.0
# 535         Espressi_60:ef:3a (ESP32-T)      ATT      12               NaN
# 536  HuaweiTe_27:59:79 (HUAWEI P20 Pro)      ATT      32             536.0
# 537         Espressi_60:ef:3a (ESP32-T)      ATT      14               NaN
# 539  HuaweiTe_27:59:79 (HUAWEI P20 Pro)      ATT      32             538.0
# 540         Espressi_60:ef:3a (ESP32-T)      ATT      14               NaN
# 541  HuaweiTe_27:59:79 (HUAWEI P20 Pro)      ATT      30             541.0
# 543         Espressi_60:ef:3a (ESP32-T)      ATT      12               NaN
# 544  HuaweiTe_27:59:79 (HUAWEI P20 Pro)      ATT      32             544.0
# 545         Espressi_60:ef:3a (ESP32-T)      ATT      14               NaN
# 547  HuaweiTe_27:59:79 (HUAWEI P20 Pro)      ATT      32             546.0
# 548         Espressi_60:ef:3a (ESP32-T)      ATT      14               NaN
# 549  HuaweiTe_27:59:79 (HUAWEI P20 Pro)      ATT      30             549.0
# 551         Espressi_60:ef:3a (ESP32-T)      ATT      16               NaN
# 552  HuaweiTe_27:59:79 (HUAWEI P20 Pro)      ATT      10             552.0
# 554         Espressi_60:ef:3a (ESP32-T)      ATT      12               NaN
# 555  HuaweiTe_27:59:79 (HUAWEI P20 Pro)      ATT      32             555.0
# 556         Espressi_60:ef:3a (ESP32-T)      ATT      14               NaN
# 558  HuaweiTe_27:59:79 (HUAWEI P20 Pro)      ATT      32             557.0
# 559         Espressi_60:ef:3a (ESP32-T)      ATT      14               NaN
# 560  HuaweiTe_27:59:79 (HUAWEI P20 Pro)      ATT      32             560.0
#
#      RF Channel                       Opcode  \
# 417         NaN   Read By Group Type Request
# 420         NaN  Read By Group Type Response
# 421         NaN   Read By Group Type Request
# 423         NaN  Read By Group Type Response
# 424         NaN         Read By Type Request
# 425         NaN               Error Response
# 426         NaN         Read By Type Request
# 428         NaN        Read By Type Response
# 429         NaN         Read By Type Request
# 431         NaN               Error Response
# 432         NaN     Find Information Request
# 434         NaN    Find Information Response
# 435         NaN     Find Information Request
# 436         NaN               Error Response
# 437         NaN         Read By Type Request
# 439         NaN               Error Response
# 440         NaN         Read By Type Request
# 441         NaN        Read By Type Response
# 442         NaN         Read By Type Request
# 444         NaN               Error Response
# 445         NaN     Find Information Request
# 446         NaN               Error Response
# 447         NaN         Read By Type Request
# 449         NaN               Error Response
# 450         NaN         Read By Type Request
# 451         NaN        Read By Type Response
# 452         NaN         Read By Type Request
# 454         NaN        Read By Type Response
# 455         NaN         Read By Type Request
# 456         NaN        Read By Type Response
# 457         NaN         Read By Type Request
# 459         NaN        Read By Type Response
# 460         NaN         Read By Type Request
# 461         NaN        Read By Type Response
# 462         NaN         Read By Type Request
# 464         NaN        Read By Type Response
# 465         NaN         Read By Type Request
# 466         NaN               Error Response
# 467         NaN     Find Information Request
# 469         NaN    Find Information Response
# 470         NaN     Find Information Request
# 471         NaN    Find Information Response
# 472         NaN     Find Information Request
# 474         NaN               Error Response
# 478         NaN                Write Request
# 479         NaN               Write Response
# 481         NaN         Exchange MTU Request
# 482         NaN        Exchange MTU Response
# 484         NaN                Write Request
# 485         NaN               Write Response
# 486         NaN                          NaN
# 487         NaN                          NaN
# 493         NaN                 Read Request
# 494         NaN                Read Response
# 496         NaN                 Read Request
# 497         NaN                Read Response
# 499         NaN                 Read Request
# 500         NaN                Read Response
# 502         NaN                Write Request
# 503         NaN               Write Response
# 505         NaN                 Read Request
# 506         NaN                Read Response
# 507         NaN            Read Blob Request
# 509         NaN           Read Blob Response
# 510         NaN                 Read Request
# 511         NaN                Read Response
# 512         NaN            Read Blob Request
# 514         NaN           Read Blob Response
# 515         NaN                 Read Request
# 516         NaN                Read Response
# 517         NaN            Read Blob Request
# 519         NaN           Read Blob Response
# 524         NaN                Write Request
# 525         NaN               Write Response
# 527         NaN                 Read Request
# 528         NaN                Read Response
# 529         NaN            Read Blob Request
# 531         NaN           Read Blob Response
# 532         NaN            Read Blob Request
# 533         NaN           Read Blob Response
# 535         NaN                 Read Request
# 536         NaN                Read Response
# 537         NaN            Read Blob Request
# 539         NaN           Read Blob Response
# 540         NaN            Read Blob Request
# 541         NaN           Read Blob Response
# 543         NaN                 Read Request
# 544         NaN                Read Response
# 545         NaN            Read Blob Request
# 547         NaN           Read Blob Response
# 548         NaN            Read Blob Request
# 549         NaN           Read Blob Response
# 551         NaN                Write Request
# 552         NaN               Write Response
# 554         NaN                 Read Request
# 555         NaN                Read Response
# 556         NaN            Read Blob Request
# 558         NaN           Read Blob Response
# 559         NaN            Read Blob Request
# 560         NaN           Read Blob Response
#
#                                             Value  \
# 417                                           NaN
# 420                                           NaN
# 421                                           NaN
# 423                                           NaN
# 424                                           NaN
# 425                                           NaN
# 426                                           NaN
# 428                                           NaN
# 429                                           NaN
# 431                                           NaN
# 432                                           NaN
# 434                                           NaN
# 435                                           NaN
# 436                                           NaN
# 437                                           NaN
# 439                                           NaN
# 440                                           NaN
# 441                                           NaN
# 442                                           NaN
# 444                                           NaN
# 445                                           NaN
# 446                                           NaN
# 447                                           NaN
# 449                                           NaN
# 450                                           NaN
# 451                                           NaN
# 452                                           NaN
# 454                                           NaN
# 455                                           NaN
# 456                                           NaN
# 457                                           NaN
# 459                                           NaN
# 460                                           NaN
# 461                                           NaN
# 462                                           NaN
# 464                                           NaN
# 465                                           NaN
# 466                                           NaN
# 467                                           NaN
# 469                                           NaN
# 470                                           NaN
# 471                                           NaN
# 472                                           NaN
# 474                                           NaN
# 478                                      14000000
# 479                                           NaN
# 481                                           NaN
# 482                                           NaN
# 484                                      24000000
# 485                                           NaN
# 486                                           NaN
# 487                                           NaN
# 493                                           NaN
# 494      446174612053697a652032306d6e6f7071727374
# 496                                           NaN
# 497      446174612053697a652032306d6e6f7071727374
# 499                                           NaN
# 500      446174612053697a652032306d6e6f7071727374
# 502                                      20000000
# 503                                           NaN
# 505                                           NaN
# 506  446174612053697a652033326d6e6f70717273747576
# 507                                           NaN
# 509                          7778797a616263646566
# 510                                           NaN
# 511  446174612053697a652033326d6e6f70717273747576
# 512                                           NaN
# 514                          7778797a616263646566
# 515                                           NaN
# 516  446174612053697a652033326d6e6f70717273747576
# 517                                           NaN
# 519                          7778797a616263646566
# 524                                      40000000
# 525                                           NaN
# 527                                           NaN
# 528  446174612053697a652036346d6e6f70717273747576
# 529                                           NaN
# 531  7778797a6162636465666768696a6b6c6d6e6f707172
# 532                                           NaN
# 533      737475767778797a6162636465666768696a6b6c
# 535                                           NaN
# 536  446174612053697a652036346d6e6f70717273747576
# 537                                           NaN
# 539  7778797a6162636465666768696a6b6c6d6e6f707172
# 540                                           NaN
# 541      737475767778797a6162636465666768696a6b6c
# 543                                           NaN
# 544  446174612053697a652036346d6e6f70717273747576
# 545                                           NaN
# 547  7778797a6162636465666768696a6b6c6d6e6f707172
# 548                                           NaN
# 549      737475767778797a6162636465666768696a6b6c
# 551                                      80000000
# 552                                           NaN
# 554                                           NaN
# 555  446174612053697a65203132386e6f70717273747576
# 556                                           NaN
# 558  7778797a6162636465666768696a6b6c6d6e6f707172
# 559                                           NaN
# 560  737475767778797a6162636465666768696a6b6c6d6e
#
#                                         Handle  \
# 417                                        NaN
# 420                              0x0001,0x0014
# 421                                        NaN
# 423                                     0x0028
# 424                                        NaN
# 425                                     0x0001
# 426                                        NaN
# 428                              0x0003,0x0002
# 429                                        NaN
# 431                                     0x0003
# 432                                        NaN
# 434                                     0x0004
# 435                                        NaN
# 436                                     0x0005
# 437                                        NaN
# 439                                     0x0014
# 440                                        NaN
# 441  0x0016,0x0018,0x001a,0x0015,0x0017,0x0019
# 442                                        NaN
# 444                                     0x001a
# 445                                        NaN
# 446                                     0x001b
# 447                                        NaN
# 449                                     0x0028
# 450                                        NaN
# 451                              0x002a,0x0029
# 452                                        NaN
# 454                              0x002c,0x002b
# 455                                        NaN
# 456                              0x002e,0x002d
# 457                                        NaN
# 459                              0x0030,0x002f
# 460                                        NaN
# 461                              0x0033,0x0032
# 462                                        NaN
# 464                              0x0035,0x0034
# 465                                        NaN
# 466                                     0x0035
# 467                                        NaN
# 469                                     0x0031
# 470                                        NaN
# 471                                     0x0036
# 472                                        NaN
# 474                                     0x0037
# 478                                     0x002e
# 479                                     0x002e
# 481                                        NaN
# 482                                        NaN
# 484                                     0x0033
# 485                                     0x0033
# 486                                        NaN
# 487                                        NaN
# 493                                     0x002a
# 494                                     0x002a
# 496                                     0x002a
# 497                                     0x002a
# 499                                     0x002a
# 500                                     0x002a
# 502                                     0x002e
# 503                                     0x002e
# 505                                     0x002a
# 506                                     0x002a
# 507                                     0x002a
# 509                                     0x002a
# 510                                     0x002a
# 511                                     0x002a
# 512                                     0x002a
# 514                                     0x002a
# 515                                     0x002a
# 516                                     0x002a
# 517                                     0x002a
# 519                                     0x002a
# 524                                     0x002e
# 525                                     0x002e
# 527                                     0x002a
# 528                                     0x002a
# 529                                     0x002a
# 531                                     0x002a
# 532                                     0x002a
# 533                                     0x002a
# 535                                     0x002a
# 536                                     0x002a
# 537                                     0x002a
# 539                                     0x002a
# 540                                     0x002a
# 541                                     0x002a
# 543                                     0x002a
# 544                                     0x002a
# 545                                     0x002a
# 547                                     0x002a
# 548                                     0x002a
# 549                                     0x002a
# 551                                     0x002e
# 552                                     0x002e
# 554                                     0x002a
# 555                                     0x002a
# 556                                     0x002a
# 558                                     0x002a
# 559                                     0x002a
# 560                                     0x002a
#
#                                                   Info  \
# 417  Sent Read By Group Type Request, GATT Primary ...
# 420  Rcvd Read By Group Type Response, Attribute Li...
# 421  Sent Read By Group Type Request, GATT Primary ...
# 423  Rcvd Read By Group Type Response, Attribute Li...
# 424  Sent Read By Type Request, GATT Include Declar...
# 425  Rcvd Error Response - Attribute Not Found, Han...
# 426  Sent Read By Type Request, GATT Characteristic...
# 428  Rcvd Read By Type Response, Attribute List Len...
# 429  Sent Read By Type Request, GATT Characteristic...
# 431  Rcvd Error Response - Attribute Not Found, Han...
# 432  Sent Find Information Request, Handles: 0x0004...
# 434  Rcvd Find Information Response, Handle: 0x0004...
# 435  Sent Find Information Request, Handles: 0x0005...
# 436  Rcvd Error Response - Attribute Not Found, Han...
# 437  Sent Read By Type Request, GATT Include Declar...
# 439  Rcvd Error Response - Attribute Not Found, Han...
# 440  Sent Read By Type Request, GATT Characteristic...
# 441  Rcvd Read By Type Response, Attribute List Len...
# 442  Sent Read By Type Request, GATT Characteristic...
# 444  Rcvd Error Response - Attribute Not Found, Han...
# 445  Sent Find Information Request, Handles: 0x001b...
# 446  Rcvd Error Response - Attribute Not Found, Han...
# 447  Sent Read By Type Request, GATT Include Declar...
# 449  Rcvd Error Response - Attribute Not Found, Han...
# 450  Sent Read By Type Request, GATT Characteristic...
# 451  Rcvd Read By Type Response, Attribute List Len...
# 452  Sent Read By Type Request, GATT Characteristic...
# 454  Rcvd Read By Type Response, Attribute List Len...
# 455  Sent Read By Type Request, GATT Characteristic...
# 456  Rcvd Read By Type Response, Attribute List Len...
# 457  Sent Read By Type Request, GATT Characteristic...
# 459  Rcvd Read By Type Response, Attribute List Len...
# 460  Sent Read By Type Request, GATT Characteristic...
# 461  Rcvd Read By Type Response, Attribute List Len...
# 462  Sent Read By Type Request, GATT Characteristic...
# 464  Rcvd Read By Type Response, Attribute List Len...
# 465  Sent Read By Type Request, GATT Characteristic...
# 466  Rcvd Error Response - Attribute Not Found, Han...
# 467  Sent Find Information Request, Handles: 0x0031...
# 469  Rcvd Find Information Response, Handle: 0x0031...
# 470  Sent Find Information Request, Handles: 0x0036...
# 471  Rcvd Find Information Response, Handle: 0x0036...
# 472  Sent Find Information Request, Handles: 0x0037...
# 474  Rcvd Error Response - Attribute Not Found, Han...
# 478  Sent Write Request, Handle: 0x002e (Unknown: U...
# 479  Rcvd Write Response, Handle: 0x002e (Unknown: ...
# 481       Sent Exchange MTU Request, Client Rx MTU: 23
# 482      Rcvd Exchange MTU Response, Server Rx MTU: 23
# 484  Sent Write Request, Handle: 0x0033 (Unknown: U...
# 485  Rcvd Write Response, Handle: 0x0033 (Unknown: ...
# 486           Rcvd Connection Parameter Update Request
# 487  Sent Connection Parameter Update Response (Acc...
# 493  Sent Read Request, Handle: 0x002a (Unknown: Un...
# 494  Rcvd Read Response, Handle: 0x002a (Unknown: U...
# 496  Sent Read Request, Handle: 0x002a (Unknown: Un...
# 497  Rcvd Read Response, Handle: 0x002a (Unknown: U...
# 499  Sent Read Request, Handle: 0x002a (Unknown: Un...
# 500  Rcvd Read Response, Handle: 0x002a (Unknown: U...
# 502  Sent Write Request, Handle: 0x002e (Unknown: U...
# 503  Rcvd Write Response, Handle: 0x002e (Unknown: ...
# 505  Sent Read Request, Handle: 0x002a (Unknown: Un...
# 506  Rcvd Read Response, Handle: 0x002a (Unknown: U...
# 507  Sent Read Blob Request, Handle: 0x002a (Unknow...
# 509  Rcvd Read Blob Response, Handle: 0x002a (Unkno...
# 510  Sent Read Request, Handle: 0x002a (Unknown: Un...
# 511  Rcvd Read Response, Handle: 0x002a (Unknown: U...
# 512  Sent Read Blob Request, Handle: 0x002a (Unknow...
# 514  Rcvd Read Blob Response, Handle: 0x002a (Unkno...
# 515  Sent Read Request, Handle: 0x002a (Unknown: Un...
# 516  Rcvd Read Response, Handle: 0x002a (Unknown: U...
# 517  Sent Read Blob Request, Handle: 0x002a (Unknow...
# 519  Rcvd Read Blob Response, Handle: 0x002a (Unkno...
# 524  Sent Write Request, Handle: 0x002e (Unknown: U...
# 525  Rcvd Write Response, Handle: 0x002e (Unknown: ...
# 527  Sent Read Request, Handle: 0x002a (Unknown: Un...
# 528  Rcvd Read Response, Handle: 0x002a (Unknown: U...
# 529  Sent Read Blob Request, Handle: 0x002a (Unknow...
# 531  Rcvd Read Blob Response, Handle: 0x002a (Unkno...
# 532  Sent Read Blob Request, Handle: 0x002a (Unknow...
# 533  Rcvd Read Blob Response, Handle: 0x002a (Unkno...
# 535  Sent Read Request, Handle: 0x002a (Unknown: Un...
# 536  Rcvd Read Response, Handle: 0x002a (Unknown: U...
# 537  Sent Read Blob Request, Handle: 0x002a (Unknow...
# 539  Rcvd Read Blob Response, Handle: 0x002a (Unkno...
# 540  Sent Read Blob Request, Handle: 0x002a (Unknow...
# 541  Rcvd Read Blob Response, Handle: 0x002a (Unkno...
# 543  Sent Read Request, Handle: 0x002a (Unknown: Un...
# 544  Rcvd Read Response, Handle: 0x002a (Unknown: U...
# 545  Sent Read Blob Request, Handle: 0x002a (Unknow...
# 547  Rcvd Read Blob Response, Handle: 0x002a (Unkno...
# 548  Sent Read Blob Request, Handle: 0x002a (Unknow...
# 549  Rcvd Read Blob Response, Handle: 0x002a (Unkno...
# 551  Sent Write Request, Handle: 0x002e (Unknown: U...
# 552  Rcvd Write Response, Handle: 0x002e (Unknown: ...
# 554  Sent Read Request, Handle: 0x002a (Unknown: Un...
# 555  Rcvd Read Response, Handle: 0x002a (Unknown: U...
# 556  Sent Read Blob Request, Handle: 0x002a (Unknow...
# 558  Rcvd Read Blob Response, Handle: 0x002a (Unkno...
# 559  Sent Read Blob Request, Handle: 0x002a (Unknow...
# 560  Rcvd Read Blob Response, Handle: 0x002a (Unkno...
#
#                         Time.1  \
# 417 2021-05-23 09:38:26.570834
# 420 2021-05-23 09:38:26.710079
# 421 2021-05-23 09:38:26.710806
# 423 2021-05-23 09:38:26.855049
# 424 2021-05-23 09:38:26.855884
# 425 2021-05-23 09:38:26.952194
# 426 2021-05-23 09:38:26.953101
# 428 2021-05-23 09:38:27.049690
# 429 2021-05-23 09:38:27.050376
# 431 2021-05-23 09:38:27.106645
# 432 2021-05-23 09:38:27.107908
# 434 2021-05-23 09:38:27.122111
# 435 2021-05-23 09:38:27.122669
# 436 2021-05-23 09:38:27.137025
# 437 2021-05-23 09:38:27.138013
# 439 2021-05-23 09:38:27.151696
# 440 2021-05-23 09:38:27.152662
# 441 2021-05-23 09:38:27.167543
# 442 2021-05-23 09:38:27.168292
# 444 2021-05-23 09:38:27.182326
# 445 2021-05-23 09:38:27.183510
# 446 2021-05-23 09:38:27.197350
# 447 2021-05-23 09:38:27.198567
# 449 2021-05-23 09:38:27.212071
# 450 2021-05-23 09:38:27.212968
# 451 2021-05-23 09:38:27.227828
# 452 2021-05-23 09:38:27.228435
# 454 2021-05-23 09:38:27.242963
# 455 2021-05-23 09:38:27.243590
# 456 2021-05-23 09:38:27.257721
# 457 2021-05-23 09:38:27.258344
# 459 2021-05-23 09:38:27.272740
# 460 2021-05-23 09:38:27.273706
# 461 2021-05-23 09:38:27.287713
# 462 2021-05-23 09:38:27.288647
# 464 2021-05-23 09:38:27.302683
# 465 2021-05-23 09:38:27.303289
# 466 2021-05-23 09:38:27.317390
# 467 2021-05-23 09:38:27.318655
# 469 2021-05-23 09:38:27.332001
# 470 2021-05-23 09:38:27.332763
# 471 2021-05-23 09:38:27.347144
# 472 2021-05-23 09:38:27.347605
# 474 2021-05-23 09:38:27.361735
# 478 2021-05-23 09:38:36.177119
# 479 2021-05-23 09:38:36.245445
# 481 2021-05-23 09:38:38.768868
# 482 2021-05-23 09:38:38.829731
# 484 2021-05-23 09:38:41.572318
# 485 2021-05-23 09:38:41.656948
# 486 2021-05-23 09:38:41.705775
# 487 2021-05-23 09:38:41.706918
# 493 2021-05-23 09:38:43.742294
# 494 2021-05-23 09:38:43.809760
# 496 2021-05-23 09:38:44.701196
# 497 2021-05-23 09:38:44.755273
# 499 2021-05-23 09:38:45.979740
# 500 2021-05-23 09:38:46.105433
# 502 2021-05-23 09:38:55.015656
# 503 2021-05-23 09:38:55.104691
# 505 2021-05-23 09:38:57.463603
# 506 2021-05-23 09:38:57.535618
# 507 2021-05-23 09:38:57.536189
# 509 2021-05-23 09:38:57.625384
# 510 2021-05-23 09:38:59.173427
# 511 2021-05-23 09:38:59.335219
# 512 2021-05-23 09:38:59.335773
# 514 2021-05-23 09:38:59.424862
# 515 2021-05-23 09:39:01.456941
# 516 2021-05-23 09:39:01.540583
# 517 2021-05-23 09:39:01.541087
# 519 2021-05-23 09:39:01.629731
# 524 2021-05-23 09:39:10.141703
# 525 2021-05-23 09:39:10.224923
# 527 2021-05-23 09:39:12.548742
# 528 2021-05-23 09:39:12.609857
# 529 2021-05-23 09:39:12.610715
# 531 2021-05-23 09:39:12.699823
# 532 2021-05-23 09:39:12.700455
# 533 2021-05-23 09:39:12.789882
# 535 2021-05-23 09:39:13.922198
# 536 2021-05-23 09:39:14.005236
# 537 2021-05-23 09:39:14.005873
# 539 2021-05-23 09:39:14.095222
# 540 2021-05-23 09:39:14.095748
# 541 2021-05-23 09:39:14.185180
# 543 2021-05-23 09:39:15.041110
# 544 2021-05-23 09:39:15.130520
# 545 2021-05-23 09:39:15.131056
# 547 2021-05-23 09:39:15.220209
# 548 2021-05-23 09:39:15.220721
# 549 2021-05-23 09:39:15.310258
# 551 2021-05-23 09:39:19.014386
# 552 2021-05-23 09:39:19.089852
# 554 2021-05-23 09:39:20.885164
# 555 2021-05-23 09:39:20.934800
# 556 2021-05-23 09:39:20.935250
# 558 2021-05-23 09:39:21.025488
# 559 2021-05-23 09:39:21.026085
# 560 2021-05-23 09:39:21.114834
#
#                                                   UUID
# 417                                                NaN
# 420                                                NaN
# 421                                                NaN
# 423  26cb2f28a4ba49fc856ad57fe4d3dada,dadad3e47fd56...
# 424                                                NaN
# 425                                                NaN
# 426                                                NaN
# 428                                                NaN
# 429                                                NaN
# 431                                                NaN
# 432                                                NaN
# 434                                                NaN
# 435                                                NaN
# 436                                                NaN
# 437                                                NaN
# 439                                                NaN
# 440                                                NaN
# 441                                                NaN
# 442                                                NaN
# 444                                                NaN
# 445                                                NaN
# 446                                                NaN
# 447                                                NaN
# 449                   26cb2f28a4ba49fc856ad57fe4d3dada
# 450                                                NaN
# 451  fbdc45f28337467b8019e7db05355215,15523505dbe71...
# 452                                                NaN
# 454  8c65f73dddab4dd9a2e0f5a10ce7e252,52e2e70ca1f5e...
# 455                                                NaN
# 456  f341082200c04dd3a60b3cd6124fd323,23d34f12d63c0...
# 457                                                NaN
# 459  1ee1d0fc6f3c4c6aac1cc54d2a97f932,32f9972a4dc51...
# 460                                                NaN
# 461  46ac40cc7eaa41a99964956a984fd9c3,c3d94f986a956...
# 462                                                NaN
# 464  83157f667c91431ea0377c2b9e594ef6,f64e599e2b7c3...
# 465                                                NaN
# 466                   83157f667c91431ea0377c2b9e594ef6
# 467                                                NaN
# 469                                                NaN
# 470                                                NaN
# 471                                                NaN
# 472                                                NaN
# 474                                                NaN
# 478                   f341082200c04dd3a60b3cd6124fd323
# 479                   f341082200c04dd3a60b3cd6124fd323
# 481                                                NaN
# 482                                                NaN
# 484                   46ac40cc7eaa41a99964956a984fd9c3
# 485                   46ac40cc7eaa41a99964956a984fd9c3
# 486                                                NaN
# 487                                                NaN
# 493                   fbdc45f28337467b8019e7db05355215
# 494                   fbdc45f28337467b8019e7db05355215
# 496                   fbdc45f28337467b8019e7db05355215
# 497                   fbdc45f28337467b8019e7db05355215
# 499                   fbdc45f28337467b8019e7db05355215
# 500                   fbdc45f28337467b8019e7db05355215
# 502                   f341082200c04dd3a60b3cd6124fd323
# 503                   f341082200c04dd3a60b3cd6124fd323
# 505                   fbdc45f28337467b8019e7db05355215
# 506                   fbdc45f28337467b8019e7db05355215
# 507                   fbdc45f28337467b8019e7db05355215
# 509                   fbdc45f28337467b8019e7db05355215
# 510                   fbdc45f28337467b8019e7db05355215
# 511                   fbdc45f28337467b8019e7db05355215
# 512                   fbdc45f28337467b8019e7db05355215
# 514                   fbdc45f28337467b8019e7db05355215
# 515                   fbdc45f28337467b8019e7db05355215
# 516                   fbdc45f28337467b8019e7db05355215
# 517                   fbdc45f28337467b8019e7db05355215
# 519                   fbdc45f28337467b8019e7db05355215
# 524                   f341082200c04dd3a60b3cd6124fd323
# 525                   f341082200c04dd3a60b3cd6124fd323
# 527                   fbdc45f28337467b8019e7db05355215
# 528                   fbdc45f28337467b8019e7db05355215
# 529                   fbdc45f28337467b8019e7db05355215
# 531                   fbdc45f28337467b8019e7db05355215
# 532                   fbdc45f28337467b8019e7db05355215
# 533                   fbdc45f28337467b8019e7db05355215
# 535                   fbdc45f28337467b8019e7db05355215
# 536                   fbdc45f28337467b8019e7db05355215
# 537                   fbdc45f28337467b8019e7db05355215
# 539                   fbdc45f28337467b8019e7db05355215
# 540                   fbdc45f28337467b8019e7db05355215
# 541                   fbdc45f28337467b8019e7db05355215
# 543                   fbdc45f28337467b8019e7db05355215
# 544                   fbdc45f28337467b8019e7db05355215
# 545                   fbdc45f28337467b8019e7db05355215
# 547                   fbdc45f28337467b8019e7db05355215
# 548                   fbdc45f28337467b8019e7db05355215
# 549                   fbdc45f28337467b8019e7db05355215
# 551                   f341082200c04dd3a60b3cd6124fd323
# 552                   f341082200c04dd3a60b3cd6124fd323
# 554                   fbdc45f28337467b8019e7db05355215
# 555                   fbdc45f28337467b8019e7db05355215
# 556                   fbdc45f28337467b8019e7db05355215
# 558                   fbdc45f28337467b8019e7db05355215
# 559                   fbdc45f28337467b8019e7db05355215
# 560                   fbdc45f28337467b8019e7db05355215

# %%
def get_connection_establishing(df):
    possible_rows = df[~df['Command Opcode'].isna()]
    starting_indices = possible_rows[possible_rows['Command Opcode'].str.contains('LE Add Device To White List')].index
    connection_update_indices = possible_rows[possible_rows['Command Opcode'].str.contains('LE Connection Update')].index
    connection_start_intervals = [(start,[i for i in connection_update_indices if i>start][0]) for start in starting_indices]
    return connection_start_intervals

def get_connection_updates(df):
    possible_rows = df[~df['Command Opcode'].isna()]
    connection_update_indices = possible_rows[possible_rows['Command Opcode'].str.contains('LE Connection Update')].index
    return connection_update_indices.values

def get_mtu_updates(df):
    possible_rows = df[~df['Opcode'].isna()]
    possible_rows = possible_rows[possible_rows['Direction'].str.contains("Rcvd")]
    mtu_update_rows = possible_rows[possible_rows['Opcode'].str.contains("MTU")]
    return mtu_update_rows.index.values
    

def get_updates(df,handle="0x0001"):
    possible_rows = df[~df['Handle'].isna()]
    possible_rows = possible_rows[possible_rows['Direction'].str.contains("Sent")]
    mtu_update_indices = possible_rows[possible_rows['Handle'].str.contains(handle)].index
    return mtu_update_indices.values

# %%
print(get_connection_establishing(df))
print(get_connection_updates(df))
print(get_mtu_updates(df))

# %%
def get_advertising_trace(df):
    return df[(df['Protocol'] == 'HCI_EVT') & (~df['RSSI'].isna())]

# %%
get_advertising_trace(df)

# %%
# %run HelpClasses.ipynb

# %%
latest_request_end = 0
requests = Request.resolve_ATT_Requests(df)
mtu_handle = "0x0052"
data_size_handle = "0x2222"
connection_interval_handle = "0x000a"

mtu_updates = get_mtu_updates(df)
mtu_info = [(0,23)] + [(i, df.loc[i]['Server Rx MTU']) for i in mtu_updates]
print(mtu_info)

conn_updates = get_connection_updates(df)
conn_update_info = [(i, df.loc[i]['Connection Interval Max']) for i in conn_updates]
print(conn_update_info)
for i,r in enumerate(requests):
    latest_conn_interval = [b for a,b in conn_update_info if not a > r.start_request_index][-1]
    latest_mtu_size = [b for a,b in mtu_info if not a > r.start_request_index][-1]
    r.set_conn_interval(latest_conn_interval)
    r.set_mtu_size(latest_mtu_size)
    

    #print(i,r.request_type,r.duration,r.request_amount,r.data)

# %%
statistics = pd.DataFrame.from_dict([r.as_dict() for r in requests if r.request_type == "READ" or r.request_type =="SPECIAL WRITE"])
statistics['duration'] = statistics['duration'].apply(lambda t:(t.microseconds+t.seconds*1_000_000)/1_000)
# print(statistics[['request_type','duration','mtu_size','data']])
statistics[['data','duration','request_type']].plot.scatter(x='data',y='duration',c=np.unique(statistics['request_type'].values,return_inverse=True)[1],colormap='viridis')
statistics.groupby(['mtu_size','request_type','conn_interval','data'])['duration'].agg(['count','mean','max'])

# %%
print(requests[28].as_dict())
requests[28].plot()
print(requests[30].dataframe[['Time.1','Opcode','Direction']])
requests[30].plot()

# %%
for i,r in enumerate(requests):
#    print(i,r.request_type, r.mtu_size, r.conn_interval, r.duration,r.data)
    if r.request_type == "READ" or r.request_type=="SPECIAL WRITE":
        r.plot()

# %%
for i,r in enumerate(requests):
    if r.request_type == 'READ':
        r.plot(title_extra = str(i) + ": " + str(r.data)+" Byte, interval:"+str(r.conn_interval))

# %%
for i,r in enumerate(requests):
    if r.request_type == 'PREPARE WRITE':
        r.plot(title_extra = str(i) + ": " + str(r.data)+" Byte, interval:"+str(r.conn_interval))
        print(r.dataframe[['Time','Timediff','Paketdiff','Direction','Opcode']])

# %%
analyse = requests[26]
print(analyse.dataframe[['Time','Timediff','Paketdiff','Direction','Opcode']])
print("connection interval:",analyse.conn_interval, analyse.conn_interval *2)
analyse.plot(title_extra=str(analyse.conn_interval)+" ms")
print()

# %%
statistics = pd.DataFrame.from_dict([r.as_dict() for r in requests])
reads = statistics[statistics['request_type'] == 'READ']
reads[['conn_interval','duration','data']].groupby(['data','conn_interval']).describe()

# %%
def get_request_trace_read(df):
    request_indices = list(df[(df['Direction'].str.contains('Sent')) & (df['Opcode'].str.contains('Read Request'))].index.values)
    response_indices = list(df[(df['Direction'].str.contains('Rcvd')) & (df['Opcode'].str.contains('Read Blob Response')) & (df['Length'] < 32)].index.values)
    request_times = [df.loc[index]['Time.1'] for index in request_indices]
    response_times = [df.loc[index]['Time.1'] for index in response_indices]
    return list(zip(request_indices,response_indices)),list(zip(request_times,response_times))

# %%
get_request_trace_read(frames[device_macs[1]])

# %%
# %run HelpClasses.ipynb

# %%
x = Request(df_tmp,conn_interval=42)
x.plot()

# %%
device_infos = dict()
for device in device_macs:
    frame = frames[device]
    device_communication = dict()
    request_indices,request_times = get_request_trace_read(frame)
    device_communication['read requests'] = request_indices
    device_communication['read requests times'] = request_times
    device_infos[device] = device_communication
pprint.pprint(device_infos)
print()
for addr, info in device_infos.items():
    print(addr)
    times = info['read requests times']
    for a,b in times:
        print("\t",b-a)
    request_indices = info['read requests']
    for a,b in request_indices:
        request = Request(df.loc[a:b],conn_interval=54)
        request.plot()

# %%
print(frames[device_macs[1]].columns)

# %%
def print_read_request_packets(df,start_index,end_index,conn_interval=54,title="",max_intervals = None):
    read_df = df.loc[start_index:end_index].copy()
    
    time_begin = read_df.iloc[0]['Time.1']
    # print(connection_intervals)
    if max_intervals == None:
        latest_packet = read_df['Time.1'].apply(lambda x:x-time_begin).max().microseconds/1000
        max_intervals = np.ceil(latest_packet / conn_interval).astype(int)+1
    connection_intervals = [i for i in range(0,conn_interval*max_intervals,conn_interval)]
    
    fig, ax = plt.subplots(figsize=(6,3))
    # plt.plot(connection_intervals,[1.1]*len(connection_intervals),'*')
    plt.title(title)
    plt.ylim([0.5,2])
    plt.xlim([0,max(connection_intervals)])
    ax.axes.yaxis.set_visible(False)
    
    # conn - intervall lines
    plt.vlines(connection_intervals,0.5,2,linestyles='dotted')
    
    # data packets
    for index, row in read_df.iterrows():
        info = row['Opcode'].lower()
        packet_time = (row['Time.1']-time_begin).microseconds / 1000
        #duration might be not interesting at all
        packet_size_bit = (row['Length']-1)*8
        rect_width = conn_interval/4
        if 'request' in info:
            rect = matplotlib.patches.Rectangle((packet_time, 1), rect_width , 0.5, linewidth=1, alpha=0.2,color='orange')
            plt.text(packet_time,1,'REQ',color='orange')
            ax.add_patch(rect)
        elif 'response' in info:
            rect = matplotlib.patches.Rectangle((packet_time, 1), -rect_width, 0.5, linewidth=1, alpha=0.2,color='green')
            plt.text(packet_time-rect_width,1.5,'RES',color='green')
            ax.add_patch(rect)
    plt.tight_layout()
    plt.xlabel('time in ms')
    plt.show()

# %%
for addr,info in device_infos.items():
    for read_request_start,read_request_end in info['read requests']:
        print_read_request_packets(frames[addr],read_request_start,read_request_end,title="%s %s-%s"%(addr,read_request_start,read_request_end),max_intervals=8)

# %%
col = list(matplotlib.colors.BASE_COLORS.values())
fig, ax = plt.subplots(figsize=(12,3))
for index,addr in enumerate(device_macs):
    index+=1
    for request,response in device_infos[addr]['read requests']:
        date_request = frames[addr].loc[request]['Time.1']
        date_response = frames[addr].loc[response]['Time.1']
        plt.plot(date_request,1*index,'^',color=col[index-1])
        plt.plot(date_response,1*index,'x',color=col[index-1])
        
        # Create a Rectangle patch
        time_delta = date_response-date_request
        rect = matplotlib.patches.Rectangle((date_request, 1*index), time_delta, 0.5, linewidth=1, edgecolor='r', facecolor=col[index-1],alpha=0.1)
        text = "%s.%s"%(time_delta.seconds,time_delta.microseconds)
        plt.text(date_request,1*index+0.2,text)
        # Add the patch to the Axes
        ax.add_patch(rect)
        
ax.spines['top'].set_color('none')
ax.spines['right'].set_color('none')
ax.spines['left'].set_color('none')
ax.spines['bottom'].set_position('zero')
plt.tight_layout()
plt.show()

# %%
for addr in device_macs:
    for request_index in device_infos[addr]['read requests']:
        packets_between = frames[addr].loc[request_index[0]:request_index[1]]
        send = packets_between[packets_between['Direction'] == 'Sent']
        received = packets_between[packets_between['Direction'] == 'Rcvd']

        fig, ax = plt.subplots(figsize=(12,1))
        plt.plot(send['Time.1'],[2]*len(send['Time.1']),'^')
        alternate = 0
        for time,send_type in zip(send['Time.1'].values,send['Opcode'].values):
            if('Blob' in send_type):
                send_type = 'Blob'
            elif (send_type == 'Read Request'):
                send_type = 'Read'
            plt.text(time,1.75-alternate/5,send_type)
            alternate = (alternate+1)%2

        plt.plot(received['Time.1'],[3]*len(received['Time.1']),'x')
        alternate = 0
        for time,send_type in zip(received['Time.1'].values,received['Opcode'].values):
            if('Blob' in send_type):
                send_type = 'Blob'
            elif (send_type == 'Read Response'):
                send_type = 'Read'
            plt.text(time,3.25+alternate/5,send_type)
            alternate = (alternate+1)%2
        time_delta = received['Time.1'].max()-send['Time.1'].min()

        fig.suptitle("%s requests & %s responses in %s.%s seconds"%(len(send),len(received),time_delta.seconds,time_delta.microseconds))
        fig.subplots_adjust(top=1.5)
        ax.spines['top'].set_color('none')
        ax.spines['right'].set_color('none')
        ax.spines['left'].set_color('none')
        ax.spines['bottom'].set_position('zero')
        plt.show()
