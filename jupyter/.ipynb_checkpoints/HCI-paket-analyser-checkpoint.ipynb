# %%
import pandas as pd
import datetime
import pprint
import re
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
# %run UbertoothHelpClasses.ipynb
# Out:
# Data Size 64mnopqrstuvwxyzabcdefghijklmnopqrstuvwxyzabcdefghijkl 64
# 72

# %%
columns = ["time","priority","class","message","extra"]
device_macs = [mac.lower() for mac in ["24:0A:C4:61:78:D2","24:0A:C4:60:EF:3A","24:0A:C4:60:E5:D2"]]

# %%
df = pd.DataFrame()
for filename in os.listdir("measurements"):
    print(filename)
    if filename.startswith("hci") and filename.endswith(".csv"):
        df = df.append(pd.read_csv("measurements/"+filename,encoding='latin1'))
        print("Added")
    if os.path.isdir("measurements/"+filename):
        for filename_subfolder in os.listdir("measurements/"+filename):
            if filename_subfolder.startswith("hci") and filename_subfolder.endswith(".csv"):
                print("%s/%s"%(filename,filename_subfolder))
                df = df.append(pd.read_csv("measurements/"+filename+"/"+filename_subfolder,encoding='latin1'))
                print("Added")
df_original = df
df
# Out:
# hci-notify_ci_256.csv
# Added
# messwerte-2021-05-25
# messwerte-2021-05-25/hci_ci_64.csv
# Added
# messwerte-2021-05-25/hci_ci_36.csv
# Added
# messwerte-2021-05-25/hci_ci_256.csv
# Added
# messwerte-read
# messwerte-read/hci_conn_int_change_notfy_2.csv
# Added
# messwerte-read/hci_conn_int_change_read_and_notify.csv
# Added
# messwerte-read/hci_data_change.csv
# Added
# messwerte-read/hci_mtu_change.csv
# Added
# messwerte-read/hci_mtu_change_2.csv
# Added
# hci-notify.csv
# Added
# messwerte-notify-detailed
# messwerte-notify-detailed/hci_mtu_change.csv
# Added
# messwerte-notify-new
# messwerte-notify-new/hci-notify_ci_256.csv
# Added
# messwerte-notify-new/hci-notify.csv
# Added
#        No.        Time      Source Destination Protocol  Length  \
# 0        1    0.000000        host  controller  HCI_CMD       4
# 1        2    0.002463  controller        host  HCI_EVT       7
# 2        3    0.002883        host  controller  HCI_CMD       4
# 3        4    0.006051  controller        host  HCI_EVT      14
# 4        5    0.006480        host  controller  HCI_CMD      11
# ...    ...         ...         ...         ...      ...     ...
# 1814  1815  445.605617  controller        host  HCI_EVT       7
# 1815  1816  445.605839        host  controller  HCI_CMD       5
# 1816  1817  445.607906  controller        host  HCI_EVT       7
# 1817  1818  445.608165        host  controller  HCI_CMD       4
# 1818  1819  445.609644  controller        host  HCI_EVT       7
#
#       Request in Frame  RF Channel Opcode Value Handle  \
# 0                  NaN         NaN    NaN   NaN    NaN
# 1                  NaN         NaN    NaN   NaN    NaN
# 2                  NaN         NaN    NaN   NaN    NaN
# 3                  NaN         NaN    NaN   NaN    NaN
# 4                  NaN         NaN    NaN   NaN    NaN
# ...                ...         ...    ...   ...    ...
# 1814               NaN         NaN    NaN   NaN    NaN
# 1815               NaN         NaN    NaN   NaN    NaN
# 1816               NaN         NaN    NaN   NaN    NaN
# 1817               NaN         NaN    NaN   NaN    NaN
# 1818               NaN         NaN    NaN   NaN    NaN
#
#                                              Info                      Time.1  \
# 0                                      Sent Reset  2021-06-07 14:05:09,970216
# 1                   Rcvd Command Complete (Reset)  2021-06-07 14:05:09,972679
# 2                           Sent Read Buffer Size  2021-06-07 14:05:09,973099
# 3        Rcvd Command Complete (Read Buffer Size)  2021-06-07 14:05:09,976267
# 4                           Sent Host Buffer Size  2021-06-07 14:05:09,976696
# ...                                           ...                         ...
# 1814    Rcvd Command Complete (Write Scan Enable)  2021-06-07 12:15:42,385034
# 1815                       Sent Write Scan Enable  2021-06-07 12:15:42,385256
# 1816    Rcvd Command Complete (Write Scan Enable)  2021-06-07 12:15:42,387323
# 1817                     Sent LE Clear White List  2021-06-07 12:15:42,387582
# 1818  Rcvd Command Complete (LE Clear White List)  2021-06-07 12:15:42,389061
#
#      UUID
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# ...   ...
# 1814  NaN
# 1815  NaN
# 1816  NaN
# 1817  NaN
# 1818  NaN
#
# [33163 rows x 14 columns]

# %% [markdown]
# ### Clean Data

# %%
df = df[df['Protocol'].str.contains("ATT")]

# %%
print("Types:\n%s"%df.dtypes)
df.fillna("")
df['Value'] = df['Value'].astype(str)
df['Opcode'] = df['Opcode'].astype(str)
df['Handle'] = df['Handle'].astype(str)
df['UUID'] = df['UUID'].astype(str)

print()
print("Cleaned:\n%s"%df.dtypes)

df
# Out:
# Types:
# No.                   int64
# Time                float64
# Source               object
# Destination          object
# Protocol             object
# Length                int64
# Request in Frame    float64
# RF Channel          float64
# Opcode               object
# Value                object
# Handle               object
# Info                 object
# Time.1               object
# UUID                 object
# dtype: object
#
# Cleaned:
# No.                   int64
# Time                float64
# Source               object
# Destination          object
# Protocol             object
# Length                int64
# Request in Frame    float64
# RF Channel          float64
# Opcode               object
# Value                object
# Handle               object
# Info                 object
# Time.1               object
# UUID                 object
# dtype: object
# <ipython-input-6-4aeacd67551a>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Value'] = df['Value'].astype(str)
# <ipython-input-6-4aeacd67551a>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Opcode'] = df['Opcode'].astype(str)
# <ipython-input-6-4aeacd67551a>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Handle'] = df['Handle'].astype(str)
# <ipython-input-6-4aeacd67551a>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['UUID'] = df['UUID'].astype(str)
#        No.        Time                              Source  \
# 357    358    9.060421  HuaweiTe_27:59:79 (HUAWEI P20 Pro)
# 360    361    9.201632         Espressi_60:ef:3a (ESP32-T)
# 361    362    9.202503  HuaweiTe_27:59:79 (HUAWEI P20 Pro)
# 363    364    9.299292         Espressi_60:ef:3a (ESP32-T)
# 364    365    9.300358  HuaweiTe_27:59:79 (HUAWEI P20 Pro)
# ...    ...         ...                                 ...
# 1771  1772  428.464851         Espressi_60:ef:3a (ESP32-T)
# 1772  1773  428.465021         Espressi_60:ef:3a (ESP32-T)
# 1773  1774  428.465184         Espressi_60:ef:3a (ESP32-T)
# 1774  1775  428.465341         Espressi_60:ef:3a (ESP32-T)
# 1775  1776  428.466098         Espressi_60:ef:3a (ESP32-T)
#
#                              Destination Protocol  Length  Request in Frame  \
# 357          Espressi_60:ef:3a (ESP32-T)      ATT      16               NaN
# 360   HuaweiTe_27:59:79 (HUAWEI P20 Pro)      ATT      23             358.0
# 361          Espressi_60:ef:3a (ESP32-T)      ATT      16               NaN
# 363   HuaweiTe_27:59:79 (HUAWEI P20 Pro)      ATT      31             362.0
# 364          Espressi_60:ef:3a (ESP32-T)      ATT      16               NaN
# ...                                  ...      ...     ...               ...
# 1771  HuaweiTe_27:59:79 (HUAWEI P20 Pro)      ATT      41               NaN
# 1772  HuaweiTe_27:59:79 (HUAWEI P20 Pro)      ATT      41               NaN
# 1773  HuaweiTe_27:59:79 (HUAWEI P20 Pro)      ATT      41               NaN
# 1774  HuaweiTe_27:59:79 (HUAWEI P20 Pro)      ATT      41               NaN
# 1775  HuaweiTe_27:59:79 (HUAWEI P20 Pro)      ATT      36               NaN
#
#       RF Channel                       Opcode  \
# 357          NaN   Read By Group Type Request
# 360          NaN  Read By Group Type Response
# 361          NaN   Read By Group Type Request
# 363          NaN  Read By Group Type Response
# 364          NaN         Read By Type Request
# ...          ...                          ...
# 1771         NaN    Handle Value Notification
# 1772         NaN    Handle Value Notification
# 1773         NaN    Handle Value Notification
# 1774         NaN    Handle Value Notification
# 1775         NaN    Handle Value Notification
#
#                                                   Value         Handle  \
# 357                                                 nan            nan
# 360                                                 nan  0x0001,0x0014
# 361                                                 nan            nan
# 363                                                 nan         0x0028
# 364                                                 nan            nan
# ...                                                 ...            ...
# 1771  6d6e6f707172737475767778797a616263646566676869...         0x0030
# 1772  707172737475767778797a6162636465666768696a6b6c...         0x0030
# 1773  737475767778797a6162636465666768696a6b6c6d6e6f...         0x0030
# 1774  767778797a6162636465666768696a6b6c6d6e6f707172...         0x0030
# 1775   797a6162636465666768696a6b6c6d6e6f70717273747576         0x0030
#
#                                                    Info  \
# 357   Sent Read By Group Type Request, GATT Primary ...
# 360   Rcvd Read By Group Type Response, Attribute Li...
# 361   Sent Read By Group Type Request, GATT Primary ...
# 363   Rcvd Read By Group Type Response, Attribute Li...
# 364   Sent Read By Type Request, GATT Include Declar...
# ...                                                 ...
# 1771  Rcvd Handle Value Notification, Handle: 0x0030...
# 1772  Rcvd Handle Value Notification, Handle: 0x0030...
# 1773  Rcvd Handle Value Notification, Handle: 0x0030...
# 1774  Rcvd Handle Value Notification, Handle: 0x0030...
# 1775  Rcvd Handle Value Notification, Handle: 0x0030...
#
#                           Time.1  \
# 357   2021-06-07 14:05:19,030637
# 360   2021-06-07 14:05:19,171848
# 361   2021-06-07 14:05:19,172719
# 363   2021-06-07 14:05:19,269508
# 364   2021-06-07 14:05:19,270574
# ...                          ...
# 1771  2021-06-07 12:15:25,244268
# 1772  2021-06-07 12:15:25,244438
# 1773  2021-06-07 12:15:25,244601
# 1774  2021-06-07 12:15:25,244758
# 1775  2021-06-07 12:15:25,245515
#
#                                                    UUID
# 357                                                 nan
# 360                                                 nan
# 361                                                 nan
# 363   26cb2f28a4ba49fc856ad57fe4d3dada,dadad3e47fd56...
# 364                                                 nan
# ...                                                 ...
# 1771                   1ee1d0fc6f3c4c6aac1cc54d2a97f932
# 1772                   1ee1d0fc6f3c4c6aac1cc54d2a97f932
# 1773                   1ee1d0fc6f3c4c6aac1cc54d2a97f932
# 1774                   1ee1d0fc6f3c4c6aac1cc54d2a97f932
# 1775                   1ee1d0fc6f3c4c6aac1cc54d2a97f932
#
# [9277 rows x 14 columns]

# %% [markdown]
# ### Add Time

# %%
df["Time.1"] = pd.to_datetime(df["Time.1"],format="%Y-%m-%d %H:%M:%S,%f")+ pd.Timedelta(hours=1)
df = df.sort_values("Time.1")
df
# Out:
# <ipython-input-7-623deb7f0879>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Time.1"] = pd.to_datetime(df["Time.1"],format="%Y-%m-%d %H:%M:%S,%f")+ pd.Timedelta(hours=1)
#          No.        Time                              Source  \
# 15784  15785  289.173475                        localhost ()
# 15787  15788  289.318103         Espressi_60:ef:3a (ESP32-T)
# 15788  15789  289.318913                        localhost ()
# 15790  15791  289.418063         Espressi_60:ef:3a (ESP32-T)
# 15791  15792  289.418906                        localhost ()
# ...      ...         ...                                 ...
# 1414    1415  222.052188         Espressi_60:ef:3a (ESP32-T)
# 1415    1416  222.052887  HuaweiTe_27:59:79 (HUAWEI P20 Pro)
# 1417    1418  222.211614         Espressi_60:ef:3a (ESP32-T)
# 1418    1419  222.212199  HuaweiTe_27:59:79 (HUAWEI P20 Pro)
# 1419    1420  222.450952         Espressi_60:ef:3a (ESP32-T)
#
#                               Destination Protocol  Length  Request in Frame  \
# 15784         Espressi_60:ef:3a (ESP32-T)      ATT      16               NaN
# 15787                        localhost ()      ATT      23           15785.0
# 15788         Espressi_60:ef:3a (ESP32-T)      ATT      16               NaN
# 15790                        localhost ()      ATT      31           15789.0
# 15791         Espressi_60:ef:3a (ESP32-T)      ATT      16               NaN
# ...                                   ...      ...     ...               ...
# 1414   HuaweiTe_27:59:79 (HUAWEI P20 Pro)      ATT      32            1414.0
# 1415          Espressi_60:ef:3a (ESP32-T)      ATT      14               NaN
# 1417   HuaweiTe_27:59:79 (HUAWEI P20 Pro)      ATT      32            1416.0
# 1418          Espressi_60:ef:3a (ESP32-T)      ATT      14               NaN
# 1419   HuaweiTe_27:59:79 (HUAWEI P20 Pro)      ATT      11            1419.0
#
#        RF Channel                       Opcode  \
# 15784         NaN   Read By Group Type Request
# 15787         NaN  Read By Group Type Response
# 15788         NaN   Read By Group Type Request
# 15790         NaN  Read By Group Type Response
# 15791         NaN         Read By Type Request
# ...           ...                          ...
# 1414          NaN           Read Blob Response
# 1415          NaN            Read Blob Request
# 1417          NaN           Read Blob Response
# 1418          NaN            Read Blob Request
# 1419          NaN           Read Blob Response
#
#                                               Value         Handle  \
# 15784                                           nan            nan
# 15787                                           nan  0x0001,0x0014
# 15788                                           nan            nan
# 15790                                           nan         0x0028
# 15791                                           nan            nan
# ...                                             ...            ...
# 1414   7778797a6162636465666768696a6b6c6d6e6f707172         0x002a
# 1415                                            nan         0x002a
# 1417   737475767778797a6162636465666768696a6b6c6d6e         0x002a
# 1418                                            nan         0x002a
# 1419                                             6f         0x002a
#
#                                                     Info  \
# 15784  Sent Read By Group Type Request, GATT Primary ...
# 15787  Rcvd Read By Group Type Response, Attribute Li...
# 15788  Sent Read By Group Type Request, GATT Primary ...
# 15790  Rcvd Read By Group Type Response, Attribute Li...
# 15791  Sent Read By Type Request, GATT Include Declar...
# ...                                                  ...
# 1414   Rcvd Read Blob Response, Handle: 0x002a (Unkno...
# 1415   Sent Read Blob Request, Handle: 0x002a (Unknow...
# 1417   Rcvd Read Blob Response, Handle: 0x002a (Unkno...
# 1418   Sent Read Blob Request, Handle: 0x002a (Unknow...
# 1419   Rcvd Read Blob Response, Handle: 0x002a (Unkno...
#
#                           Time.1  \
# 15784 2021-05-25 16:38:42.303438
# 15787 2021-05-25 16:38:42.448066
# 15788 2021-05-25 16:38:42.448876
# 15790 2021-05-25 16:38:42.548026
# 15791 2021-05-25 16:38:42.548869
# ...                          ...
# 1414  2021-06-12 11:36:38.004213
# 1415  2021-06-12 11:36:38.004912
# 1417  2021-06-12 11:36:38.163639
# 1418  2021-06-12 11:36:38.164224
# 1419  2021-06-12 11:36:38.402977
#
#                                                     UUID
# 15784                                                nan
# 15787                                                nan
# 15788                                                nan
# 15790  26cb2f28a4ba49fc856ad57fe4d3dada,dadad3e47fd56...
# 15791                                                nan
# ...                                                  ...
# 1414                    fbdc45f28337467b8019e7db05355215
# 1415                    fbdc45f28337467b8019e7db05355215
# 1417                    fbdc45f28337467b8019e7db05355215
# 1418                    fbdc45f28337467b8019e7db05355215
# 1419                    fbdc45f28337467b8019e7db05355215
#
# [9277 rows x 14 columns]

# %% [markdown]
# ### Split Data into Mac Adresses

# %%
devices = list(set(df['Destination']))
print("Devices:%s"%devices)
devices = [d for d in devices if d.startswith("Espressi")]
# Expected addr: Espressi_xx:xx:xx ()
devices = [d.split("_")[1][:8] for d in devices]
devices = list(set(devices))
devices
# Out:
# Devices:['localhost ()', 'Espressi_60:ef:3a (ESP32-T)', 'HuaweiTe_27:59:79 (HUAWEI P20 Pro)', 'Espressi_60:ef:3a ()']
# ['60:ef:3a']

# %%
device_df_dict = dict()
for device_mac in devices:
    df_other_device = df[df["Source"].str.contains(device_mac)]
    df_other_device = df_other_device.append(df[df["Destination"].str.contains(device_mac)],ignore_index=True)
    device_df_dict[device_mac]=df_other_device
[print(key,value.shape) for key,value in device_df_dict.items()]
# Out:
# 60:ef:3a (9277, 14)
# [None]

# %% [markdown]
# ### Clean Data

# %%
for k,df in device_df_dict.items():
    device_df_dict[k] = df.drop(["Source","Destination","Protocol"],axis=1)

# %% [markdown]
# ### Add Packet Types

# %%
uuid_map = dict({ #"26cb2f28-a4ba-49fc-856a-d57fe4d3dada":"SERVICE_UUID_MAIN",
"fbdc45f2-8337-467b-8019-e7db05355215":"CHARACTERISTIC_UUID_READ",
"8c65f73d-ddab-4dd9-a2e0-f5a10ce7e252":"CHARACTERISTIC_UUID_WRITE_COMMAND",
"f3410822-00c0-4dd3-a60b-3cd6124fd323":"CHARACTERISTIC_UUID_WRITE_SIZE",
"1ee1d0fc-6f3c-4c6a-ac1c-c54d2a97f932":"CHARACTERISTIC_UUID_NOTIFY",
"83157f66-7c91-431e-a037-7c2b9e594ef6":"CHARACTERISTIC_UUID_INDICATE",
"46ac40cc-7eaa-41a9-9964-956a984fd9c3":"CHARACTERISTIC_UUID_CONN_INTERVAL"})
uuid_map = {k.replace("-",""):v.replace("CHARACTERISTIC_UUID_","") for k,v in uuid_map.items()}

# %%
def checkPaketType(row):  
    uuid = row['UUID']
    if uuid in uuid_map.keys():
        if "Response" in row['Opcode']:
            return uuid_map[uuid] + " Rcvd"
        elif "Request" in row['Opcode']:
            return uuid_map[uuid] + " Req"
        else:
            return uuid_map[uuid]
    else:
        return ""
    
for k,df in device_df_dict.items():
    df = device_df_dict[k]
    device_df_dict[k]['Pakettype'] = df.apply(axis=1,func = checkPaketType)
    print(k,'Pakettypes:%s'%list(set(device_df_dict[k]['Pakettype'].values)))
# Out:
# 60:ef:3a Pakettypes:['', 'CONN_INTERVAL Req', 'READ Rcvd', 'CONN_INTERVAL Rcvd', 'WRITE_COMMAND Req', 'WRITE_SIZE Rcvd', 'WRITE_COMMAND Rcvd', 'READ Req', 'INDICATE Rcvd', 'WRITE_SIZE Req', 'NOTIFY']

# %%
no_type_dict = dict()
for addr in devices:
    df = device_df_dict[addr]
    no_type_dict[addr] = df[~df['Pakettype'].apply(lambda x:len(x)>0)]
    device_df_dict[addr] = df.drop(no_type_dict[addr].index.values)
    print(addr,"no types:",no_type_dict[addr].shape)
# Out:
# 60:ef:3a no types: (835, 12)

# %% [markdown]
# ### Cant Define Hops on HCI

# %% [markdown]
# ### Define Settings

# %%
def hex_string_to_int(string,reverse=True):
    if reverse:
        string = "".join(reversed([string[i:i+2] for i in range(0, len(string),2)]))
    print(string,"->",int(string,16))
    return int(string,16)
    
def mtu_df_to_list_of_tuple(df):
    df_tmp =  df[df['Opcode'].str.contains("Response")]
    mtu_updates = []
    for _,row in df_tmp.iterrows():
        mtu_size = int(row['Info'].split("MTU:")[-1].strip())
        time = row['Time.1']
        mtu_updates.append((time,mtu_size))
    return mtu_updates

def conn_interval_df_to_list_of_tuple(df):
    df_tmp =  df[df['Opcode'].str.contains("Request")]
    interval_updates = []
    for _,row in df_tmp.iterrows():
        conn_update = hex_string_to_int(row['Value'],reverse=True)
        time = row['Time.1']
        interval_updates.append((time,conn_update))
    return interval_updates

def data_size_df_to_list_of_tuple(df):
    df_tmp =  df[df['Opcode'].str.contains("Request")]
    size_updates = []
    for _,row in df_tmp.iterrows():
        data_size = hex_string_to_int(row['Value'],reverse=True)
        time = row['Time.1']
        size_updates.append((time,data_size))
    return size_updates

# %%
mtu_update_dict = dict()
size_update_dict = dict()
interval_update_dict = dict()
for addr in devices:
    df_no_type = no_type_dict[addr]
    df = device_df_dict[addr]
    
    df_update_mtu = df_no_type[df_no_type['Opcode'].str.contains("Exchange MTU")]
    mtu_update_dict[addr] = mtu_df_to_list_of_tuple(df_update_mtu)
    mtu_update_dict[addr].sort(key=lambda pair:pair[0])
    print("MTU Updates:")
    pprint.pprint(mtu_update_dict[addr])
    
    df_update_size = df[df['Pakettype'].str.contains("WRITE_SIZE")]
    size_update_dict[addr] = data_size_df_to_list_of_tuple(df_update_size)
    size_update_dict[addr].sort(key=lambda pair:pair[0])
    pprint.pprint("Size Updates:")
    pprint.pprint(size_update_dict[addr])
    
    df_update_interval = df[df['Pakettype'].str.contains("CONN_INTERVAL")]
    interval_update_dict[addr] =  conn_interval_df_to_list_of_tuple(df_update_interval)
    interval_update_dict[addr].sort(key=lambda pair:pair[0])
    pprint.pprint("Interval Updates:")
    pprint.pprint(interval_update_dict[addr])
    
    device_df_dict[addr] = device_df_dict[addr].drop(df_update_size.index.values)
    device_df_dict[addr] = device_df_dict[addr].drop(df_update_interval.index.values)
# Out:
# MTU Updates:
# [(Timestamp('2021-05-25 16:38:56.018516'), 23),
#  (Timestamp('2021-05-25 16:40:17.918233'), 32),
#  (Timestamp('2021-05-25 16:41:29.017756'), 64),
#  (Timestamp('2021-05-25 16:42:25.447630'), 128),
#  (Timestamp('2021-05-25 16:43:09.907797'), 256),
#  (Timestamp('2021-05-25 16:57:04.386074'), 23),
#  (Timestamp('2021-05-25 16:58:37.908050'), 32),
#  (Timestamp('2021-05-25 16:59:56.865378'), 64),
#  (Timestamp('2021-05-25 17:01:02.065250'), 128),
#  (Timestamp('2021-05-25 17:01:49.265453'), 256),
#  (Timestamp('2021-05-26 14:48:04.410271'), 23),
#  (Timestamp('2021-05-26 14:50:47.610334'), 32),
#  (Timestamp('2021-05-26 14:52:50.810824'), 64),
#  (Timestamp('2021-05-26 14:55:03.611235'), 128),
#  (Timestamp('2021-05-26 14:56:14.010948'), 256),
#  (Timestamp('2021-06-07 13:08:35.003519'), 23),
#  (Timestamp('2021-06-07 13:08:35.003519'), 23),
#  (Timestamp('2021-06-08 15:37:16.088962'), 32),
#  (Timestamp('2021-06-08 15:37:24.807680'), 33),
#  (Timestamp('2021-06-08 15:37:32.327440'), 35),
#  (Timestamp('2021-06-08 15:37:40.007776'), 64),
#  (Timestamp('2021-06-08 15:37:48.567490'), 65),
#  (Timestamp('2021-06-08 15:37:57.767421'), 67),
#  (Timestamp('2021-06-08 15:38:05.367295'), 128),
#  (Timestamp('2021-06-08 15:38:11.687777'), 129),
#  (Timestamp('2021-06-08 15:38:22.087305'), 131),
#  (Timestamp('2021-06-08 15:38:30.807299'), 256),
#  (Timestamp('2021-06-08 16:45:41.267281'), 35),
#  (Timestamp('2021-06-08 17:22:48.559935'), 35),
#  (Timestamp('2021-06-12 11:33:27.043301'), 23)]
# 00000014 -> 20
# 00000020 -> 32
# 00000040 -> 64
# 00000080 -> 128
# 00000100 -> 256
# 00000200 -> 512
# 00000014 -> 20
# 00000020 -> 32
# 00000040 -> 64
# 00000080 -> 128
# 00000100 -> 256
# 00000200 -> 512
# 00000014 -> 20
# 00000020 -> 32
# 00000040 -> 64
# 00000080 -> 128
# 00000100 -> 256
# 00000200 -> 512
# 00000014 -> 20
# 00000020 -> 32
# 00000040 -> 64
# 00000080 -> 128
# 00000100 -> 256
# 00000200 -> 512
# 00000014 -> 20
# 00000020 -> 32
# 00000040 -> 64
# 00000080 -> 128
# 00000100 -> 256
# 00000200 -> 512
# 00000014 -> 20
# 00000020 -> 32
# 00000040 -> 64
# 00000080 -> 128
# 00000100 -> 256
# 00000200 -> 512
# 00000014 -> 20
# 00000020 -> 32
# 00000040 -> 64
# 00000080 -> 128
# 00000100 -> 256
# 00000200 -> 512
# 00000014 -> 20
# 00000020 -> 32
# 00000040 -> 64
# 00000080 -> 128
# 00000100 -> 256
# 00000200 -> 512
# 00000014 -> 20
# 00000020 -> 32
# 00000040 -> 64
# 00000080 -> 128
# 00000100 -> 256
# 00000200 -> 512
# 00000014 -> 20
# 00000020 -> 32
# 00000040 -> 64
# 00000080 -> 128
# 00000100 -> 256
# 00000200 -> 512
# 00000014 -> 20
# 00000020 -> 32
# 00000040 -> 64
# 00000080 -> 128
# 00000100 -> 256
# 00000200 -> 512
# 00000014 -> 20
# 00000020 -> 32
# 00000040 -> 64
# 00000080 -> 128
# 00000100 -> 256
# 00000200 -> 512
# 00000014 -> 20
# 00000020 -> 32
# 00000040 -> 64
# 00000080 -> 128
# 00000100 -> 256
# 00000200 -> 512
# 00000014 -> 20
# 00000020 -> 32
# 00000040 -> 64
# 00000080 -> 128
# 00000100 -> 256
# 00000200 -> 512
# 00000014 -> 20
# 0000001e -> 30
# 00000020 -> 32
# 00000040 -> 64
# 00000080 -> 128
# 00000100 -> 256
# 00000200 -> 512
# 00000014 -> 20
# 00000014 -> 20
# 00000020 -> 32
# 00000020 -> 32
# 00000040 -> 64
# 00000040 -> 64
# 00000080 -> 128
# 00000080 -> 128
# 00000100 -> 256
# 00000100 -> 256
# 00000100 -> 256
# 00000100 -> 256
# 00000200 -> 512
# 00000200 -> 512
# 00000014 -> 20
# 00000014 -> 20
# 00000020 -> 32
# 00000020 -> 32
# 00000040 -> 64
# 00000040 -> 64
# 00000080 -> 128
# 00000080 -> 128
# 00000100 -> 256
# 00000100 -> 256
# 00000200 -> 512
# 00000200 -> 512
# 00000014 -> 20
# 00000014 -> 20
# 00000020 -> 32
# 00000020 -> 32
# 00000040 -> 64
# 00000040 -> 64
# 00000080 -> 128
# 00000080 -> 128
# 00000100 -> 256
# 00000100 -> 256
# 00000200 -> 512
# 00000200 -> 512
# 00000014 -> 20
# 00000014 -> 20
# 00000020 -> 32
# 00000020 -> 32
# 00000040 -> 64
# 00000040 -> 64
# 00000080 -> 128
# 00000080 -> 128
# 00000100 -> 256
# 00000100 -> 256
# 00000200 -> 512
# 00000200 -> 512
# 00000014 -> 20
# 00000014 -> 20
# 00000020 -> 32
# 00000020 -> 32
# 00000040 -> 64
# 00000040 -> 64
# 00000080 -> 128
# 00000080 -> 128
# 00000100 -> 256
# 00000100 -> 256
# 00000200 -> 512
# 00000200 -> 512
# 00000014 -> 20
# 00000014 -> 20
# 00000020 -> 32
# 00000020 -> 32
# 00000040 -> 64
# 00000040 -> 64
# 00000080 -> 128
# 00000080 -> 128
# 00000100 -> 256
# 00000100 -> 256
# 00000200 -> 512
# 00000200 -> 512
# 00000014 -> 20
# 00000014 -> 20
# 00000020 -> 32
# 00000020 -> 32
# 00000040 -> 64
# 00000040 -> 64
# 00000080 -> 128
# 00000080 -> 128
# 00000100 -> 256
# 00000100 -> 256
# 00000200 -> 512
# 00000200 -> 512
# 00000014 -> 20
# 00000014 -> 20
# 00000020 -> 32
# 00000020 -> 32
# 00000040 -> 64
# 00000040 -> 64
# 00000040 -> 64
# 00000040 -> 64
# 00000080 -> 128
# 00000080 -> 128
# 00000100 -> 256
# 00000100 -> 256
# 00000200 -> 512
# 00000200 -> 512
# 00000014 -> 20
# 00000014 -> 20
# 00000020 -> 32
# 00000020 -> 32
# 00000040 -> 64
# 00000040 -> 64
# 00000080 -> 128
# 00000080 -> 128
# 00000100 -> 256
# 00000100 -> 256
# 00000200 -> 512
# 00000200 -> 512
# 00000014 -> 20
# 00000014 -> 20
# 00000020 -> 32
# 00000020 -> 32
# 00000040 -> 64
# 00000040 -> 64
# 00000080 -> 128
# 00000080 -> 128
# 00000100 -> 256
# 00000100 -> 256
# 00000200 -> 512
# 00000200 -> 512
# 00000014 -> 20
# 00000014 -> 20
# 00000020 -> 32
# 00000020 -> 32
# 00000040 -> 64
# 00000040 -> 64
# 00000080 -> 128
# 00000080 -> 128
# 00000100 -> 256
# 00000100 -> 256
# 00000200 -> 512
# 00000200 -> 512
# 00000014 -> 20
# 00000014 -> 20
# 00000020 -> 32
# 00000020 -> 32
# 00000040 -> 64
# 00000040 -> 64
# 00000080 -> 128
# 00000080 -> 128
# 00000100 -> 256
# 00000100 -> 256
# 00000200 -> 512
# 00000200 -> 512
# 00000014 -> 20
# 00000014 -> 20
# 00000020 -> 32
# 00000020 -> 32
# 00000040 -> 64
# 00000040 -> 64
# 00000080 -> 128
# 00000080 -> 128
# 00000100 -> 256
# 00000100 -> 256
# 00000200 -> 512
# 00000200 -> 512
# 00000014 -> 20
# 00000014 -> 20
# 00000020 -> 32
# 00000020 -> 32
# 00000040 -> 64
# 00000040 -> 64
# 00000080 -> 128
# 00000080 -> 128
# 00000100 -> 256
# 00000100 -> 256
# 00000200 -> 512
# 00000200 -> 512
# 00000014 -> 20
# 00000014 -> 20
# 00000020 -> 32
# 00000020 -> 32
# 00000040 -> 64
# 00000040 -> 64
# 00000080 -> 128
# 00000080 -> 128
# 00000100 -> 256
# 00000100 -> 256
# 00000200 -> 512
# 00000200 -> 512
# 00000080 -> 128
# 00000080 -> 128
# 00000080 -> 128
# 00000080 -> 128
# 00000200 -> 512
# 00000200 -> 512
# 00000015 -> 21
# 00000016 -> 22
# 00000016 -> 22
# 00000017 -> 23
# 0000002b -> 43
# 0000002c -> 44
# 0000002d -> 45
# 00000041 -> 65
# 00000042 -> 66
# 00000043 -> 67
# 00000057 -> 87
# 00000058 -> 88
# 00000059 -> 89
# 000000af -> 175
# 000000b0 -> 176
# 000000b1 -> 177
# 0000015f -> 351
# 00000160 -> 352
# 00000161 -> 353
# 'Size Updates:'
# [(Timestamp('2021-05-25 16:39:03.142894'), 20),
#  (Timestamp('2021-05-25 16:39:15.284896'), 32),
#  (Timestamp('2021-05-25 16:39:23.055364'), 64),
#  (Timestamp('2021-05-25 16:39:32.249083'), 128),
#  (Timestamp('2021-05-25 16:39:41.528301'), 256),
#  (Timestamp('2021-05-25 16:39:53.923949'), 512),
#  (Timestamp('2021-05-25 16:40:21.904177'), 20),
#  (Timestamp('2021-05-25 16:40:30.150206'), 32),
#  (Timestamp('2021-05-25 16:40:38.185954'), 64),
#  (Timestamp('2021-05-25 16:40:46.759074'), 128),
#  (Timestamp('2021-05-25 16:41:03.430878'), 256),
#  (Timestamp('2021-05-25 16:41:15.473910'), 512),
#  (Timestamp('2021-05-25 16:41:33.775719'), 20),
#  (Timestamp('2021-05-25 16:41:40.987299'), 32),
#  (Timestamp('2021-05-25 16:41:47.759647'), 64),
#  (Timestamp('2021-05-25 16:41:55.011548'), 128),
#  (Timestamp('2021-05-25 16:42:04.820381'), 256),
#  (Timestamp('2021-05-25 16:42:13.208428'), 512),
#  (Timestamp('2021-05-25 16:42:27.649190'), 20),
#  (Timestamp('2021-05-25 16:42:33.715827'), 32),
#  (Timestamp('2021-05-25 16:42:40.014684'), 64),
#  (Timestamp('2021-05-25 16:42:47.117990'), 128),
#  (Timestamp('2021-05-25 16:42:54.017148'), 256),
#  (Timestamp('2021-05-25 16:43:01.381441'), 512),
#  (Timestamp('2021-06-08 16:48:56.710301'), 36),
#  (Timestamp('2021-06-08 16:49:05.755360'), 36),
#  (Timestamp('2021-06-08 17:22:52.478806'), 36),
#  (Timestamp('2021-06-08 17:23:07.118739'), 64),
#  (Timestamp('2021-06-08 17:23:17.139498'), 128),
#  (Timestamp('2021-06-08 17:23:27.180359'), 256),
#  (Timestamp('2021-06-08 17:23:40.460954'), 512),
#  (Timestamp('2021-06-08 17:24:15.595799'), 1024),
#  (Timestamp('2021-06-12 11:33:20.544350'), 64)]

# %% [markdown]
# ### Define Read & Notify Requests with REGEX
# Request -> A
# Following Request -> C
# Response -> B
# Following Response -> D
# Notify -> D

# %%
import re

# %%
paket_regex_map = dict({'Error Response':'Z', 
                        'Read Blob Response':'D', 
                        'Read Response':'B', 
                        'Handle Value Notification':'D', 
                        'Write Request':'A', 
                        'Write Response':'B', 
                        'Read Blob Request':'C', 
                        'Read Request':'A'
                       })

# %%
# examples for regex
test = "ABABABCDABCDAB"
for i in re.finditer('(AB)(CD)*',test):
    print(i)
test_2 = 'ABDDDABDDDBDDDAD'
for i in re.finditer('(AB|A|B)D*',test_2):
    print(i)
# Out:
# <re.Match object; span=(0, 2), match='AB'>
# <re.Match object; span=(2, 4), match='AB'>
# <re.Match object; span=(4, 8), match='ABCD'>
# <re.Match object; span=(8, 12), match='ABCD'>
# <re.Match object; span=(12, 14), match='AB'>
# <re.Match object; span=(0, 5), match='ABDDD'>
# <re.Match object; span=(5, 10), match='ABDDD'>
# <re.Match object; span=(10, 14), match='BDDD'>
# <re.Match object; span=(14, 16), match='AD'>

# %%
read_requests = dict()
for addr in devices:
    read_requests[addr] = []
    df = device_df_dict[addr]
    # Filter on Opcode == READ Req && READ Rcvd
    df.sort_values("Time.1",inplace=True)
    df = df[df['Opcode'].apply(lambda op:op in ['Read Request','Read Blob Request','Read Response','Read Blob Response'])]
    column_to_string = "".join(list(df['Opcode'].map(paket_regex_map).values))
    print(column_to_string)
    for i in re.finditer('(AB)(CD)*',column_to_string):
        first = i.span(0)[0]
        last = i.span(0)[1]
        request_type = df.iloc[first]['Pakettype']
        request = Request(request_type)
        request.add(df.iloc[first:last])
        request.state_close()
        read_requests[addr].append(request)

for addr in devices:
    print(addr,":",len(read_requests[addr]))
    print("bsp first request:")
    try:
        print(read_requests[addr][0])
    except:
        pass
# Out:
# ...
# 60:ef:3a : 394
# bsp first request:
# {'request_type': 'READ Req', 'starting_time': Timestamp('2021-05-25 16:39:08.578330'), 'ending_time': Timestamp('2021-05-25 16:39:08.664347'), 'duration': Timedelta('0 days 00:00:00.086017'), 'data_size': None, 'mtu_size': None, 'conn_interval': None, 'data': 'Data Size 20mnopqrst', 'read_requests': 1, 'read_responses': 1, 'notifies': 0}

# %%
write_requests = dict()
for addr in devices:
    write_requests[addr] = []
    df = device_df_dict[addr]
    # Filter on Opcode == READ Req && READ Rcvd
    df.sort_values("Time.1",inplace=True)
    df = df[df['Opcode'].apply(lambda op:op in ['Handle Value Notification','Write Request','Write Response'])]
    column_to_string = "".join(list(df['Opcode'].map(paket_regex_map).values))
    print(column_to_string)
    for i in re.finditer('(AB|A|B)D*',column_to_string):
        first = i.span(0)[0]
        last = i.span(0)[1]
        request_type = df.iloc[first]['Pakettype']
        request = Request(request_type)
        request.add(df.iloc[first:last])
        request.state_close()
        write_requests[addr].append(request)

for addr in devices:
    print(addr,":",len(write_requests[addr]))
    print("bsp first request:")
    print(write_requests[addr][0])
# Out:
# ...
# 60:ef:3a : 900
# bsp first request:
# {'request_type': 'WRITE_COMMAND Req', 'starting_time': Timestamp('2021-06-07 13:08:41.922114'), 'ending_time': Timestamp('2021-06-07 13:08:41.922114'), 'duration': Timedelta('0 days 00:00:00'), 'data_size': None, 'mtu_size': None, 'conn_interval': None, 'data': '', 'read_requests': 0, 'read_responses': 0, 'notifies': 0}

# %% [markdown]
# ### Combine Settings and Requests

# %%
all_requests = dict()
for addr in devices:
    print("addr:",addr,"combine",len(write_requests[addr]),"notify requests and",len(read_requests[addr]),"read requests")
    all_requests[addr] = write_requests[addr] + read_requests[addr]
    for r in all_requests[addr]:
        start_time = r.starting_time
        latest_mtu_updates = [mtu_update for mtu_update in mtu_update_dict[addr] if mtu_update[0] < start_time]
        latest_mtu_update = latest_mtu_updates[-1]
        r.set_mtu_size(latest_mtu_update[1])
        
        latest_data_updates = [update for update in size_update_dict[addr] if update[0] < start_time]
        latest_data_update = latest_data_updates[-1]
        r.set_data_size(latest_data_update[1])
                
        latest_conn_interval_updates = [update for update in interval_update_dict[addr] if update[0] < start_time]
        latest_conn_interval_update= latest_conn_interval_updates[-1]
        r.set_conn_interval(latest_conn_interval_update[1])
for addr in devices:
    index_to_check = 0
    print("bsp first request:",all_requests[addr][index_to_check],len(all_requests[addr][index_to_check].get_data(True)))
# Out:
# addr: 60:ef:3a combine 900 notify requests and 394 read requests
# bsp first request: {'request_type': 'WRITE_COMMAND Req', 'starting_time': Timestamp('2021-06-07 13:08:41.922114'), 'ending_time': Timestamp('2021-06-07 13:08:41.922114'), 'duration': Timedelta('0 days 00:00:00'), 'data_size': 20, 'mtu_size': 23, 'conn_interval': 36, 'data': '', 'read_requests': 0, 'read_responses': 0, 'notifies': 0} 0

# %%
dataframe = pd.DataFrame()
for addr in devices:
    requests_dataframe = pd.DataFrame.from_dict([r.as_dict() for r in all_requests[addr]])
    dataframe = dataframe.append(requests_dataframe)
# dataframe.groupby(["conn_interval","mtu_size","data_size","request_type"]).max()
#dataframe.set_index(["conn_interval","mtu_size","data_size","request_type"],inplace=True)
dataframe['duration'] = dataframe['duration'].apply(lambda dt:dt.seconds * 1_000_000 + dt.microseconds)
dataframe.to_csv("HCI_Output.csv")
dataframe = dataframe.drop(["starting_time","ending_time"],axis=1)
dataframe
# Out:
#             request_type  duration  data_size  mtu_size  conn_interval  \
# 0      WRITE_COMMAND Req         0         20        23             36
# 1      WRITE_COMMAND Req     55996         20        23             36
# 2     WRITE_COMMAND Rcvd       670         20        23             36
# 3      WRITE_COMMAND Req         0         20        23             36
# 4      WRITE_COMMAND Req     61891         20        23             36
# ...                  ...       ...        ...       ...            ...
# 1289            READ Req   2816905        352        23             64
# 1290            READ Req   2664478        352        23             64
# 1291            READ Req   2757100        353        23             64
# 1292            READ Req   2683764        353        23             64
# 1293            READ Req   2764076        353        23             64
#
#                                                    data  read_requests  \
# 0                                                                    0
# 1                                                                    0
# 2              Data Size 20mnopqrstData Size 20mnopqrst              0
# 3                                                                    0
# 4                                                                    0
# ...                                                 ...            ...
# 1289  Data Size 352nopqrstuvwxyzabcdefghijklmnopqrst...             17
# 1290  Data Size 352nopqrstuvwxyzabcdefghijklmnopqrst...             17
# 1291  Data Size 353nopqrstuvwxyzabcdefghijklmnopqrst...             17
# 1292  Data Size 353nopqrstuvwxyzabcdefghijklmnopqrst...             17
# 1293  Data Size 353nopqrstuvwxyzabcdefghijklmnopqrst...             17
#
#       read_responses  notifies
# 0                  0         0
# 1                  0         0
# 2                  0         2
# 3                  0         0
# 4                  0         0
# ...              ...       ...
# 1289              17         0
# 1290              17         0
# 1291              17         0
# 1292              17         0
# 1293              17         0
#
# [1294 rows x 9 columns]

# %%
dfs =[(i,x) for i,x in dataframe.groupby("conn_interval")]
for interval,df in dfs:
    print(interval)
    step = int(interval*1.25*1_000)
    df_sizes = [(s,x) for s,x in df.groupby("mtu_size")]
    for size,df_size in df_sizes:
        xticks = range(0,step*int(df_size['duration'].max()/step + 2),step*4)
        subplot = df_size.drop(["mtu_size","conn_interval"],axis=1).set_index(["data_size"]).plot.barh(figsize=(15,5))
        subplot.xaxis.set_major_locator(matplotlib.ticker.MultipleLocator(step*4))
        subplot.xaxis.set_minor_locator(matplotlib.ticker.MultipleLocator(step))
        subplot.set_aspect("auto")
        subplot.set_ylabel("Data Size")
        subplot.set_xlabel("Time in Microseconds")
        subplot.set_title("Interval:%d ms - MTU:%d Byte"%(int(interval*1.25),int(size)))
# Out:
# 36
# 64
# 128
# 256
# /opt/conda/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:328: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# 512
# 1024

# %%
pd.set_option("display.max_rows", 200)
dataframe.groupby(["mtu_size","data_size","conn_interval","request_type"])["duration"].std()
# Out:
# mtu_size  data_size  conn_interval  request_type
# 23        20         36             READ Req                6383.406301
#                                     WRITE_COMMAND Rcvd       556.961698
#                                     WRITE_COMMAND Req      30774.759942
#                      64             READ Req               12962.577393
#                                     WRITE_COMMAND Rcvd       378.527410
#                                                               ...
# 256       512        64             WRITE_COMMAND Rcvd       995.808382
#                                     WRITE_COMMAND Req      74943.408545
#                      256            READ Req              177980.860485
#                                     WRITE_COMMAND Rcvd    184311.992893
#                                     WRITE_COMMAND Req     264141.993408
# Name: duration, Length: 319, dtype: float64

# %%
mtu = 23
interval = 256
data = 512
print(interval*1.25)
to_find = dataframe
to_find = to_find[to_find["mtu_size"]==mtu]
to_find = to_find[to_find["conn_interval"]==interval]
to_find = to_find[to_find["data_size"]==data]
to_find
# Out:
# 320.0
#             request_type  duration  data_size  mtu_size  conn_interval  \
# 591    WRITE_COMMAND Req         0        512        23            256
# 592    WRITE_COMMAND Req    485282        512        23            256
# 593   WRITE_COMMAND Rcvd    642225        512        23            256
# 594    WRITE_COMMAND Req         0        512        23            256
# 595    WRITE_COMMAND Req    534601        512        23            256
# 596   WRITE_COMMAND Rcvd    324158        512        23            256
# 597    WRITE_COMMAND Req         0        512        23            256
# 598    WRITE_COMMAND Req    607423        512        23            256
# 599   WRITE_COMMAND Rcvd    323712        512        23            256
# 1097            READ Req  15816487        512        23            256
# 1098            READ Req  15071916        512        23            256
# 1099            READ Req  15562739        512        23            256
#
#                                                    data  read_requests  \
# 591                                                                  0
# 592                                                                  0
# 593   Data Size 512nopqrstData Size 512nopqrstuvwxyz...              0
# 594                                                                  0
# 595                                                                  0
# 596   Data Size 512nopqrstData Size 512nopqrstuvwxyz...              0
# 597                                                                  0
# 598                                                                  0
# 599   Data Size 512nopqrstData Size 512nopqrstuvwxyz...              0
# 1097  Data Size 512nopqrstuvwxyzabcdefghijklmnopqrst...             24
# 1098  Data Size 512nopqrstuvwxyzabcdefghijklmnopqrst...             24
# 1099  Data Size 512nopqrstuvwxyzabcdefghijklmnopqrst...             24
#
#       read_responses  notifies
# 591                0         0
# 592                0         0
# 593                0        52
# 594                0         0
# 595                0         0
# 596                0        52
# 597                0         0
# 598                0         0
# 599                0        52
# 1097              24         0
# 1098              24         0
# 1099              24         0

# %%
all_requests
# Out:
# {'60:ef:3a': [<__main__.Request at 0x7f1bc74f0ac0>,
#   <__main__.Request at 0x7f1bc75a6c40>,
#   <__main__.Request at 0x7f1bc75ac490>,
#   <__main__.Request at 0x7f1bc7315580>,
#   <__main__.Request at 0x7f1bc73153a0>,
#   <__main__.Request at 0x7f1bc75a6dc0>,
#   <__main__.Request at 0x7f1bc75a6a00>,
#   <__main__.Request at 0x7f1bc75a69a0>,
#   <__main__.Request at 0x7f1bc75a6d30>,
#   <__main__.Request at 0x7f1bc744a0a0>,
#   <__main__.Request at 0x7f1bc744a700>,
#   <__main__.Request at 0x7f1bc744a820>,
#   <__main__.Request at 0x7f1bc744aee0>,
#   <__main__.Request at 0x7f1bc744adf0>,
#   <__main__.Request at 0x7f1bc744a760>,
#   <__main__.Request at 0x7f1bc744a2b0>,
#   <__main__.Request at 0x7f1bc744a5b0>,
#   <__main__.Request at 0x7f1bc744abb0>,
#   <__main__.Request at 0x7f1bc744a550>,
#   <__main__.Request at 0x7f1bc744abe0>,
#   <__main__.Request at 0x7f1bc744af10>,
#   <__main__.Request at 0x7f1bc744a520>,
#   <__main__.Request at 0x7f1bc744af70>,
#   <__main__.Request at 0x7f1bc744afd0>,
#   <__main__.Request at 0x7f1bc744adc0>,
#   <__main__.Request at 0x7f1bc745ad00>,
#   <__main__.Request at 0x7f1bc745ab50>,
#   <__main__.Request at 0x7f1bc745a3d0>,
#   <__main__.Request at 0x7f1bc745adc0>,
#   <__main__.Request at 0x7f1bc745a490>,
#   <__main__.Request at 0x7f1bc745a7f0>,
#   <__main__.Request at 0x7f1bc745abe0>,
#   <__main__.Request at 0x7f1bc745a910>,
#   <__main__.Request at 0x7f1bc745a760>,
#   <__main__.Request at 0x7f1bc745af40>,
#   <__main__.Request at 0x7f1bc745a370>,
#   <__main__.Request at 0x7f1bc745ae80>,
#   <__main__.Request at 0x7f1bc746fc10>,
#   <__main__.Request at 0x7f1bc746feb0>,
#   <__main__.Request at 0x7f1bc746fee0>,
#   <__main__.Request at 0x7f1bc746fa90>,
#   <__main__.Request at 0x7f1bc746f370>,
#   <__main__.Request at 0x7f1bc746f7f0>,
#   <__main__.Request at 0x7f1bc746fbe0>,
#   <__main__.Request at 0x7f1bc746f820>,
#   <__main__.Request at 0x7f1bc746f8b0>,
#   <__main__.Request at 0x7f1bc746ff40>,
#   <__main__.Request at 0x7f1bc746f6a0>,
#   <__main__.Request at 0x7f1bc746fe50>,
#   <__main__.Request at 0x7f1bc73ffc70>,
#   <__main__.Request at 0x7f1bc73ff550>,
#   <__main__.Request at 0x7f1bc73ff400>,
#   <__main__.Request at 0x7f1bc73ffd30>,
#   <__main__.Request at 0x7f1bc73ff370>,
#   <__main__.Request at 0x7f1bc73ff7f0>,
#   <__main__.Request at 0x7f1bc73ffb20>,
#   <__main__.Request at 0x7f1bc73ff820>,
#   <__main__.Request at 0x7f1bc73ffe20>,
#   <__main__.Request at 0x7f1bc73fff40>,
#   <__main__.Request at 0x7f1bc73ffe50>,
#   <__main__.Request at 0x7f1bc73ffdf0>,
#   <__main__.Request at 0x7f1bc7412c70>,
#   <__main__.Request at 0x7f1bc74124c0>,
#   <__main__.Request at 0x7f1bc7412370>,
#   <__main__.Request at 0x7f1bc7412d30>,
#   <__main__.Request at 0x7f1bc74122e0>,
#   <__main__.Request at 0x7f1bc7412f40>,
#   <__main__.Request at 0x7f1bc7412e20>,
#   <__main__.Request at 0x7f1bc7412e50>,
#   <__main__.Request at 0x7f1bc7412b20>,
#   <__main__.Request at 0x7f1bc7412790>,
#   <__main__.Request at 0x7f1bc7412df0>,
#   <__main__.Request at 0x7f1bc741f3a0>,
#   <__main__.Request at 0x7f1bc741fb20>,
#   <__main__.Request at 0x7f1bc741fca0>,
#   <__main__.Request at 0x7f1bc741ff40>,
#   <__main__.Request at 0x7f1bc741f2b0>,
#   <__main__.Request at 0x7f1bc741fee0>,
#   <__main__.Request at 0x7f1bc741f910>,
#   <__main__.Request at 0x7f1bc741f4f0>,
#   <__main__.Request at 0x7f1bc741f760>,
#   <__main__.Request at 0x7f1bc741f430>,
#   <__main__.Request at 0x7f1bc741fe50>,
#   <__main__.Request at 0x7f1bc7427490>,
#   <__main__.Request at 0x7f1bc74271c0>,
#   <__main__.Request at 0x7f1bc7427a60>,
#   <__main__.Request at 0x7f1bc7427730>,
#   <__main__.Request at 0x7f1bc7427ee0>,
#   <__main__.Request at 0x7f1bc7427700>,
#   <__main__.Request at 0x7f1bc7427b80>,
#   <__main__.Request at 0x7f1bc7427250>,
#   <__main__.Request at 0x7f1bc7427dc0>,
#   <__main__.Request at 0x7f1bc74275e0>,
#   <__main__.Request at 0x7f1bc7427520>,
#   <__main__.Request at 0x7f1bc7427e80>,
#   <__main__.Request at 0x7f1bc73bfee0>,
#   <__main__.Request at 0x7f1bc73bf2e0>,
#   <__main__.Request at 0x7f1bc73bfa60>,
#   <__main__.Request at 0x7f1bc73bf6d0>,
#   <__main__.Request at 0x7f1bc73bf520>,
#   <__main__.Request at 0x7f1bc73bf6a0>,
#   <__main__.Request at 0x7f1bc73bfa90>,
#   <__main__.Request at 0x7f1bc73bfaf0>,
#   <__main__.Request at 0x7f1bc73bfeb0>,
#   <__main__.Request at 0x7f1bc73bf670>,
#   <__main__.Request at 0x7f1bc73bf700>,
#   <__main__.Request at 0x7f1bc73bff70>,
#   <__main__.Request at 0x7f1bc73cbc40>,
#   <__main__.Request at 0x7f1bc73cb250>,
#   <__main__.Request at 0x7f1bc73cba60>,
#   <__main__.Request at 0x7f1bc73cb820>,
#   <__main__.Request at 0x7f1bc73cbf10>,
#   <__main__.Request at 0x7f1bc73cbe80>,
#   <__main__.Request at 0x7f1bc73cbac0>,
#   <__main__.Request at 0x7f1bc73cbc70>,
#   <__main__.Request at 0x7f1bc73cb6a0>,
#   <__main__.Request at 0x7f1bc73cb670>,
#   <__main__.Request at 0x7f1bc73cb850>,
#   <__main__.Request at 0x7f1bc73cbc10>,
#   <__main__.Request at 0x7f1bc73ddac0>,
#   <__main__.Request at 0x7f1bc73dd1f0>,
#   <__main__.Request at 0x7f1bc73dd9d0>,
#   <__main__.Request at 0x7f1bc73dda90>,
#   <__main__.Request at 0x7f1bc73ddf10>,
#   <__main__.Request at 0x7f1bc73dde80>,
#   <__main__.Request at 0x7f1bc73ddbb0>,
#   <__main__.Request at 0x7f1bc73dd520>,
#   <__main__.Request at 0x7f1bc73dd640>,
#   <__main__.Request at 0x7f1bc73dd610>,
#   <__main__.Request at 0x7f1bc73dda00>,
#   <__main__.Request at 0x7f1bc73ddd00>,
#   <__main__.Request at 0x7f1bc73ece80>,
#   <__main__.Request at 0x7f1bc73ec190>,
#   <__main__.Request at 0x7f1bc73eca30>,
#   <__main__.Request at 0x7f1bc73ec700>,
#   <__main__.Request at 0x7f1bc73ecfd0>,
#   <__main__.Request at 0x7f1bc73ec6d0>,
#   <__main__.Request at 0x7f1bc73ecb50>,
#   <__main__.Request at 0x7f1bc73ec970>,
#   <__main__.Request at 0x7f1bc73eceb0>,
#   <__main__.Request at 0x7f1bc73ec5b0>,
#   <__main__.Request at 0x7f1bc73ec550>,
#   <__main__.Request at 0x7f1bc73ecca0>,
#   <__main__.Request at 0x7f1bc72bcee0>,
#   <__main__.Request at 0x7f1bc72bc340>,
#   <__main__.Request at 0x7f1bc72bcac0>,
#   <__main__.Request at 0x7f1bc72bc820>,
#   <__main__.Request at 0x7f1bc72bcfd0>,
#   <__main__.Request at 0x7f1bc72bc7f0>,
#   <__main__.Request at 0x7f1bc72bcbe0>,
#   <__main__.Request at 0x7f1bc72bca00>,
#   <__main__.Request at 0x7f1bc72bc580>,
#   <__main__.Request at 0x7f1bc72bc6d0>,
#   <__main__.Request at 0x7f1bc72bc610>,
#   <__main__.Request at 0x7f1bc72bcca0>,
#   <__main__.Request at 0x7f1bc72cafd0>,
#   <__main__.Request at 0x7f1bc72ca340>,
#   <__main__.Request at 0x7f1bc72caac0>,
#   <__main__.Request at 0x7f1bc72ca640>,
#   <__main__.Request at 0x7f1bc72caee0>,
#   <__main__.Request at 0x7f1bc72ca7f0>,
#   <__main__.Request at 0x7f1bc72caaf0>,
#   <__main__.Request at 0x7f1bc72cab50>,
#   <__main__.Request at 0x7f1bc72caf40>,
#   <__main__.Request at 0x7f1bc72ca6d0>,
#   <__main__.Request at 0x7f1bc72ca2b0>,
#   <__main__.Request at 0x7f1bc72caca0>,
#   <__main__.Request at 0x7f1bc72ddc70>,
#   <__main__.Request at 0x7f1bc72dd2b0>,
#   <__main__.Request at 0x7f1bc72ddac0>,
#   <__main__.Request at 0x7f1bc72dd880>,
#   <__main__.Request at 0x7f1bc72ddfd0>,
#   <__main__.Request at 0x7f1bc72ddc40>,
#   <__main__.Request at 0x7f1bc72ddaf0>,
#   <__main__.Request at 0x7f1bc72ddca0>,
#   <__main__.Request at 0x7f1bc72dd700>,
#   <__main__.Request at 0x7f1bc72dd6d0>,
#   <__main__.Request at 0x7f1bc72dd8b0>,
#   <__main__.Request at 0x7f1bc72dde80>,
#   <__main__.Request at 0x7f1bc72ebdf0>,
#   <__main__.Request at 0x7f1bc72eb250>,
#   <__main__.Request at 0x7f1bc72eba30>,
#   <__main__.Request at 0x7f1bc72ebac0>,
#   <__main__.Request at 0x7f1bc72ebfd0>,
#   <__main__.Request at 0x7f1bc72eb670>,
#   <__main__.Request at 0x7f1bc72eba60>,
#   <__main__.Request at 0x7f1bc72ebee0>,
#   <__main__.Request at 0x7f1bc72ebe20>,
#   <__main__.Request at 0x7f1bc72eb640>,
#   <__main__.Request at 0x7f1bc72ebaf0>,
#   <__main__.Request at 0x7f1bc72eb940>,
#   <__main__.Request at 0x7f1bc723be80>,
#   <__main__.Request at 0x7f1bc723b340>,
#   <__main__.Request at 0x7f1bc723bac0>,
#   <__main__.Request at 0x7f1bc723b820>,
#   <__main__.Request at 0x7f1bc723bfd0>,
#   <__main__.Request at 0x7f1bc723b7f0>,
#   <__main__.Request at 0x7f1bc723bbe0>,
#   <__main__.Request at 0x7f1bc723ba00>,
#   <__main__.Request at 0x7f1bc723beb0>,
#   <__main__.Request at 0x7f1bc723b6d0>,
#   <__main__.Request at 0x7f1bc723b610>,
#   <__main__.Request at 0x7f1bc723bca0>,
#   <__main__.Request at 0x7f1bc724ae80>,
#   <__main__.Request at 0x7f1bc724a340>,
#   <__main__.Request at 0x7f1bc724aac0>,
#   <__main__.Request at 0x7f1bc724a820>,
#   <__main__.Request at 0x7f1bc724afd0>,
#   <__main__.Request at 0x7f1bc724a7f0>,
#   <__main__.Request at 0x7f1bc724abe0>,
#   <__main__.Request at 0x7f1bc724aa00>,
#   <__main__.Request at 0x7f1bc724aeb0>,
#   <__main__.Request at 0x7f1bc724a6d0>,
#   <__main__.Request at 0x7f1bc724a610>,
#   <__main__.Request at 0x7f1bc724aca0>,
#   <__main__.Request at 0x7f1bc7258640>,
#   <__main__.Request at 0x7f1bc7258f40>,
#   <__main__.Request at 0x7f1bc72587f0>,
#   <__main__.Request at 0x7f1bc7258d60>,
#   <__main__.Request at 0x7f1bc72586d0>,
#   <__main__.Request at 0x7f1bc7258ee0>,
#   <__main__.Request at 0x7f1bc7258f70>,
#   <__main__.Request at 0x7f1bc7258be0>,
#   <__main__.Request at 0x7f1bc7258ac0>,
#   <__main__.Request at 0x7f1bc7258340>,
#   <__main__.Request at 0x7f1bc7268d60>,
#   <__main__.Request at 0x7f1bc72687c0>,
#   <__main__.Request at 0x7f1bc72680a0>,
#   <__main__.Request at 0x7f1bc7268bb0>,
#   <__main__.Request at 0x7f1bc72687f0>,
#   <__main__.Request at 0x7f1bc7268820>,
#   <__main__.Request at 0x7f1bc7268100>,
#   <__main__.Request at 0x7f1bc7268460>,
#   <__main__.Request at 0x7f1bc7268790>,
#   <__main__.Request at 0x7f1bc7268fd0>,
#   <__main__.Request at 0x7f1bc7268ee0>,
#   <__main__.Request at 0x7f1bc7268b80>,
#   <__main__.Request at 0x7f1bc7268a30>,
#   <__main__.Request at 0x7f1bc71f6ca0>,
#   <__main__.Request at 0x7f1bc71f6df0>,
#   <__main__.Request at 0x7f1bc71f6ac0>,
#   <__main__.Request at 0x7f1bc71f6cd0>,
#   <__main__.Request at 0x7f1bc71f6310>,
#   <__main__.Request at 0x7f1bc71f6790>,
#   <__main__.Request at 0x7f1bc71f6b80>,
#   <__main__.Request at 0x7f1bc71f68b0>,
#   <__main__.Request at 0x7f1bc71f68e0>,
#   <__main__.Request at 0x7f1bc71f6eb0>,
#   <__main__.Request at 0x7f1bc71f66d0>,
#   <__main__.Request at 0x7f1bc71f6fd0>,
#   <__main__.Request at 0x7f1bc7203ca0>,
#   <__main__.Request at 0x7f1bc7203df0>,
#   <__main__.Request at 0x7f1bc7203ac0>,
#   <__main__.Request at 0x7f1bc7203cd0>,
#   <__main__.Request at 0x7f1bc7203430>,
#   <__main__.Request at 0x7f1bc7203790>,
#   <__main__.Request at 0x7f1bc7203b80>,
#   <__main__.Request at 0x7f1bc72038b0>,
#   <__main__.Request at 0x7f1bc72038e0>,
#   <__main__.Request at 0x7f1bc7203eb0>,
#   <__main__.Request at 0x7f1bc72036d0>,
#   <__main__.Request at 0x7f1bc7203fd0>,
#   <__main__.Request at 0x7f1bc7212ca0>,
#   <__main__.Request at 0x7f1bc7212df0>,
#   <__main__.Request at 0x7f1bc7212ac0>,
#   <__main__.Request at 0x7f1bc7212cd0>,
#   <__main__.Request at 0x7f1bc7212430>,
#   <__main__.Request at 0x7f1bc7212790>,
#   <__main__.Request at 0x7f1bc7212b80>,
#   <__main__.Request at 0x7f1bc72128b0>,
#   <__main__.Request at 0x7f1bc72128e0>,
#   <__main__.Request at 0x7f1bc7212eb0>,
#   <__main__.Request at 0x7f1bc72126d0>,
#   <__main__.Request at 0x7f1bc7212fd0>,
#   <__main__.Request at 0x7f1bc7221ca0>,
#   <__main__.Request at 0x7f1bc7221fa0>,
#   <__main__.Request at 0x7f1bc72211f0>,
#   <__main__.Request at 0x7f1bc7221af0>,
#   <__main__.Request at 0x7f1bc7221430>,
#   <__main__.Request at 0x7f1bc7221790>,
#   <__main__.Request at 0x7f1bc7221b80>,
#   <__main__.Request at 0x7f1bc72218b0>,
#   <__main__.Request at 0x7f1bc7221700>,
#   <__main__.Request at 0x7f1bc7221eb0>,
#   <__main__.Request at 0x7f1bc72212b0>,
#   <__main__.Request at 0x7f1bc7221ee0>,
#   <__main__.Request at 0x7f1bc722fbb0>,
#   <__main__.Request at 0x7f1bc722fdf0>,
#   <__main__.Request at 0x7f1bc722fc10>,
#   <__main__.Request at 0x7f1bc722fbe0>,
#   <__main__.Request at 0x7f1bc722f310>,
#   <__main__.Request at 0x7f1bc722f790>,
#   <__main__.Request at 0x7f1bc722fb80>,
#   <__main__.Request at 0x7f1bc722f7c0>,
#   <__main__.Request at 0x7f1bc722f7f0>,
#   <__main__.Request at 0x7f1bc722feb0>,
#   <__main__.Request at 0x7f1bc722f820>,
#   <__main__.Request at 0x7f1bc722ffd0>,
#   <__main__.Request at 0x7f1bc71c1ca0>,
#   <__main__.Request at 0x7f1bc71c1fa0>,
#   <__main__.Request at 0x7f1bc71c1220>,
#   <__main__.Request at 0x7f1bc71c1af0>,
#   <__main__.Request at 0x7f1bc71c1430>,
#   <__main__.Request at 0x7f1bc71c1790>,
#   <__main__.Request at 0x7f1bc71c1b80>,
#   <__main__.Request at 0x7f1bc71c18b0>,
#   <__main__.Request at 0x7f1bc71c18e0>,
#   <__main__.Request at 0x7f1bc71c1eb0>,
#   <__main__.Request at 0x7f1bc71c16d0>,
#   <__main__.Request at 0x7f1bc71c1ee0>,
#   <__main__.Request at 0x7f1bc71cfbb0>,
#   <__main__.Request at 0x7f1bc71cfc40>,
#   <__main__.Request at 0x7f1bc71cfa30>,
#   <__main__.Request at 0x7f1bc71cfd60>,
#   <__main__.Request at 0x7f1bc71cf310>,
#   <__main__.Request at 0x7f1bc71cf790>,
#   <__main__.Request at 0x7f1bc71cfb80>,
#   <__main__.Request at 0x7f1bc71cf7c0>,
#   <__main__.Request at 0x7f1bc71cf850>,
#   <__main__.Request at 0x7f1bc71cfee0>,
#   <__main__.Request at 0x7f1bc71cf640>,
#   <__main__.Request at 0x7f1bc71cffd0>,
#   <__main__.Request at 0x7f1bc71ddca0>,
#   <__main__.Request at 0x7f1bc71dd4f0>,
#   <__main__.Request at 0x7f1bc71dd3a0>,
#   <__main__.Request at 0x7f1bc71ddd60>,
#   <__main__.Request at 0x7f1bc71dd310>,
#   <__main__.Request at 0x7f1bc71dd790>,
#   <__main__.Request at 0x7f1bc71ddb50>,
#   <__main__.Request at 0x7f1bc71dd7c0>,
#   <__main__.Request at 0x7f1bc71dda60>,
#   <__main__.Request at 0x7f1bc71ddee0>,
#   <__main__.Request at 0x7f1bc71dda90>,
#   <__main__.Request at 0x7f1bc71ddfd0>,
#   <__main__.Request at 0x7f1bc71edca0>,
#   <__main__.Request at 0x7f1bc71ed460>,
#   <__main__.Request at 0x7f1bc71ed700>,
#   <__main__.Request at 0x7f1bc71edd60>,
#   <__main__.Request at 0x7f1bc71ed280>,
#   <__main__.Request at 0x7f1bc71ed6d0>,
#   <__main__.Request at 0x7f1bc71edb50>,
#   <__main__.Request at 0x7f1bc71ed820>,
#   <__main__.Request at 0x7f1bc71ed310>,
#   <__main__.Request at 0x7f1bc71edee0>,
#   <__main__.Request at 0x7f1bc71eda00>,
#   <__main__.Request at 0x7f1bc71edfd0>,
#   <__main__.Request at 0x7f1bc717eca0>,
#   <__main__.Request at 0x7f1bc717efa0>,
#   <__main__.Request at 0x7f1bc717eac0>,
#   <__main__.Request at 0x7f1bc717ecd0>,
#   <__main__.Request at 0x7f1bc717e430>,
#   <__main__.Request at 0x7f1bc717e790>,
#   <__main__.Request at 0x7f1bc717eb80>,
#   <__main__.Request at 0x7f1bc717e8b0>,
#   <__main__.Request at 0x7f1bc717e8e0>,
#   <__main__.Request at 0x7f1bc717eeb0>,
#   <__main__.Request at 0x7f1bc717e6d0>,
#   <__main__.Request at 0x7f1bc717eee0>,
#   <__main__.Request at 0x7f1bc718abb0>,
#   <__main__.Request at 0x7f1bc718abe0>,
#   <__main__.Request at 0x7f1bc718ac10>,
#   <__main__.Request at 0x7f1bc718ad60>,
#   <__main__.Request at 0x7f1bc718a430>,
#   <__main__.Request at 0x7f1bc718ab80>,
#   <__main__.Request at 0x7f1bc718a700>,
#   <__main__.Request at 0x7f1bc718a790>,
#   <__main__.Request at 0x7f1bc718a8b0>,
#   <__main__.Request at 0x7f1bc718aee0>,
#   <__main__.Request at 0x7f1bc718afd0>,
#   <__main__.Request at 0x7f1bc7198d90>,
#   <__main__.Request at 0x7f1bc71987f0>,
#   <__main__.Request at 0x7f1bc7198400>,
#   <__main__.Request at 0x7f1bc7198be0>,
#   <__main__.Request at 0x7f1bc7198970>,
#   <__main__.Request at 0x7f1bc71989a0>,
#   <__main__.Request at 0x7f1bc71984f0>,
#   <__main__.Request at 0x7f1bc7198310>,
#   <__main__.Request at 0x7f1bc7198580>,
#   <__main__.Request at 0x7f1bc7198e50>,
#   <__main__.Request at 0x7f1bc7198f10>,
#   <__main__.Request at 0x7f1bc7198bb0>,
#   <__main__.Request at 0x7f1bc7198a60>,
#   <__main__.Request at 0x7f1bc71a8b80>,
#   <__main__.Request at 0x7f1bc71a8fa0>,
#   <__main__.Request at 0x7f1bc71a8fd0>,
#   <__main__.Request at 0x7f1bc71a8d30>,
#   <__main__.Request at 0x7f1bc71a8340>,
#   <__main__.Request at 0x7f1bc71a8730>,
#   <__main__.Request at 0x7f1bc71a8d00>,
#   <__main__.Request at 0x7f1bc71a8760>,
#   <__main__.Request at 0x7f1bc71a8bb0>,
#   <__main__.Request at 0x7f1bc71a8eb0>,
#   <__main__.Request at 0x7f1bc71a8be0>,
#   <__main__.Request at 0x7f1bc71a8dc0>,
#   <__main__.Request at 0x7f1bc7136c40>,
#   <__main__.Request at 0x7f1bc7136e20>,
#   <__main__.Request at 0x7f1bc7136a60>,
#   <__main__.Request at 0x7f1bc7136c70>,
#   <__main__.Request at 0x7f1bc71362b0>,
#   <__main__.Request at 0x7f1bc7136670>,
#   <__main__.Request at 0x7f1bc7136b20>,
#   <__main__.Request at 0x7f1bc71367c0>,
#   <__main__.Request at 0x7f1bc7136340>,
#   <__main__.Request at 0x7f1bc7136ee0>,
#   <__main__.Request at 0x7f1bc7136d00>,
#   <__main__.Request at 0x7f1bc7258220>,
#   <__main__.Request at 0x7f1bc7136e50>,
#   <__main__.Request at 0x7f1bc7144cd0>,
#   <__main__.Request at 0x7f1bc7144700>,
#   <__main__.Request at 0x7f1bc7144af0>,
#   <__main__.Request at 0x7f1bc7144910>,
#   <__main__.Request at 0x7f1bc71448e0>,
#   <__main__.Request at 0x7f1bc7144460>,
#   <__main__.Request at 0x7f1bc7144e20>,
#   <__main__.Request at 0x7f1bc7144e50>,
#   <__main__.Request at 0x7f1bc71447c0>,
#   <__main__.Request at 0x7f1bc7144bb0>,
#   <__main__.Request at 0x7f1bc7144d00>,
#   <__main__.Request at 0x7f1bc7144f10>,
#   <__main__.Request at 0x7f1bc71548b0>,
#   <__main__.Request at 0x7f1bc7154b80>,
#   <__main__.Request at 0x7f1bc7154ca0>,
#   <__main__.Request at 0x7f1bc7154d60>,
#   <__main__.Request at 0x7f1bc71544c0>,
#   <__main__.Request at 0x7f1bc7154790>,
#   <__main__.Request at 0x7f1bc7154430>,
#   <__main__.Request at 0x7f1bc7154fd0>,
#   <__main__.Request at 0x7f1bc7154ee0>,
#   <__main__.Request at 0x7f1bc7154700>,
#   <__main__.Request at 0x7f1bc7154310>,
#   <__main__.Request at 0x7f1bc7161bb0>,
#   <__main__.Request at 0x7f1bc7161d30>,
#   <__main__.Request at 0x7f1bc7161d60>,
#   <__main__.Request at 0x7f1bc7161a30>,
#   <__main__.Request at 0x7f1bc7161310>,
#   <__main__.Request at 0x7f1bc7161790>,
#   <__main__.Request at 0x7f1bc71617f0>,
#   <__main__.Request at 0x7f1bc7161820>,
#   <__main__.Request at 0x7f1bc7161b80>,
#   <__main__.Request at 0x7f1bc71617c0>,
#   <__main__.Request at 0x7f1bc7161fd0>,
#   <__main__.Request at 0x7f1bc71713a0>,
#   <__main__.Request at 0x7f1bc7171640>,
#   <__main__.Request at 0x7f1bc71717c0>,
#   <__main__.Request at 0x7f1bc7171c70>,
#   <__main__.Request at 0x7f1bc7171af0>,
#   <__main__.Request at 0x7f1bc7171bb0>,
#   <__main__.Request at 0x7f1bc7171940>,
#   <__main__.Request at 0x7f1bc7171a00>,
#   <__main__.Request at 0x7f1bc7171790>,
#   <__main__.Request at 0x7f1bc7171fd0>,
#   <__main__.Request at 0x7f1bc7171d60>,
#   <__main__.Request at 0x7f1bc7171b20>,
#   <__main__.Request at 0x7f1bc7171e80>,
#   <__main__.Request at 0x7f1bc70fdca0>,
#   <__main__.Request at 0x7f1bc70fde20>,
#   <__main__.Request at 0x7f1bc70fdb50>,
#   <__main__.Request at 0x7f1bc70fdd60>,
#   <__main__.Request at 0x7f1bc70fd4c0>,
#   <__main__.Request at 0x7f1bc70fd820>,
#   <__main__.Request at 0x7f1bc70fdc10>,
#   <__main__.Request at 0x7f1bc70fd940>,
#   <__main__.Request at 0x7f1bc70fd970>,
#   <__main__.Request at 0x7f1bc70fdfd0>,
#   <__main__.Request at 0x7f1bc70fd760>,
#   <__main__.Request at 0x7f1bc70fdd30>,
#   <__main__.Request at 0x7f1bc710fca0>,
#   <__main__.Request at 0x7f1bc710fe20>,
#   <__main__.Request at 0x7f1bc710fb50>,
#   <__main__.Request at 0x7f1bc710fd60>,
#   <__main__.Request at 0x7f1bc710f4c0>,
#   <__main__.Request at 0x7f1bc710f820>,
#   <__main__.Request at 0x7f1bc710fc10>,
#   <__main__.Request at 0x7f1bc710f940>,
#   <__main__.Request at 0x7f1bc710f970>,
#   <__main__.Request at 0x7f1bc710ffd0>,
#   <__main__.Request at 0x7f1bc710f760>,
#   <__main__.Request at 0x7f1bc710fd30>,
#   <__main__.Request at 0x7f1bc711dca0>,
#   <__main__.Request at 0x7f1bc711db80>,
#   <__main__.Request at 0x7f1bc711d2e0>,
#   <__main__.Request at 0x7f1bc711de80>,
#   <__main__.Request at 0x7f1bc711d4c0>,
#   <__main__.Request at 0x7f1bc711d820>,
#   <__main__.Request at 0x7f1bc711dc10>,
#   <__main__.Request at 0x7f1bc711d940>,
#   <__main__.Request at 0x7f1bc711d790>,
#   <__main__.Request at 0x7f1bc711d430>,
#   <__main__.Request at 0x7f1bc711d340>,
#   <__main__.Request at 0x7f1bc711dfd0>,
#   <__main__.Request at 0x7f1bc712e490>,
#   <__main__.Request at 0x7f1bc712ec70>,
#   <__main__.Request at 0x7f1bc712eca0>,
#   <__main__.Request at 0x7f1bc712ee80>,
#   <__main__.Request at 0x7f1bc712e3a0>,
#   <__main__.Request at 0x7f1bc712e820>,
#   <__main__.Request at 0x7f1bc712ec10>,
#   <__main__.Request at 0x7f1bc712e850>,
#   <__main__.Request at 0x7f1bc712e880>,
#   <__main__.Request at 0x7f1bc712e430>,
#   <__main__.Request at 0x7f1bc712e8b0>,
#   <__main__.Request at 0x7f1bc712efd0>,
#   <__main__.Request at 0x7f1bc70bbca0>,
#   <__main__.Request at 0x7f1bc70bbe20>,
#   <__main__.Request at 0x7f1bc70bbb50>,
#   <__main__.Request at 0x7f1bc70bbd60>,
#   <__main__.Request at 0x7f1bc70bb3a0>,
#   <__main__.Request at 0x7f1bc70bb820>,
#   <__main__.Request at 0x7f1bc70bbc10>,
#   <__main__.Request at 0x7f1bc70bb850>,
#   <__main__.Request at 0x7f1bc70bb9d0>,
#   <__main__.Request at 0x7f1bc70bbfd0>,
#   <__main__.Request at 0x7f1bc70bba00>,
#   <__main__.Request at 0x7f1bc70bbd30>,
#   <__main__.Request at 0x7f1bc70cbca0>,
#   <__main__.Request at 0x7f1bc70cbe20>,
#   <__main__.Request at 0x7f1bc70cbb50>,
#   <__main__.Request at 0x7f1bc70cbd60>,
#   <__main__.Request at 0x7f1bc70cb4c0>,
#   <__main__.Request at 0x7f1bc70cb820>,
#   <__main__.Request at 0x7f1bc70cbc10>,
#   <__main__.Request at 0x7f1bc70cb940>,
#   <__main__.Request at 0x7f1bc70cb970>,
#   <__main__.Request at 0x7f1bc7095fd0>,
#   <__main__.Request at 0x7f1bc70a44f0>,
#   <__main__.Request at 0x7f1bc70a4ee0>,
#   <__main__.Request at 0x7f1bc70a4f10>,
#   <__main__.Request at 0x7f1bc70a4d90>,
#   <__main__.Request at 0x7f1bc70a43a0>,
#   <__main__.Request at 0x7f1bc70a4820>,
#   <__main__.Request at 0x7f1bc70a4c10>,
#   <__main__.Request at 0x7f1bc70a4850>,
#   <__main__.Request at 0x7f1bc70a4af0>,
#   <__main__.Request at 0x7f1bc70a4430>,
#   <__main__.Request at 0x7f1bc70a4b20>,
#   <__main__.Request at 0x7f1bc70a4fd0>,
#   <__main__.Request at 0x7f1bc70b2c10>,
#   <__main__.Request at 0x7f1bc70b2580>,
#   <__main__.Request at 0x7f1bc70b2430>,
#   <__main__.Request at 0x7f1bc70b2df0>,
#   <__main__.Request at 0x7f1bc70b23a0>,
#   <__main__.Request at 0x7f1bc70b2790>,
#   <__main__.Request at 0x7f1bc70b2b50>,
#   <__main__.Request at 0x7f1bc70b27c0>,
#   <__main__.Request at 0x7f1bc70b2e50>,
#   <__main__.Request at 0x7f1bc70b2cd0>,
#   <__main__.Request at 0x7f1bc70b2e80>,
#   <__main__.Request at 0x7f1bc70b2fd0>,
#   <__main__.Request at 0x7f1bc70413d0>,
#   <__main__.Request at 0x7f1bc7041af0>,
#   <__main__.Request at 0x7f1bc7041bb0>,
#   <__main__.Request at 0x7f1bc7041d30>,
#   <__main__.Request at 0x7f1bc7041460>,
#   <__main__.Request at 0x7f1bc7041520>,
#   <__main__.Request at 0x7f1bc7041b80>,
#   <__main__.Request at 0x7f1bc7041790>,
#   <__main__.Request at 0x7f1bc70418e0>,
#   <__main__.Request at 0x7f1bc70417c0>,
#   <__main__.Request at 0x7f1bc7051460>,
#   <__main__.Request at 0x7f1bc7051c70>,
#   <__main__.Request at 0x7f1bc70513d0>,
#   <__main__.Request at 0x7f1bc7051fd0>,
#   <__main__.Request at 0x7f1bc7051880>,
#   <__main__.Request at 0x7f1bc7051910>,
#   <__main__.Request at 0x7f1bc7051520>,
#   <__main__.Request at 0x7f1bc7051d00>,
#   <__main__.Request at 0x7f1bc7051fa0>,
#   <__main__.Request at 0x7f1bc70514c0>,
#   <__main__.Request at 0x7f1bc7051670>,
#   <__main__.Request at 0x7f1bc7051640>,
#   <__main__.Request at 0x7f1bc7051f70>,
#   <__main__.Request at 0x7f1bc705fe80>,
#   <__main__.Request at 0x7f1bc705f9d0>,
#   <__main__.Request at 0x7f1bc705f9a0>,
#   <__main__.Request at 0x7f1bc705f5b0>,
#   <__main__.Request at 0x7f1bc705fdc0>,
#   <__main__.Request at 0x7f1bc705fa00>,
#   <__main__.Request at 0x7f1bc705fdf0>,
#   <__main__.Request at 0x7f1bc705fbe0>,
#   <__main__.Request at 0x7f1bc705f400>,
#   <__main__.Request at 0x7f1bc705fd90>,
#   <__main__.Request at 0x7f1bc705f580>,
#   <__main__.Request at 0x7f1bc705f970>,
#   <__main__.Request at 0x7f1bc706efd0>,
#   <__main__.Request at 0x7f1bc706eb20>,
#   <__main__.Request at 0x7f1bc706e9a0>,
#   <__main__.Request at 0x7f1bc706e7f0>,
#   <__main__.Request at 0x7f1bc706ef10>,
#   <__main__.Request at 0x7f1bc706eb50>,
#   <__main__.Request at 0x7f1bc706ef40>,
#   <__main__.Request at 0x7f1bc706eaf0>,
#   <__main__.Request at 0x7f1bc706e580>,
#   <__main__.Request at 0x7f1bc706ed90>,
#   <__main__.Request at 0x7f1bc706e520>,
#   <__main__.Request at 0x7f1bc706e970>,
#   <__main__.Request at 0x7f1bc6ffcaf0>,
#   <__main__.Request at 0x7f1bc6ffcd60>,
#   <__main__.Request at 0x7f1bc6ffc910>,
#   <__main__.Request at 0x7f1bc6ffc9d0>,
#   <__main__.Request at 0x7f1bc6ffc490>,
#   <__main__.Request at 0x7f1bc6ffcd90>,
#   <__main__.Request at 0x7f1bc6ffc520>,
#   <__main__.Request at 0x7f1bc6ffcc10>,
#   <__main__.Request at 0x7f1bc6ffc4f0>,
#   <__main__.Request at 0x7f1bc6ffce80>,
#   <__main__.Request at 0x7f1bc6ffccd0>,
#   <__main__.Request at 0x7f1bc6ffc8e0>,
#   <__main__.Request at 0x7f1bc7009df0>,
#   <__main__.Request at 0x7f1bc7009ee0>,
#   <__main__.Request at 0x7f1bc7009970>,
#   <__main__.Request at 0x7f1bc7009850>,
#   <__main__.Request at 0x7f1bc7009e20>,
#   <__main__.Request at 0x7f1bc7009e80>,
#   <__main__.Request at 0x7f1bc7009c10>,
#   <__main__.Request at 0x7f1bc7009cd0>,
#   <__main__.Request at 0x7f1bc70094f0>,
#   <__main__.Request at 0x7f1bc7009820>,
#   <__main__.Request at 0x7f1bc7009490>,
#   <__main__.Request at 0x7f1bc7009b50>,
#   <__main__.Request at 0x7f1bc701be80>,
#   <__main__.Request at 0x7f1bc701bac0>,
#   <__main__.Request at 0x7f1bc701ba90>,
#   <__main__.Request at 0x7f1bc701b4c0>,
#   <__main__.Request at 0x7f1bc701beb0>,
#   <__main__.Request at 0x7f1bc701b8b0>,
#   <__main__.Request at 0x7f1bc701bca0>,
#   <__main__.Request at 0x7f1bc701bd60>,
#   <__main__.Request at 0x7f1bc701b580>,
#   <__main__.Request at 0x7f1bc701b970>,
#   <__main__.Request at 0x7f1bc701b520>,
#   <__main__.Request at 0x7f1bc701bbe0>,
#   <__main__.Request at 0x7f1bc7029d90>,
#   <__main__.Request at 0x7f1bc70298e0>,
#   <__main__.Request at 0x7f1bc7029a90>,
#   <__main__.Request at 0x7f1bc70295b0>,
#   <__main__.Request at 0x7f1bc7029cd0>,
#   <__main__.Request at 0x7f1bc7029430>,
#   <__main__.Request at 0x7f1bc7029550>,
#   <__main__.Request at 0x7f1bc7029be0>,
#   <__main__.Request at 0x7f1bc7029580>,
#   <__main__.Request at 0x7f1bc7029e80>,
#   <__main__.Request at 0x7f1bc7029520>,
#   <__main__.Request at 0x7f1bc7029970>,
#   <__main__.Request at 0x7f1bc6fbafd0>,
#   <__main__.Request at 0x7f1bc6fba9d0>,
#   <__main__.Request at 0x7f1bc6fba9a0>,
#   <__main__.Request at 0x7f1bc6fba6a0>,
#   <__main__.Request at 0x7f1bc6fbaf10>,
#   <__main__.Request at 0x7f1bc6fbaa00>,
#   <__main__.Request at 0x7f1bc6fbaf40>,
#   <__main__.Request at 0x7f1bc6fbabe0>,
#   <__main__.Request at 0x7f1bc6fba580>,
#   <__main__.Request at 0x7f1bc6fbad90>,
#   <__main__.Request at 0x7f1bc6fba520>,
#   <__main__.Request at 0x7f1bc6fba970>,
#   <__main__.Request at 0x7f1bc6fc7af0>,
#   <__main__.Request at 0x7f1bc6fc7d60>,
#   <__main__.Request at 0x7f1bc6fc79a0>,
#   <__main__.Request at 0x7f1bc6fc77f0>,
#   <__main__.Request at 0x7f1bc6fc7520>,
#   <__main__.Request at 0x7f1bc6fc7d90>,
#   <__main__.Request at 0x7f1bc6fc75b0>,
#   <__main__.Request at 0x7f1bc6fc7c10>,
#   <__main__.Request at 0x7f1bc6fc7580>,
#   <__main__.Request at 0x7f1bc6fc7e80>,
#   <__main__.Request at 0x7f1bc6fc7cd0>,
#   <__main__.Request at 0x7f1bc6fc7970>,
#   <__main__.Request at 0x7f1bc6fd7e80>,
#   <__main__.Request at 0x7f1bc6fd7ac0>,
#   <__main__.Request at 0x7f1bc6fd7a90>,
#   <__main__.Request at 0x7f1bc6fd7430>,
#   <__main__.Request at 0x7f1bc6fd7eb0>,
#   <__main__.Request at 0x7f1bc6fd78b0>,
#   <__main__.Request at 0x7f1bc6fd7ca0>,
#   <__main__.Request at 0x7f1bc6fd7d60>,
#   <__main__.Request at 0x7f1bc6fd74f0>,
#   <__main__.Request at 0x7f1bc6fd7970>,
#   <__main__.Request at 0x7f1bc6fd7490>,
#   <__main__.Request at 0x7f1bc6fd7be0>,
#   <__main__.Request at 0x7f1bc6fe4e80>,
#   <__main__.Request at 0x7f1bc6fe4ac0>,
#   <__main__.Request at 0x7f1bc6fe4a90>,
#   <__main__.Request at 0x7f1bc6fe44c0>,
#   <__main__.Request at 0x7f1bc6fe4eb0>,
#   <__main__.Request at 0x7f1bc6fe48b0>,
#   <__main__.Request at 0x7f1bc6fe4ca0>,
#   <__main__.Request at 0x7f1bc6fe4d60>,
#   <__main__.Request at 0x7f1bc6fe4580>,
#   <__main__.Request at 0x7f1bc6fe4970>,
#   <__main__.Request at 0x7f1bc6fe4520>,
#   <__main__.Request at 0x7f1bc6fe4be0>,
#   <__main__.Request at 0x7f1bc6ff3d90>,
#   <__main__.Request at 0x7f1bc6ff38e0>,
#   <__main__.Request at 0x7f1bc6ff3a90>,
#   <__main__.Request at 0x7f1bc6ff34c0>,
#   <__main__.Request at 0x7f1bc6ff3cd0>,
#   <__main__.Request at 0x7f1bc6ff3430>,
#   <__main__.Request at 0x7f1bc6ff36d0>,
#   <__main__.Request at 0x7f1bc6ff3be0>,
#   <__main__.Request at 0x7f1bc6ff3580>,
#   <__main__.Request at 0x7f1bc6ff3e80>,
#   <__main__.Request at 0x7f1bc6ff3520>,
#   <__main__.Request at 0x7f1bc6ff3970>,
#   <__main__.Request at 0x7f1bc6f82e80>,
#   <__main__.Request at 0x7f1bc6f829d0>,
#   <__main__.Request at 0x7f1bc6f829a0>,
#   <__main__.Request at 0x7f1bc6f826a0>,
#   <__main__.Request at 0x7f1bc6f82dc0>,
#   <__main__.Request at 0x7f1bc6f82a00>,
#   <__main__.Request at 0x7f1bc6f82df0>,
#   <__main__.Request at 0x7f1bc6f82be0>,
#   <__main__.Request at 0x7f1bc6f82580>,
#   <__main__.Request at 0x7f1bc6f82d90>,
#   <__main__.Request at 0x7f1bc6f82520>,
#   <__main__.Request at 0x7f1bc6f82970>,
#   <__main__.Request at 0x7f1bc6f91d90>,
#   <__main__.Request at 0x7f1bc6f91b20>,
#   <__main__.Request at 0x7f1bc6f919a0>,
#   <__main__.Request at 0x7f1bc6f917f0>,
#   <__main__.Request at 0x7f1bc6f91f10>,
#   <__main__.Request at 0x7f1bc6f91b50>,
#   <__main__.Request at 0x7f1bc6f91f40>,
#   <__main__.Request at 0x7f1bc6f91d60>,
#   <__main__.Request at 0x7f1bc6f91580>,
#   <__main__.Request at 0x7f1bc6f91970>,
#   <__main__.Request at 0x7f1bc6f91520>,
#   <__main__.Request at 0x7f1bc6f91af0>,
#   <__main__.Request at 0x7f1bc6f9fe80>,
#   <__main__.Request at 0x7f1bc6f9fac0>,
#   <__main__.Request at 0x7f1bc6f9fa90>,
#   <__main__.Request at 0x7f1bc6f9f4c0>,
#   <__main__.Request at 0x7f1bc6f9feb0>,
#   <__main__.Request at 0x7f1bc6f9f8b0>,
#   <__main__.Request at 0x7f1bc6f9fca0>,
#   <__main__.Request at 0x7f1bc6f9fd60>,
#   <__main__.Request at 0x7f1bc6f9f580>,
#   <__main__.Request at 0x7f1bc6f9f970>,
#   <__main__.Request at 0x7f1bc6f9f520>,
#   <__main__.Request at 0x7f1bc6f9fbe0>,
#   <__main__.Request at 0x7f1bc6face80>,
#   <__main__.Request at 0x7f1bc6facac0>,
#   <__main__.Request at 0x7f1bc6faca90>,
#   <__main__.Request at 0x7f1bc6fac4c0>,
#   <__main__.Request at 0x7f1bc6faceb0>,
#   <__main__.Request at 0x7f1bc6fac8b0>,
#   <__main__.Request at 0x7f1bc6facca0>,
#   <__main__.Request at 0x7f1bc6facd60>,
#   <__main__.Request at 0x7f1bc6fac580>,
#   <__main__.Request at 0x7f1bc6fac970>,
#   <__main__.Request at 0x7f1bc6fac520>,
#   <__main__.Request at 0x7f1bc6facbe0>,
#   <__main__.Request at 0x7f1bc6f3ed30>,
#   <__main__.Request at 0x7f1bc6f3eac0>,
#   <__main__.Request at 0x7f1bc7171310>,
#   <__main__.Request at 0x7f1bc75a6820>,
#   <__main__.Request at 0x7f1bc7171b80>,
#   <__main__.Request at 0x7f1bc718a310>,
#   <__main__.Request at 0x7f1bc6f3e970>,
#   <__main__.Request at 0x7f1bc6f3e580>,
#   <__main__.Request at 0x7f1bc6f3ea90>,
#   <__main__.Request at 0x7f1bc7258fd0>,
#   <__main__.Request at 0x7f1bc7258ca0>,
#   <__main__.Request at 0x7f1bc72582b0>,
#   <__main__.Request at 0x7f1bc6f4dfd0>,
#   <__main__.Request at 0x7f1bc6f4dc70>,
#   <__main__.Request at 0x7f1bc6f4dac0>,
#   <__main__.Request at 0x7f1bc6f4de80>,
#   <__main__.Request at 0x7f1bc6f4dc10>,
#   <__main__.Request at 0x7f1bc6f4d550>,
#   <__main__.Request at 0x7f1bc6f4da60>,
#   <__main__.Request at 0x7f1bc6f3eca0>,
#   <__main__.Request at 0x7f1bc6f3eeb0>,
#   <__main__.Request at 0x7f1bc6f3e520>,
#   <__main__.Request at 0x7f1bc6f3e8b0>,
#   <__main__.Request at 0x7f1bc6f3e4c0>,
#   <__main__.Request at 0x7f1bc6f3ebe0>,
#   <__main__.Request at 0x7f1bc6f5ce80>,
#   <__main__.Request at 0x7f1bc6f5cc70>,
#   <__main__.Request at 0x7f1bc6f5cca0>,
#   <__main__.Request at 0x7f1bc6f5c8e0>,
#   <__main__.Request at 0x7f1bc6f5c460>,
#   <__main__.Request at 0x7f1bc6f5ca00>,
#   <__main__.Request at 0x7f1bc6f5cdf0>,
#   <__main__.Request at 0x7f1bc6f5cfd0>,
#   <__main__.Request at 0x7f1bc6f5cf40>,
#   <__main__.Request at 0x7f1bc6f5cdc0>,
#   <__main__.Request at 0x7f1bc6f5c9d0>,
#   <__main__.Request at 0x7f1bc6f5cb50>,
#   <__main__.Request at 0x7f1bc6f6bfd0>,
#   <__main__.Request at 0x7f1bc6f6bb80>,
#   <__main__.Request at 0x7f1bc6f6b9a0>,
#   <__main__.Request at 0x7f1bc6f6b790>,
#   <__main__.Request at 0x7f1bc6f6b460>,
#   <__main__.Request at 0x7f1bc6f6b700>,
#   <__main__.Request at 0x7f1bc6f6baf0>,
#   <__main__.Request at 0x7f1bc6f6bf10>,
#   <__main__.Request at 0x7f1bc6f6bc40>,
#   <__main__.Request at 0x7f1bc6f6bcd0>,
#   <__main__.Request at 0x7f1bc6f6b8e0>,
#   <__main__.Request at 0x7f1bc6f6bee0>,
#   <__main__.Request at 0x7f1bc6efbe20>,
#   <__main__.Request at 0x7f1bc6efb820>,
#   <__main__.Request at 0x7f1bc6efbb50>,
#   <__main__.Request at 0x7f1bc6efbd60>,
#   <__main__.Request at 0x7f1bc6efb610>,
#   <__main__.Request at 0x7f1bc6efb8b0>,
#   <__main__.Request at 0x7f1bc6efbca0>,
#   <__main__.Request at 0x7f1bc6efb970>,
#   <__main__.Request at 0x7f1bc6efb760>,
#   <__main__.Request at 0x7f1bc6efbeb0>,
#   <__main__.Request at 0x7f1bc6efbd30>,
#   <__main__.Request at 0x7f1bc6efbe80>,
#   <__main__.Request at 0x7f1bc6f09d90>,
#   <__main__.Request at 0x7f1bc6f09b80>,
#   <__main__.Request at 0x7f1bc6f099a0>,
#   <__main__.Request at 0x7f1bc6f09790>,
#   <__main__.Request at 0x7f1bc6f09520>,
#   <__main__.Request at 0x7f1bc6f09700>,
#   <__main__.Request at 0x7f1bc6f09af0>,
#   <__main__.Request at 0x7f1bc6f09ee0>,
#   <__main__.Request at 0x7f1bc6f09c40>,
#   <__main__.Request at 0x7f1bc6f09cd0>,
#   <__main__.Request at 0x7f1bc6f098e0>,
#   <__main__.Request at 0x7f1bc6f09850>,
#   <__main__.Request at 0x7f1bc6f17d90>,
#   <__main__.Request at 0x7f1bc6f17b80>,
#   <__main__.Request at 0x7f1bc6f179a0>,
#   <__main__.Request at 0x7f1bc6f17e80>,
#   <__main__.Request at 0x7f1bc6f17370>,
#   <__main__.Request at 0x7f1bc6f17640>,
#   <__main__.Request at 0x7f1bc6f17af0>,
#   <__main__.Request at 0x7f1bc6f17a30>,
#   <__main__.Request at 0x7f1bc6f17700>,
#   <__main__.Request at 0x7f1bc6f17cd0>,
#   <__main__.Request at 0x7f1bc6f178e0>,
#   <__main__.Request at 0x7f1bc6f17850>,
#   <__main__.Request at 0x7f1bc6f26b80>,
#   <__main__.Request at 0x7f1bc6f26f70>,
#   <__main__.Request at 0x7f1bc7bb1f10>,
#   <__main__.Request at 0x7f1bc7bb1eb0>,
#   <__main__.Request at 0x7f1bc7bb1ee0>,
#   <__main__.Request at 0x7f1bc75a6100>,
#   <__main__.Request at 0x7f1bc75aca60>,
#   <__main__.Request at 0x7f1bc75ac790>,
#   <__main__.Request at 0x7f1bc75ac340>,
#   <__main__.Request at 0x7f1bc732fb80>,
#   <__main__.Request at 0x7f1bc732fa90>,
#   <__main__.Request at 0x7f1bc732f850>,
#   <__main__.Request at 0x7f1bc732faf0>,
#   <__main__.Request at 0x7f1bc732f910>,
#   <__main__.Request at 0x7f1bc732fa60>,
#   <__main__.Request at 0x7f1bc732f9d0>,
#   <__main__.Request at 0x7f1bc732fd00>,
#   <__main__.Request at 0x7f1bc732fd60>,
#   <__main__.Request at 0x7f1bc732f1c0>,
#   <__main__.Request at 0x7f1bc732f940>,
#   <__main__.Request at 0x7f1bc732f1f0>,
#   <__main__.Request at 0x7f1bc732f370>,
#   <__main__.Request at 0x7f1bc732f340>,
#   <__main__.Request at 0x7f1bc732f190>,
#   <__main__.Request at 0x7f1bc732f610>,
#   <__main__.Request at 0x7f1bc732f130>,
#   <__main__.Request at 0x7f1bc732ffd0>,
#   <__main__.Request at 0x7f1bc732fbb0>,
#   <__main__.Request at 0x7f1bc7318b80>,
#   <__main__.Request at 0x7f1bc7318850>,
#   <__main__.Request at 0x7f1bc7318c10>,
#   <__main__.Request at 0x7f1bc7318a00>,
#   <__main__.Request at 0x7f1bc7318880>,
#   <__main__.Request at 0x7f1bc73188e0>,
#   <__main__.Request at 0x7f1bc7318c40>,
#   <__main__.Request at 0x7f1bc7284d60>,
#   <__main__.Request at 0x7f1bc7318df0>,
#   <__main__.Request at 0x7f1bc7318790>,
#   <__main__.Request at 0x7f1bc7318b50>,
#   <__main__.Request at 0x7f1bc7318eb0>,
#   <__main__.Request at 0x7f1bc7284e50>,
#   <__main__.Request at 0x7f1bc7284430>,
#   <__main__.Request at 0x7f1bc7284c40>,
#   <__main__.Request at 0x7f1bc7284970>,
#   <__main__.Request at 0x7f1bc7284ee0>,
#   <__main__.Request at 0x7f1bc7284460>,
#   <__main__.Request at 0x7f1bc7284940>,
#   <__main__.Request at 0x7f1bc7284eb0>,
#   <__main__.Request at 0x7f1bc72b5d60>,
#   <__main__.Request at 0x7f1bc72b5850>,
#   <__main__.Request at 0x7f1bc72b5cd0>,
#   <__main__.Request at 0x7f1bc72b5dc0>,
#   <__main__.Request at 0x7f1bc72b5e50>,
#   <__main__.Request at 0x7f1bc72b55e0>,
#   <__main__.Request at 0x7f1bc72b5e20>,
#   <__main__.Request at 0x7f1bc72b5bb0>,
#   <__main__.Request at 0x7f1bc72b5f10>,
#   <__main__.Request at 0x7f1bc72b5a90>,
#   <__main__.Request at 0x7f1bc72b59d0>,
#   <__main__.Request at 0x7f1bc72b5c70>,
#   <__main__.Request at 0x7f1bc72b5940>,
#   <__main__.Request at 0x7f1bc72aab20>,
#   <__main__.Request at 0x7f1bc72aa9d0>,
#   <__main__.Request at 0x7f1bc72aaf40>,
#   <__main__.Request at 0x7f1bc72aaf10>,
#   <__main__.Request at 0x7f1bc72aa310>,
#   <__main__.Request at 0x7f1bc72aae20>,
#   <__main__.Request at 0x7f1bc72aa6a0>,
#   <__main__.Request at 0x7f1bc72aaa90>,
#   <__main__.Request at 0x7f1bc72aa940>,
#   <__main__.Request at 0x7f1bc72aae80>,
#   <__main__.Request at 0x7f1bc72aa5e0>,
#   <__main__.Request at 0x7f1bc72aab80>,
#   <__main__.Request at 0x7f1bc735f3d0>,
#   <__main__.Request at 0x7f1bc735ffd0>,
#   <__main__.Request at 0x7f1bc735faf0>,
#   <__main__.Request at 0x7f1bc735f2e0>,
#   <__main__.Request at 0x7f1bc735f460>,
#   <__main__.Request at 0x7f1bc735f790>,
#   <__main__.Request at 0x7f1bc735fc40>,
#   <__main__.Request at 0x7f1bc735fd90>,
#   <__main__.Request at 0x7f1bc735ffa0>,
#   <__main__.Request at 0x7f1bc735fe50>,
#   <__main__.Request at 0x7f1bc735fe20>,
#   <__main__.Request at 0x7f1bc735f8e0>,
#   <__main__.Request at 0x7f1bc7348cd0>,
#   <__main__.Request at 0x7f1bc73485e0>,
#   <__main__.Request at 0x7f1bc7348a30>,
#   <__main__.Request at 0x7f1bc7348730>,
#   <__main__.Request at 0x7f1bc73481c0>,
#   <__main__.Request at 0x7f1bc7348640>,
#   <__main__.Request at 0x7f1bc7348b80>,
#   <__main__.Request at 0x7f1bc73488e0>,
#   <__main__.Request at 0x7f1bc7348490>,
#   <__main__.Request at 0x7f1bc7348f10>,
#   <__main__.Request at 0x7f1bc73484f0>,
#   <__main__.Request at 0x7f1bc7348e50>,
#   <__main__.Request at 0x7f1bc7384c10>,
#   <__main__.Request at 0x7f1bc7384a60>,
#   <__main__.Request at 0x7f1bc7384880>,
#   <__main__.Request at 0x7f1bc7384b50>,
#   <__main__.Request at 0x7f1bc7384ca0>,
#   ...]}

# %%
matches = []
for rq in [rq for rq in all_requests[addr] for addr in devices if (rq.mtu_size == mtu and rq.data_size == data and rq.conn_interval == interval)]:
    if "WRITE" in rq.request_type:
        matches += [rq]
for rq in matches:
    df_tmp = rq.df[["Opcode","Time.1"]]
    df_tmp["Time Diff"] = df_tmp["Time.1"].diff().apply(lambda dt:dt.seconds*1_000_000 + dt.microseconds).apply(lambda x:x/1_000).fillna(0)
# 4014  Handle Value Notification 2021-06-07 15:09:03.400723     12.008
# 4013  Handle Value Notification 2021-06-07 15:09:03.400723      0.000
# 4016  Handle Value Notification 2021-06-07 15:09:03.401225      0.502
# 4015  Handle Value Notification 2021-06-07 15:09:03.401225      0.000
# 4017  Handle Value Notification 2021-06-07 15:09:03.401602      0.377
# 4018  Handle Value Notification 2021-06-07 15:09:03.401602      0.000
# 4019  Handle Value Notification 2021-06-07 15:09:03.401789      0.187
# 4020  Handle Value Notification 2021-06-07 15:09:03.401789      0.000
# 4022  Handle Value Notification 2021-06-07 15:09:03.401955      0.166
# 4021  Handle Value Notification 2021-06-07 15:09:03.401955      0.000
# 4024  Handle Value Notification 2021-06-07 15:09:03.402116      0.161
# 4023  Handle Value Notification 2021-06-07 15:09:03.402116      0.000
# 4026  Handle Value Notification 2021-06-07 15:09:03.402278      0.162
# 4025  Handle Value Notification 2021-06-07 15:09:03.402278      0.000
# 4028  Handle Value Notification 2021-06-07 15:09:03.402447      0.169
# 4027  Handle Value Notification 2021-06-07 15:09:03.402447      0.000
# 4030  Handle Value Notification 2021-06-07 15:09:03.402617      0.170
# 4029  Handle Value Notification 2021-06-07 15:09:03.402617      0.000
# 4032  Handle Value Notification 2021-06-07 15:09:03.402775      0.158
# 4031  Handle Value Notification 2021-06-07 15:09:03.402775      0.000
# 4033  Handle Value Notification 2021-06-07 15:09:03.402936      0.161
# 4034  Handle Value Notification 2021-06-07 15:09:03.402936      0.000
# 4036  Handle Value Notification 2021-06-07 15:09:03.403169      0.233
# 4035  Handle Value Notification 2021-06-07 15:09:03.403169      0.000
# 4038  Handle Value Notification 2021-06-07 15:09:03.403444      0.275
# 4037  Handle Value Notification 2021-06-07 15:09:03.403444      0.000
# 4040  Handle Value Notification 2021-06-07 15:09:03.704657    301.213
# 4039  Handle Value Notification 2021-06-07 15:09:03.704657      0.000
# 4041  Handle Value Notification 2021-06-07 15:09:03.705109      0.452
# 4042  Handle Value Notification 2021-06-07 15:09:03.705109      0.000
# 4044  Handle Value Notification 2021-06-07 15:09:03.705425      0.316
# 4043  Handle Value Notification 2021-06-07 15:09:03.705425      0.000
# 4046  Handle Value Notification 2021-06-07 15:09:03.706066      0.641
# 4045  Handle Value Notification 2021-06-07 15:09:03.706066      0.000
# 4048  Handle Value Notification 2021-06-07 15:09:03.706754      0.688
# 4047  Handle Value Notification 2021-06-07 15:09:03.706754      0.000
# 4050  Handle Value Notification 2021-06-07 15:09:03.707742      0.988
# 4049  Handle Value Notification 2021-06-07 15:09:03.707742      0.000
# <ipython-input-27-202c84d956f1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["Time Diff"] = df_tmp["Time.1"].diff().apply(lambda dt:dt.seconds*1_000_000 + dt.microseconds).apply(lambda x:x/1_000).fillna(0)
# <ipython-input-27-202c84d956f1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["Time Diff"] = df_tmp["Time.1"].diff().apply(lambda dt:dt.seconds*1_000_000 + dt.microseconds).apply(lambda x:x/1_000).fillna(0)
# <ipython-input-27-202c84d956f1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["Time Diff"] = df_tmp["Time.1"].diff().apply(lambda dt:dt.seconds*1_000_000 + dt.microseconds).apply(lambda x:x/1_000).fillna(0)
# <ipython-input-27-202c84d956f1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["Time Diff"] = df_tmp["Time.1"].diff().apply(lambda dt:dt.seconds*1_000_000 + dt.microseconds).apply(lambda x:x/1_000).fillna(0)
# <ipython-input-27-202c84d956f1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["Time Diff"] = df_tmp["Time.1"].diff().apply(lambda dt:dt.seconds*1_000_000 + dt.microseconds).apply(lambda x:x/1_000).fillna(0)
# <ipython-input-27-202c84d956f1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["Time Diff"] = df_tmp["Time.1"].diff().apply(lambda dt:dt.seconds*1_000_000 + dt.microseconds).apply(lambda x:x/1_000).fillna(0)
# <ipython-input-27-202c84d956f1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["Time Diff"] = df_tmp["Time.1"].diff().apply(lambda dt:dt.seconds*1_000_000 + dt.microseconds).apply(lambda x:x/1_000).fillna(0)
# <ipython-input-27-202c84d956f1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["Time Diff"] = df_tmp["Time.1"].diff().apply(lambda dt:dt.seconds*1_000_000 + dt.microseconds).apply(lambda x:x/1_000).fillna(0)
# <ipython-input-27-202c84d956f1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["Time Diff"] = df_tmp["Time.1"].diff().apply(lambda dt:dt.seconds*1_000_000 + dt.microseconds).apply(lambda x:x/1_000).fillna(0)
