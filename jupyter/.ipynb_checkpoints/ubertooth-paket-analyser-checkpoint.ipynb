# %%
import pandas as pd
import datetime
import pprint
import re
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import os
import math

# %%
# %run UbertoothHelpClasses.ipynb
# Out:
# Data Size 64mnopqrstuvwxyzabcdefghijklmnopqrstuvwxyzabcdefghijkl 64
# 72

# %%
columns = ["time","priority","class","message","extra"]
device_macs = [mac.lower() for mac in ["24:0A:C4:61:78:D2","24:0A:C4:60:EF:3A","24:0A:C4:60:E5:D2"]]

# %%
df = pd.DataFrame()
for filename in os.listdir("measurements"):
    print(filename)
    if filename.startswith("ubertooth") and filename.endswith(".csv"):
        df = df.append(pd.read_csv("measurements/"+filename,encoding='latin1'))
        print("Added")
    if os.path.isdir("measurements/"+filename):
        for filename_subfolder in os.listdir("measurements/"+filename):
            if filename_subfolder.startswith("ubertooth") and filename_subfolder.endswith(".csv"):
                print("%s/%s"%(filename,filename_subfolder))
                df = df.append(pd.read_csv("measurements/"+filename+"/"+filename_subfolder,encoding='latin1'))
                print("Added")
df_original = df
df
# Out:
# hci-notify_ci_256.csv
# messwerte-2021-05-25
# messwerte-2021-05-25/ubertooth_ci_36.csv
# Added
# messwerte-2021-05-25/ubertooth_ci_64.csv
# Added
# messwerte-2021-05-25/ubertooth_ci_256.csv
# Added
# messwerte-read
# hci-notify.csv
# messwerte-notify-detailed
# messwerte-notify-new
#        No.           Time              Source         Destination Protocol  \
# 0        1              0       88.221.60.168      192.168.143.64  TLSv1.2
# 1        2     5.8937e-05      192.168.143.64       88.221.60.168      TCP
# 2        3       4.49e-07       88.221.60.168      192.168.143.64      TCP
# 3        4        3.86674   48:a5:89:1e:a8:97           Broadcast    LE LL
# 4        5    0.000321835      192.168.143.64       88.221.60.168      TCP
# ...    ...            ...                 ...                 ...      ...
# 4790  4791  567.690537500  Unknown_0x506544e1  Unknown_0x506544e1    LE LL
# 4791  4792  340.875130271      192.168.143.64      162.254.197.54  TLSv1.2
# 4792  4793  340.956100257      162.254.197.54      192.168.143.64      TCP
# 4793  4794  341.183642301      162.254.197.54      192.168.143.64  TLSv1.2
# 4794  4795  341.183706616      192.168.143.64      162.254.197.54      TCP
#
#       Length  Request in Frame  RF Channel Opcode Value Handle  \
# 0         92               NaN         NaN    NaN   NaN    NaN
# 1         66               NaN         NaN    NaN   NaN    NaN
# 2         68               NaN         NaN    NaN   NaN    NaN
# 3         43               NaN         0.0    NaN   NaN    NaN
# 4         66               NaN         NaN    NaN   NaN    NaN
# ...      ...               ...         ...    ...   ...    ...
# 4790      19               NaN        36.0    NaN   NaN    NaN
# 4791     121               NaN         NaN    NaN   NaN    NaN
# 4792      56               NaN         NaN    NaN   NaN    NaN
# 4793     251               NaN         NaN    NaN   NaN    NaN
# 4794      54               NaN         NaN    NaN   NaN    NaN
#
#                                                    Info  \
# 0                                      Application Data
# 1     42802  >  443 [ACK] Seq=1 Ack=25 Win=501 Len=0...
# 2     443  >  42802 [FIN, ACK] Seq=25 Ack=1 Win=501 ...
# 3                                               ADV_IND
# 4     42802  >  443 [FIN, ACK] Seq=1 Ack=26 Win=501 ...
# ...                                                 ...
# 4790                                          Empty PDU
# 4791                                   Application Data
# 4792  27028  >  43065 [ACK] Seq=2877 Ack=1392 Win=10...
# 4793                                   Application Data
# 4794  43065  >  27028 [ACK] Seq=1392 Ack=3074 Win=32...
#
#                              Time.1 UUID
# 0     2021-05-25 15:38:25,659317240  NaN
# 1     2021-05-25 15:38:25,659376177  NaN
# 2     2021-05-25 15:38:25,659317689  NaN
# 3     2021-05-25 15:38:29,526056637  NaN
# 4     2021-05-25 15:38:25,659639075  NaN
# ...                             ...  ...
# 4790  2021-05-26 14:01:06,756717203  NaN
# 4791  2021-05-26 13:57:19,941309974  NaN
# 4792  2021-05-26 13:57:20,022279960  NaN
# 4793  2021-05-26 13:57:20,249822004  NaN
# 4794  2021-05-26 13:57:20,249886319  NaN
#
# [32781 rows x 14 columns]

# %%
pprint.pprint('sources:%s'%list(set(df['Source'].values)))
pprint.pprint('protocols:%s'%list(set(df['Protocol'].values)))

pprint.pprint('Opcodes:%s'%list(set(df['Opcode'].values)))
pprint.pprint('Handles:%s'%list(set(df['Handle'].values)))
#pprint.pprint('Infos:%s'%list(set(df['Info'].values)))
# Out:
# ("sources:[nan, '7b:27:ae:a3:96:b0', '7b:01:84:16:3b:45', '47:b6:e4:ea:74:d8', "
#  "'66:d5:88:4b:2b:10', 'd3:f0:98:6d:4f:61', '17:65:5f:01:c3:10', "
#  "'49:1a:b5:e2:e8:8e', '217.14.146.53', '48:85:f0:9f:99:4a', "
#  "'66:c1:10:b8:0c:ee', '48:01:c0:1f:9f:6a', '89:f0:f3:a5:b8:5b', "
#  "'48:45:f0:16:99:6b', '31:9a:c0:8c:6e:bd', '3e:e9:e1:25:ba:b5', "
#  "'5d:51:21:9a:c7:e0', '48:65:a0:5f:99:e8', '5b:bf:2e:b3:aa:18', "
#  "'07:e4:98:84:e0:59', '3e:e9:72:35:ba:bd', '3e:99:e1:25:ba:b5', "
#  "'47:f0:18:c4:e4:59', '0b:c2:96:a4:28:0a', '17:46:5f:01:c9:90', "
#  "'SeamapUK_f6:d8:79', '13:1d:09:23:36:c0', '7c:1a:f1:a3:28:8f', "
#  "'48:05:f0:1f:b1:48', '4b:f0:18:82:e4:51', '43:f1:18:84:e4:59', "
#  "'1b:17:09:23:36:c0', '5f:1a:8a:8a:44:d2', '40:09:f0:1f:99:6e', "
#  "'52:77:45:42:f0:5e', '57:d9:12:45:a9:33', '39:14:68:8b:d9:8b', "
#  "'01:85:6a:28:4b:36', '18:72:0d:f3:9b:09', '47:f0:18:84:ec:59', "
#  "'68:05:f8:1f:99:68', '48:05:f0:0f:99:6a', '48:05:f0:bf:99:6a', "
#  "'1b:15:09:23:b6:c0', '48:a5:89:1e:a8:97', '4c:61:cf:3f:97:2a', "
#  "'0b:c2:96:a4:22:0a', '35:ac:6d:b3:39:d3', '192.168.143.1', "
#  "'8c:60:c7:3d:cf:28', 'be:e9:e2:25:ba:b5', 'TexasIns_bf:d2:c2', "
#  "'68:12:f1:fb:28:ef', '7b:27:ae:a3:ba:88', '36:a1:59:b1:ba:b6', "
#  "'6d:75:3e:3a:7e:9b', '79:01:84:16:7b:45', 'TexasIns_3d:cf:28', "
#  "'188.40.136.143', '40:fc:8b:6d:bf:de', 'u-blox_84:cc:cc', "
#  "'cd:4b:57:8d:c0:c4', '17:15:09:23:36:c0', '47:b6:64:ee:74:d0', "
#  "'21:20:0e:61:5f:3f', 'cc:7f:57:c7:cc:cc', '48:05:f0:1d:99:6a', "
#  "'MS-NLB-PhysServer-32_1c:d9:84:1d:4f', '2a00:1450:400c:c09::bc', "
#  "'192.168.143.64', '23:4b:80:64:a7:e3', '40:30:cc:85:31:f0', "
#  "'54:53:b4:a9:2d:9f', '5f:d9:19:83:a9:33', '68:1f:71:e2:b8:ef', "
#  "'55:f2:38:84:84:51', '43:d0:18:84:e4:59', '4b:95:f0:1f:99:6a', "
#  "'60:6a:ef:b9:8e:f4', 'cc:61:cf:3f:df:28', '6b:a7:ae:a3:9a:88', "
#  "'40:e2:bf:d9:91:54', '2a03:2880:f1ff:83:face:b00c:0:25de', "
#  "'c8:15:70:1f:99:6a', '4b:f0:bd:84:e6:d9', '6a:2a:6b:36:2b:52', "
#  "'4a:28:69:36:6b:56', '2f:a2:3a:01:f2:e9', '40:68:c6:eb:a7:f4', "
#  "'40:91:6c:51:74:9b', '58:bb:87:34:99:7d', '2f:a3:3a:01:e3:c0', "
#  "'7b:a2:ae:b3:ba:88', '88:05:f0:1f:99:6a', '0f:c2:96:a4:2a:0a', "
#  "'6a:28:6b:36:2a:41', 'd1:60:b8:ed:4e:f1', '5f:d9:12:45:a9:33', "
#  "'4e:45:f8:5f:a1:4a', '48:05:f0:1f:dd:4a', '7b:27:ae:a3:9a:88', "
#  "'TexasIns_3d:c7:28', '41:e4:18:86:e5:58', '1e:07:19:cd:90:e5', "
#  "'68:1a:f1:23:f8:8f', '6f:e7:a4:5e:41:f4', '58:07:f0:1d:99:4a', "
#  "'3e:e9:e2:25:ba:a5', '20:9a:f3:83:68:8f', 'cc:eb:57:87:ec:cc', "
#  "'4b:9c:ab:a0:9b:69', '5c:d1:3a:47:28:25', '78:81:0e:8e:79:8e', "
#  "'4d:19:28:91:bb:96']")
# ("protocols:['ATT', 'TLSv1.2', '0x8912', 'BROWSER', 'HomePlug AV', 'NTP', "
#  "'SSDP', 'TLSv1.3', 'MDNS', 'TCP', 'HTTP', 'BT Mesh', 'LE LL', 'ARP', "
#  "'ICMPv6', 'BT Mesh PB-ADV', 'L2CAP', 'QUIC', 'IGMPv3', 'DNS', 'UDP', "
#  "'EAPOL']")
# ("Opcodes:[nan, 'Write Request', 'Exchange MTU Request', 'Error Response', "
#  "'Read Blob Response', 'Handle Value Indication', 'Read Blob Request', 'Read "
#  "Multiple Request', 'Read By Group Type Response', 'Read By Type Request', "
#  "'Write Response', 'Find Information Request', 'Exchange MTU Response', 'Read "
#  "Response', 'Find Information Response', 'Read By Type Response', 'Read By "
#  "Group Type Request', 'Read Request']")
# ("Handles:[nan, '0x001b', '0x002a,0x009b', '0x0005', '0x0004', "
#  "'0x002c,0x002b', '0x002e', '0x0035', '0x0015,0x0017,0x0019', '0x002a', "
#  "'0x706f', '0x0003', '0x0028', '0x6261', '0x002e,0x002d', '0x0001', '0x0037', "
#  "'0x0016,0x0018,0x001a,0x0015,0x0017,0x0019', '0x002a,0x0029', "
#  "'0x0003,0x0002', '0x0035,0x0034', '0x001a', '0x0030,0x002f', '0x0036', "
#  "'0x0033,0x0032', '0x0014', '0x205a', '0x0033', '0x0001,0x0014', '0x0031']")

# %%
df[df['Protocol'].str.contains("ATT")]
# Out:
#        No.           Time              Source         Destination Protocol  \
# 1216  1217        17.3759  Unknown_0x50657d91  Unknown_0x50657d91      ATT
# 1219  1220        17.4262  Unknown_0x50657d91  Unknown_0x50657d91      ATT
# 1220  1221        17.4759  Unknown_0x50657d91  Unknown_0x50657d91      ATT
# 1223  1224        17.5263  Unknown_0x50657d91  Unknown_0x50657d91      ATT
# 1224  1225        17.5759  Unknown_0x50657d91  Unknown_0x50657d91      ATT
# ...    ...            ...                 ...                 ...      ...
# 4754  4755  557.770299000  Unknown_0x506544e1  Unknown_0x506544e1      ATT
# 4760  4761  558.730105000  Unknown_0x506544e1  Unknown_0x506544e1      ATT
# 4775  4776  563.850243800  Unknown_0x506544e1  Unknown_0x506544e1      ATT
# 4776  4777  564.490253000  Unknown_0x506544e1  Unknown_0x506544e1      ATT
# 4780  4781  565.130261800  Unknown_0x506544e1  Unknown_0x506544e1      ATT
#
#       Length  Request in Frame  RF Channel                       Opcode Value  \
# 1216      30               NaN         5.0   Read By Group Type Request   NaN
# 1219      37            1217.0        19.0  Read By Group Type Response   NaN
# 1220      30               NaN         7.0   Read By Group Type Request   NaN
# 1223      45            1221.0         7.0  Read By Group Type Response   NaN
# 1224      30               NaN        21.0         Read By Type Request   NaN
# ...      ...               ...         ...                          ...   ...
# 4754      24            4752.0        29.0               Write Response   NaN
# 4760      26               NaN        19.0                 Read Request   NaN
# 4775      26               NaN        13.0                 Read Request   NaN
# 4776      28               NaN        20.0            Read Blob Request   NaN
# 4780      28               NaN        38.0            Read Blob Request   NaN
#
#              Handle                                               Info  \
# 1216            NaN  UnknownDirection Read By Group Type Request, G...
# 1219  0x0001,0x0014  UnknownDirection Read By Group Type Response, ...
# 1220            NaN  UnknownDirection Read By Group Type Request, G...
# 1223         0x0028  UnknownDirection Read By Group Type Response, ...
# 1224            NaN  UnknownDirection Read By Type Request, GATT In...
# ...             ...                                                ...
# 4754         0x002e  UnknownDirection Write Response, Handle: 0x002...
# 4760         0x002a  UnknownDirection Read Request, Handle: 0x002a ...
# 4775         0x002a  UnknownDirection Read Request, Handle: 0x002a ...
# 4776         0x002a  UnknownDirection Read Blob Request, Handle: 0x...
# 4780         0x002a  UnknownDirection Read Blob Request, Handle: 0x...
#
#                              Time.1  \
# 1216  2021-05-25 15:38:43,035249537
# 1219  2021-05-25 15:38:43,085550237
# 1220  2021-05-25 15:38:43,135251037
# 1223  2021-05-25 15:38:43,185576137
# 1224  2021-05-25 15:38:43,235252637
# ...                             ...
# 4754  2021-05-26 14:00:56,836478703
# 4760  2021-05-26 14:00:57,796284703
# 4775  2021-05-26 14:01:02,916423503
# 4776  2021-05-26 14:01:03,556432703
# 4780  2021-05-26 14:01:04,196441503
#
#                                                    UUID
# 1216                                                NaN
# 1219                                                NaN
# 1220                                                NaN
# 1223  26cb2f28a4ba49fc856ad57fe4d3dada,dadad3e47fd56...
# 1224                                                NaN
# ...                                                 ...
# 4754                   f341082200c04dd3a60b3cd6124fd323
# 4760                   fbdc45f28337467b8019e7db05355215
# 4775                   fbdc45f28337467b8019e7db05355215
# 4776                   fbdc45f28337467b8019e7db05355215
# 4780                   fbdc45f28337467b8019e7db05355215
#
# [2561 rows x 14 columns]

# %% [markdown]
# ### Reduce Dataframe on only Rows of active conection

# %%
df['Source'] = df['Source'].astype(str)
df['Source'] = df['Source'].fillna("")
unknown_sources = [addr for addr in list(set(df['Source'].values)) if addr.startswith("Unknown_")]
print("all: ",df.shape)
print("filter on %s"%unknown_sources)
df = df[df['Source'].apply(lambda src:src in unknown_sources)]
print("filtered: ",df.shape)
# Out:
# all:  (32781, 14)
# filter on ['Unknown_0x506574d7', 'Unknown_0xaf9a85a5', 'Unknown_0x506544e1', 'Unknown_0x50657d91']
# filtered:  (25313, 14)

# %% [markdown]
# ### Clean Data

# %%
try:
    print("Types:\n%s"%df.dtypes)
    df = df.drop(['Source','Destination','Protocol'],axis=1)
    df['Info'] = df['Info'].astype(str)
    df['Info'] = df['Info'].fillna("")
    df['Value'] = df['Value'].astype(str)
    df['Value'] = df['Value'].fillna("")
    df['Opcode'] = df['Opcode'].astype(str)
    df['Opcode'] = df['Opcode'].fillna("")
    df['Handle'] = df['Handle'].astype(str)
    df['Handle'] = df['Handle'].fillna("")
    df['UUID'] = df['UUID'].astype(str)
    df['UUID'] = df['UUID'].fillna("")
    print("Cleaned:\n%s"%df.dtypes)
except:
    pass
# Out:
# Types:
# No.                   int64
# Time                 object
# Source               object
# Destination          object
# Protocol             object
# Length                int64
# Request in Frame    float64
# RF Channel          float64
# Opcode               object
# Value                object
# Handle               object
# Info                 object
# Time.1               object
# UUID                 object
# dtype: object
# Cleaned:
# No.                   int64
# Time                 object
# Length                int64
# Request in Frame    float64
# RF Channel          float64
# Opcode               object
# Value                object
# Handle               object
# Info                 object
# Time.1               object
# UUID                 object
# dtype: object

# %% [markdown]
# ### Add Time

# %%
df = df[~df['Time.1'].str.contains("REF")]

# %%
df["Time.1"] = pd.to_datetime(df["Time.1"],format="%Y-%m-%d %H:%M:%S,%f")+ pd.Timedelta(hours=1)
df.sort_values("Time.1",inplace=True)
df
# Out:
#        No.           Time  Length  Request in Frame  RF Channel Opcode Value  \
# 1204  1205        17.0847      31               NaN         0.0    nan   nan
# 1205  1206        17.0869      72               NaN         0.0    nan   nan
# 1206  1207        17.1259      19               NaN        15.0    nan   nan
# 1207  1208        17.1262      25               NaN        15.0    nan   nan
# 1208  1209        17.1759      28               NaN         3.0    nan   nan
# ...    ...            ...     ...               ...         ...    ...   ...
# 4786  4787  567.050520000      19               NaN        18.0    nan   nan
# 4787  4788  567.370295500      19               NaN        27.0    nan   nan
# 4788  4789  567.370524400      19               NaN        27.0    nan   nan
# 4789  4790  567.690309300      19               NaN        36.0    nan   nan
# 4790  4791  567.690537500      19               NaN        36.0    nan   nan
#
#      Handle                            Info                        Time.1 UUID
# 1204    nan         Control Opcode: Unknown 2021-05-25 16:38:42.744037337  nan
# 1205    nan            L2CAP Fragment Start 2021-05-25 16:38:42.746248137  nan
# 1206    nan                       Empty PDU 2021-05-25 16:38:42.785247037  nan
# 1207    nan  Control Opcode: LL_VERSION_IND 2021-05-25 16:38:42.785475737  nan
# 1208    nan  Control Opcode: LL_FEATURE_REQ 2021-05-25 16:38:42.835247837  nan
# ...     ...                             ...                           ...  ...
# 4786    nan                       Empty PDU 2021-05-26 15:01:06.116699703  nan
# 4787    nan                       Empty PDU 2021-05-26 15:01:06.436475203  nan
# 4788    nan                       Empty PDU 2021-05-26 15:01:06.436704103  nan
# 4789    nan                       Empty PDU 2021-05-26 15:01:06.756489003  nan
# 4790    nan                       Empty PDU 2021-05-26 15:01:06.756717203  nan
#
# [25312 rows x 11 columns]

# %%
print('Opcodes:%s'%list(set(df['Opcode'].values)))
# Out:
# Opcodes:['nan', 'Write Request', 'Exchange MTU Request', 'Error Response', 'Read Blob Response', 'Handle Value Indication', 'Read Blob Request', 'Read Multiple Request', 'Read By Group Type Response', 'Read By Type Request', 'Write Response', 'Find Information Request', 'Exchange MTU Response', 'Read Response', 'Find Information Response', 'Read By Type Response', 'Read By Group Type Request', 'Read Request']

# %% [markdown]
# ### Resolve Handles

# %%
uuid_map = dict({"26cb2f28-a4ba-49fc-856a-d57fe4d3dada":"SERVICE_UUID_MAIN",
"fbdc45f2-8337-467b-8019-e7db05355215":"CHARACTERISTIC_UUID_READ",
"8c65f73d-ddab-4dd9-a2e0-f5a10ce7e252":"CHARACTERISTIC_UUID_WRITE_COMMAND",
"f3410822-00c0-4dd3-a60b-3cd6124fd323":"CHARACTERISTIC_UUID_WRITE_SIZE",
"1ee1d0fc-6f3c-4c6a-ac1c-c54d2a97f932":"CHARACTERISTIC_UUID_NOTIFY",
"83157f66-7c91-431e-a037-7c2b9e594ef6":"CHARACTERISTIC_UUID_INDICATE",
"46ac40cc-7eaa-41a9-9964-956a984fd9c3":"CHARACTERISTIC_UUID_CONN_INTERVAL"})
uuid_map = {k.replace("-",""):v.replace("CHARACTERISTIC_UUID_","") for k,v in uuid_map.items()}
handle_map = dict()
def resolve_handles(df):
    df_read_by_type_response = df[df['Opcode'].str.startswith("Read By Type Response")][['Handle','UUID']]
    for i,row in df_read_by_type_response.iterrows():
        handles = row['Handle'].split(",")
        uuids = row['UUID'].split(",")
        for i in range(0,min(len(handles),len(uuids))):
            handle = handles[i]
            uuid = uuids[i]
            if uuid in uuid_map.keys():
                handle_map[handle] = uuid_map[uuid]
    print("unresolved characteristics:",[char for uuid,char in uuid_map.items() if char not in handle_map.values()])
resolve_handles(df)
print(handle_map)
# Out:
# unresolved characteristics: ['SERVICE_UUID_MAIN']
# {'0x002a': 'READ', '0x002c': 'WRITE_COMMAND', '0x002e': 'WRITE_SIZE', '0x0030': 'NOTIFY', '0x0033': 'CONN_INTERVAL', '0x0035': 'INDICATE'}

# %%
# handle_map['0x002a'] = 'READ'

# %% [markdown]
#  ### Add Packettypes

# %%
def checkPaketType(row):  
    handle = row['Handle']
    if row['Info'].startswith("Empty PDU"):
        return "Channel Hop"
    elif len(handle) > 0:
        opcode = row['Opcode']
        if handle in handle_map.keys():
            pakettype = handle_map[handle]
            isSent = any([r in row['Info'] for r in ['Request','Req','REQ']])
            if isSent:
                return pakettype + " Req"
            else:
                return pakettype + " Rcvd"
        
        if opcode.startswith("Exchange MTU"):
            return opcode
    return ""

df['Pakettype'] = df.apply(axis=1,func = checkPaketType)
print('Pakettypes:%s'%list(set(df['Pakettype'].values)))
df
# Out:
# Pakettypes:['', 'Exchange MTU Request', 'WRITE_SIZE Req', 'Channel Hop', 'CONN_INTERVAL Req', 'CONN_INTERVAL Rcvd', 'READ Req', 'WRITE_SIZE Rcvd', 'INDICATE Rcvd', 'Exchange MTU Response', 'READ Rcvd']
#        No.           Time  Length  Request in Frame  RF Channel Opcode Value  \
# 1204  1205        17.0847      31               NaN         0.0    nan   nan
# 1205  1206        17.0869      72               NaN         0.0    nan   nan
# 1206  1207        17.1259      19               NaN        15.0    nan   nan
# 1207  1208        17.1262      25               NaN        15.0    nan   nan
# 1208  1209        17.1759      28               NaN         3.0    nan   nan
# ...    ...            ...     ...               ...         ...    ...   ...
# 4786  4787  567.050520000      19               NaN        18.0    nan   nan
# 4787  4788  567.370295500      19               NaN        27.0    nan   nan
# 4788  4789  567.370524400      19               NaN        27.0    nan   nan
# 4789  4790  567.690309300      19               NaN        36.0    nan   nan
# 4790  4791  567.690537500      19               NaN        36.0    nan   nan
#
#      Handle                            Info                        Time.1  \
# 1204    nan         Control Opcode: Unknown 2021-05-25 16:38:42.744037337
# 1205    nan            L2CAP Fragment Start 2021-05-25 16:38:42.746248137
# 1206    nan                       Empty PDU 2021-05-25 16:38:42.785247037
# 1207    nan  Control Opcode: LL_VERSION_IND 2021-05-25 16:38:42.785475737
# 1208    nan  Control Opcode: LL_FEATURE_REQ 2021-05-25 16:38:42.835247837
# ...     ...                             ...                           ...
# 4786    nan                       Empty PDU 2021-05-26 15:01:06.116699703
# 4787    nan                       Empty PDU 2021-05-26 15:01:06.436475203
# 4788    nan                       Empty PDU 2021-05-26 15:01:06.436704103
# 4789    nan                       Empty PDU 2021-05-26 15:01:06.756489003
# 4790    nan                       Empty PDU 2021-05-26 15:01:06.756717203
#
#      UUID    Pakettype
# 1204  nan
# 1205  nan
# 1206  nan  Channel Hop
# 1207  nan
# 1208  nan
# ...   ...          ...
# 4786  nan  Channel Hop
# 4787  nan  Channel Hop
# 4788  nan  Channel Hop
# 4789  nan  Channel Hop
# 4790  nan  Channel Hop
#
# [25312 rows x 12 columns]

# %%
print("All: ",df.shape)
print("With Pakettype: ",df[df['Pakettype'].apply(lambda st:len(st)>0)].shape)
print("Without Pakettype: ",df[df['Pakettype'].apply(lambda st:len(st) == 0)].shape)
df[df['Pakettype'].apply(lambda st:len(st) == 0)]
df = df[df['Pakettype'].apply(lambda st:len(st)>0)]
# Out:
# All:  (25312, 12)
# With Pakettype:  (24916, 12)
# Without Pakettype:  (396, 12)

# %% [markdown]
# ### Define Hops

# %%
df_hops = df[df['Pakettype'].str.contains("Channel Hop")]
df_hops = df_hops.drop(["Opcode","Value","Handle","Info","UUID"],axis=1)
df_hops
# Out:
#        No.           Time  Length  Request in Frame  RF Channel  \
# 1206  1207        17.1259      19               NaN        15.0
# 1211  1212        17.2262      19               NaN         3.0
# 1212  1213        17.2759      19               NaN        17.0
# 1215  1216        17.3264      19               NaN         5.0
# 1225  1226        17.6259      19               NaN         9.0
# ...    ...            ...     ...               ...         ...
# 4786  4787  567.050520000      19               NaN        18.0
# 4787  4788  567.370295500      19               NaN        27.0
# 4788  4789  567.370524400      19               NaN        27.0
# 4789  4790  567.690309300      19               NaN        36.0
# 4790  4791  567.690537500      19               NaN        36.0
#
#                             Time.1    Pakettype
# 1206 2021-05-25 16:38:42.785247037  Channel Hop
# 1211 2021-05-25 16:38:42.885524737  Channel Hop
# 1212 2021-05-25 16:38:42.935249237  Channel Hop
# 1215 2021-05-25 16:38:42.985669337  Channel Hop
# 1225 2021-05-25 16:38:43.285253237  Channel Hop
# ...                            ...          ...
# 4786 2021-05-26 15:01:06.116699703  Channel Hop
# 4787 2021-05-26 15:01:06.436475203  Channel Hop
# 4788 2021-05-26 15:01:06.436704103  Channel Hop
# 4789 2021-05-26 15:01:06.756489003  Channel Hop
# 4790 2021-05-26 15:01:06.756717203  Channel Hop
#
# [22550 rows x 7 columns]

# %%
ref_time = df_hops.iloc[0]['Time.1']
df_hops['microseconds diff'] = df_hops['Time.1'].apply(lambda dt:dt-ref_time).apply(lambda dt:dt.microseconds + dt.seconds*1_000_000)
df_hops
print(df_hops.shape)
fig, ax = plt.subplots(figsize=(12,3))
plt.xlim(0,df_hops['microseconds diff'].max())
plt.ylim(0,1)
plt.vlines(df_hops['microseconds diff'],0,1)
plt.title("Channel hops")
# Out:
# (22550, 8)
# Text(0.5, 1.0, 'Channel hops')

# %% [markdown]
# ### Define Settings

# %%
df = df[~df['Pakettype'].str.contains("Channel Hop")]
print(df.shape)
# Out:
# (2366, 12)

# %%
print("Requests: %d"%df[df['Opcode'].str.contains("Read Request")].shape[0])
print("Responses: %d"%df[df['Opcode'].str.contains("Read Response")].shape[0])
# Out:
# Requests: 265
# Responses: 224

# %%
def hex_string_to_int(string,reverse=True):
    if reverse:
        string = "".join(reversed([string[i:i+2] for i in range(0, len(string),2)]))
    print(string,"->",int(string,16))
    return int(string,16)

# %%
#setting updates
size_updates = []
connection_interval_updates = []
mtu_updates = []
df_size_updates = df[df['Pakettype'].str.contains("WRITE_SIZE")]
df_connection_interval_updates = df[df['Pakettype'].str.contains("CONN_INTERVAL")]
df_mtu_updates = df[df['Pakettype'].str.contains("Exchange MTU")]
indices_to_drop = set(list(df_size_updates.index.values)+list(df_connection_interval_updates.index.values)+list(df_mtu_updates.index.values))
print("drop following:",indices_to_drop)
df = df.drop(indices_to_drop)

df_size_updates = df_size_updates [df_size_updates ['Pakettype'].str.contains("Req")]
size_updates = [(dt,hex_string_to_int(val,True)) for dt,val in zip(df_size_updates['Time.1'].values,df_size_updates['Value'].values)]
size_updates.sort(key=lambda pair:pair[0])
print("Size Updates:")
pprint.pprint(size_updates)

df_connection_interval_updates = df_connection_interval_updates[df_connection_interval_updates['Pakettype'].str.contains("Req")]
connection_interval_updates = [(dt,hex_string_to_int(val,True)) for dt,val in zip(df_connection_interval_updates['Time.1'].values,df_connection_interval_updates['Value'].values)]
connection_interval_updates += [(np.datetime64('2021-05-28T11:50:15.673801245'),64)]
connection_interval_updates.sort(key=lambda pair:pair[0])

print("Interval Updates:")
pprint.pprint(connection_interval_updates)

df_mtu_updates =df_mtu_updates [df_mtu_updates['Pakettype'].str.contains("Request")]
mtu_updates = [(dt,int(val)) for dt,val in zip(df_mtu_updates['Time.1'].values,df_mtu_updates['Info'].apply(lambda st: st.split(":")[-1]).values)]
mtu_updates.sort(key=lambda pair:pair[0])
print("MTU Updates:")
pprint.pprint(mtu_updates)
print(df.shape)
# Out:
# drop following: {10240, 4609, 8712, 4109, 8718, 8719, 4112, 8722, 8220, 8222, 10787, 10790, 13351, 10281, 13354, 10283, 1588, 4662, 1591, 4665, 3643, 2108, 3648, 5699, 2116, 5702, 2119, 9288, 9289, 2634, 2123, 2636, 9292, 4170, 4173, 4681, 4684, 1108, 1110, 3579, 6240, 6243, 3582, 9834, 12395, 9837, 12397, 3700, 10869, 2680, 2682, 5756, 1662, 5759, 1664, 5247, 5250, 5256, 5259, 4751, 4754, 2196, 4246, 2199, 4248, 1178, 12442, 11420, 1180, 3229, 11423, 4256, 12445, 12447, 12449, 4261, 3751, 13991, 13993, 3754, 11956, 11959, 7870, 6847, 6849, 7873, 705, 708, 10440, 10447, 6352, 6355, 8406, 8409, 8415, 8416, 3303, 10986, 3306, 10989, 11505, 11508, 3327, 3330, 13062, 13065, 12053, 8469, 1303, 12058, 8474, 1306, 2331, 8990, 1821, 2336, 8993, 1824, 5411, 10523, 5415, 820, 10037, 823, 7481, 6458, 10042, 3902, 4415, 7488, 3905, 4418, 4427, 11598, 9040, 4945, 9043, 4950, 12637, 4449, 13666, 4452, 13669, 9577, 9579, 10603, 10606, 12142, 3950, 3953, 12147, 3444, 12662, 3447, 11128, 11131, 10620, 10623, 2435, 2950, 2438, 3975, 2953, 2965, 2968, 2993, 2996, 4024, 1470, 1472, 11715, 964, 11718, 966, 974, 4561, 977, 4564, 6616, 6619, 4065, 3554, 4068, 7141, 7654, 3557, 9704, 9705, 7144, 7659, 9707, 9708, 9709, 11752, 7152, 9712, 11755, 7155, 14331, 4606}
# 00000014 -> 20
# 00000020 -> 32
# 00000040 -> 64
# 00000080 -> 128
# 00000100 -> 256
# 00000200 -> 512
# 00000014 -> 20
# 00000020 -> 32
# 00000080 -> 128
# 00000100 -> 256
# 00000200 -> 512
# 00000014 -> 20
# 00000014 -> 20
# 00000020 -> 32
# 00000040 -> 64
# 00000080 -> 128
# 00000080 -> 128
# 00000100 -> 256
# 00000100 -> 256
# 00000100 -> 256
# 00000100 -> 256
# 00000100 -> 256
# 00000200 -> 512
# 00000014 -> 20
# 00000020 -> 32
# 00000040 -> 64
# 00000080 -> 128
# 00000100 -> 256
# 00000200 -> 512
# 00000014 -> 20
# 00000020 -> 32
# 00000040 -> 64
# 00000080 -> 128
# 00000100 -> 256
# 00000200 -> 512
# 00000014 -> 20
# 00000020 -> 32
# 00000040 -> 64
# 00000080 -> 128
# 00000100 -> 256
# 00000200 -> 512
# 00000014 -> 20
# 00000020 -> 32
# 00000040 -> 64
# 00000080 -> 128
# 00000100 -> 256
# 00000200 -> 512
# 00000014 -> 20
# 00000020 -> 32
# 00000020 -> 32
# 00000040 -> 64
# 00000100 -> 256
# 00000200 -> 512
# 00000014 -> 20
# 00000020 -> 32
# 00000040 -> 64
# 00000080 -> 128
# 00000100 -> 256
# 00000014 -> 20
# 00000020 -> 32
# 00000040 -> 64
# 00000080 -> 128
# 00000100 -> 256
# 00000200 -> 512
# 00000014 -> 20
# 00000020 -> 32
# 00000040 -> 64
# 00000080 -> 128
# 00000100 -> 256
# 00000200 -> 512
# 00000014 -> 20
# 00000020 -> 32
# 00000080 -> 128
# 00000100 -> 256
# 00000200 -> 512
# 00000014 -> 20
# 00000020 -> 32
# 00000040 -> 64
# 00000080 -> 128
# 00000100 -> 256
# 00000200 -> 512
# 00000014 -> 20
# 00000020 -> 32
# 00000040 -> 64
# 00000080 -> 128
# 00000100 -> 256
# 00000200 -> 512
# 00000014 -> 20
# 00000020 -> 32
# 00000040 -> 64
# 00000100 -> 256
# 00000200 -> 512
# Size Updates:
# [(numpy.datetime64('2021-05-25T16:39:03.811818337'), 20),
#  (numpy.datetime64('2021-05-25T16:39:15.961963437'), 32),
#  (numpy.datetime64('2021-05-25T16:39:23.702063337'), 64),
#  (numpy.datetime64('2021-05-25T16:39:32.927157637'), 128),
#  (numpy.datetime64('2021-05-25T16:39:42.197262937'), 256),
#  (numpy.datetime64('2021-05-25T16:39:54.572399437'), 512),
#  (numpy.datetime64('2021-05-25T16:40:22.562703137'), 20),
#  (numpy.datetime64('2021-05-25T16:40:30.797774737'), 32),
#  (numpy.datetime64('2021-05-25T16:40:47.448042337'), 128),
#  (numpy.datetime64('2021-05-25T16:41:04.098250737'), 256),
#  (numpy.datetime64('2021-05-25T16:41:16.158400737'), 512),
#  (numpy.datetime64('2021-05-25T16:41:34.428594337'), 20),
#  (numpy.datetime64('2021-05-25T16:41:34.473595537'), 20),
#  (numpy.datetime64('2021-05-25T16:41:41.673698137'), 32),
#  (numpy.datetime64('2021-05-25T16:41:48.468793237'), 64),
#  (numpy.datetime64('2021-05-25T16:41:55.668915237'), 128),
#  (numpy.datetime64('2021-05-25T16:41:55.713915737'), 128),
#  (numpy.datetime64('2021-05-25T16:42:05.524044337'), 256),
#  (numpy.datetime64('2021-05-25T16:42:05.569045137'), 256),
#  (numpy.datetime64('2021-05-25T16:42:05.614045237'), 256),
#  (numpy.datetime64('2021-05-25T16:42:05.659045337'), 256),
#  (numpy.datetime64('2021-05-25T16:42:05.704045837'), 256),
#  (numpy.datetime64('2021-05-25T16:42:13.894176937'), 512),
#  (numpy.datetime64('2021-05-25T16:42:28.339400337'), 20),
#  (numpy.datetime64('2021-05-25T16:42:34.369466237'), 32),
#  (numpy.datetime64('2021-05-25T16:42:40.669572237'), 64),
#  (numpy.datetime64('2021-05-25T16:42:47.779609937'), 128),
#  (numpy.datetime64('2021-05-25T16:42:54.664706037'), 256),
#  (numpy.datetime64('2021-05-25T16:43:02.044810337'), 512),
#  (numpy.datetime64('2021-05-25T16:43:15.320050637'), 20),
#  (numpy.datetime64('2021-05-25T16:43:22.970149437'), 32),
#  (numpy.datetime64('2021-05-25T16:43:29.360286337'), 64),
#  (numpy.datetime64('2021-05-25T16:43:36.470406537'), 128),
#  (numpy.datetime64('2021-05-25T16:43:43.625563137'), 256),
#  (numpy.datetime64('2021-05-25T16:43:51.050632237'), 512),
#  (numpy.datetime64('2021-05-25T17:00:01.750772169'), 20),
#  (numpy.datetime64('2021-05-25T17:00:20.071018769'), 32),
#  (numpy.datetime64('2021-05-25T17:00:29.271171369'), 64),
#  (numpy.datetime64('2021-05-25T17:00:39.831315269'), 128),
#  (numpy.datetime64('2021-05-25T17:00:51.111490769'), 256),
#  (numpy.datetime64('2021-05-25T17:01:06.391725469'), 512),
#  (numpy.datetime64('2021-05-25T17:01:30.152059369'), 20),
#  (numpy.datetime64('2021-05-25T17:01:39.592207469'), 32),
#  (numpy.datetime64('2021-05-25T17:01:47.752296569'), 64),
#  (numpy.datetime64('2021-05-25T17:01:58.712468769'), 128),
#  (numpy.datetime64('2021-05-25T17:02:11.432642269'), 256),
#  (numpy.datetime64('2021-05-25T17:02:25.352823669'), 512),
#  (numpy.datetime64('2021-05-25T17:02:47.513178769'), 20),
#  (numpy.datetime64('2021-05-25T17:02:55.913302569'), 32),
#  (numpy.datetime64('2021-05-25T17:02:55.993302869'), 32),
#  (numpy.datetime64('2021-05-25T17:03:07.433440069'), 64),
#  (numpy.datetime64('2021-05-25T17:03:27.433655169'), 256),
#  (numpy.datetime64('2021-05-25T17:03:36.313757169'), 512),
#  (numpy.datetime64('2021-05-25T17:03:52.073989969'), 20),
#  (numpy.datetime64('2021-05-25T17:03:57.914082969'), 32),
#  (numpy.datetime64('2021-05-25T17:04:03.834130769'), 64),
#  (numpy.datetime64('2021-05-25T17:04:10.474210669'), 128),
#  (numpy.datetime64('2021-05-25T17:04:17.914318969'), 256),
#  (numpy.datetime64('2021-05-25T17:04:40.954801169'), 20),
#  (numpy.datetime64('2021-05-25T17:04:46.954905469'), 32),
#  (numpy.datetime64('2021-05-25T17:04:54.474989969'), 64),
#  (numpy.datetime64('2021-05-25T17:05:01.515071969'), 128),
#  (numpy.datetime64('2021-05-25T17:05:10.875223469'), 256),
#  (numpy.datetime64('2021-05-25T17:05:19.755363569'), 512),
#  (numpy.datetime64('2021-05-26T14:51:50.906163603'), 20),
#  (numpy.datetime64('2021-05-26T14:52:08.506479503'), 32),
#  (numpy.datetime64('2021-05-26T14:52:20.986717003'), 64),
#  (numpy.datetime64('2021-05-26T14:52:36.987058703'), 128),
#  (numpy.datetime64('2021-05-26T14:53:00.667490603'), 256),
#  (numpy.datetime64('2021-05-26T14:53:33.948000003'), 512),
#  (numpy.datetime64('2021-05-26T14:54:39.229160203'), 20),
#  (numpy.datetime64('2021-05-26T14:54:46.589297103'), 32),
#  (numpy.datetime64('2021-05-26T14:55:08.669750103'), 128),
#  (numpy.datetime64('2021-05-26T14:55:25.310119003'), 256),
#  (numpy.datetime64('2021-05-26T14:55:53.790626503'), 512),
#  (numpy.datetime64('2021-05-26T14:56:43.071495003'), 20),
#  (numpy.datetime64('2021-05-26T14:57:08.352010303'), 32),
#  (numpy.datetime64('2021-05-26T14:57:19.552181603'), 64),
#  (numpy.datetime64('2021-05-26T14:57:39.392537403'), 128),
#  (numpy.datetime64('2021-05-26T14:57:53.152859303'), 256),
#  (numpy.datetime64('2021-05-26T14:58:15.873306703'), 512),
#  (numpy.datetime64('2021-05-26T14:58:56.514103303'), 20),
#  (numpy.datetime64('2021-05-26T14:59:04.514234303'), 32),
#  (numpy.datetime64('2021-05-26T14:59:11.554342303'), 64),
#  (numpy.datetime64('2021-05-26T14:59:18.914474303'), 128),
#  (numpy.datetime64('2021-05-26T14:59:28.834641803'), 256),
#  (numpy.datetime64('2021-05-26T14:59:40.994824703'), 512),
#  (numpy.datetime64('2021-05-26T15:00:06.595296803'), 20),
#  (numpy.datetime64('2021-05-26T15:00:23.555623703'), 32),
#  (numpy.datetime64('2021-05-26T15:00:30.595784603'), 64),
#  (numpy.datetime64('2021-05-26T15:00:45.956072203'), 256),
#  (numpy.datetime64('2021-05-26T15:00:56.516244003'), 512)]
# 00000024 -> 36
# 00000040 -> 64
# 00000040 -> 64
# 00000100 -> 256
# Interval Updates:
# [(numpy.datetime64('2021-05-25T16:38:50.785400837'), 36),
#  (numpy.datetime64('2021-05-25T16:58:38.008215169'), 64),
#  (numpy.datetime64('2021-05-25T16:59:50.865609269'), 64),
#  (numpy.datetime64('2021-05-26T14:51:32.803336803'), 256),
#  (numpy.datetime64('2021-05-28T11:50:15.673801245'), 64)]
# MTU Updates:
# [(numpy.datetime64('2021-05-25T16:38:56.611747437'), 23),
#  (numpy.datetime64('2021-05-25T16:40:18.512665537'), 32),
#  (numpy.datetime64('2021-05-25T16:41:29.613516637'), 64),
#  (numpy.datetime64('2021-05-25T16:42:26.044368837'), 128),
#  (numpy.datetime64('2021-05-25T16:43:10.504945737'), 256),
#  (numpy.datetime64('2021-05-25T16:59:52.790643469'), 23),
#  (numpy.datetime64('2021-05-25T17:01:26.312000869'), 32),
#  (numpy.datetime64('2021-05-25T17:02:45.273154169'), 64),
#  (numpy.datetime64('2021-05-25T17:03:50.473970869'), 128),
#  (numpy.datetime64('2021-05-25T17:04:37.674764269'), 256),
#  (numpy.datetime64('2021-05-26T14:51:52.826205803'), 23),
#  (numpy.datetime64('2021-05-26T14:54:36.029115903'), 32),
#  (numpy.datetime64('2021-05-26T14:56:39.231409003'), 64),
#  (numpy.datetime64('2021-05-26T14:58:52.033971203'), 128),
#  (numpy.datetime64('2021-05-26T15:00:02.435221703'), 256)]
# (2145, 12)

# %% [markdown]
# ### Define Read & Notify Requests by REGEX
# Request -> A
# Following Request -> C
# Response -> B
# Following Response -> D
# Notify -> D

# %%
import re
paket_regex_map = dict({'Error Response':'Z', 
                        'Read Blob Response':'D', 
                        'Read Response':'B', 
                        'Handle Value Notification':'D', 
                        'Write Request':'A', 
                        'Write Response':'B', 
                        'Read Blob Request':'C', 
                        'Read Request':'A'
                       })

# %%
# examples for regex
test = "ABABABCDABCDAB"
print(test)
for i in re.finditer('(AB)(CD)*',test):
    print(i)
test_2 = 'ABADDABAABADDABDDDDDDDD'
print(test_2)
for i in re.finditer('(A*B*)+D+',test_2):
    print(i)
# Out:
# ABABABCDABCDAB
# <re.Match object; span=(0, 2), match='AB'>
# <re.Match object; span=(2, 4), match='AB'>
# <re.Match object; span=(4, 8), match='ABCD'>
# <re.Match object; span=(8, 12), match='ABCD'>
# <re.Match object; span=(12, 14), match='AB'>
# ABADDABAABADDABDDDDDDDD
# <re.Match object; span=(0, 5), match='ABADD'>
# <re.Match object; span=(5, 13), match='ABAABADD'>
# <re.Match object; span=(13, 23), match='ABDDDDDDDD'>

# %%
read_requests = []
df_reads = df[df['Pakettype'].str.contains("READ")]
# Filter on Opcode == READ Req && READ Rcvd
df_reads.sort_values("Time.1",inplace=True)
df_reads = df_reads[df_reads['Opcode'].apply(lambda op:op in ['Read Request','Read Blob Request','Read Response','Read Blob Response'])]
column_to_string = "".join(list(df_reads['Opcode'].map(paket_regex_map).values))
print(column_to_string)
for i in re.finditer('(AB)(CD)*',column_to_string):
    first = i.span(0)[0]
    last = i.span(0)[1]
    request_type = df_reads.iloc[first]['Pakettype']
    request = Request(request_type)
    request.add(df_reads.iloc[first:last])
    request.state_close()
    read_requests.append(request)

print(len(read_requests))
print("bsp first request")
print(read_requests[0])
# Out:
# ...
# <ipython-input-24-27b68bf1ed49>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_reads.sort_values("Time.1",inplace=True)
# 210
# bsp first request
# {'request_type': 'READ Req', 'starting_time': Timestamp('2021-05-25 16:39:09.256856837'), 'ending_time': Timestamp('2021-05-25 16:39:09.302085537'), 'duration': Timedelta('0 days 00:00:00.045228700'), 'data_size': None, 'mtu_size': None, 'conn_interval': None, 'data': 'Data Size 20mnopqrst', 'read_requests': 1, 'read_responses': 1, 'notifies': 0}

# %%
write_requests = []
df_writes = df.copy()
# Filter on Opcode == READ Req && READ Rcvd
df_writes.sort_values("Time.1",inplace=True)
df_writes = df_writes[df_writes['Opcode'].apply(lambda op:op in ['Handle Value Notification','Write Request','Write Response'])]
column_to_string = "".join(list(df_writes['Opcode'].map(paket_regex_map).values))
print(column_to_string)
for i in re.finditer('(A*B*)+D+',column_to_string):
    first = i.span(0)[0]
    last = i.span(0)[1]
    request_type = df_writes.iloc[first]['Pakettype']
    request = Request(request_type)
    request.add(df_writes.iloc[first:last])
    request.state_close()
    write_requests.append(request)

try:
    print(len(write_requests))
    print("bsp first request")
    print(write_requests[0])
    pprint.pprint(write_requests[0].df)
except:
    pass
# Out:
# 0
# bsp first request

# %% [markdown]
# ### Combine Write and Notify requests

# %%
print("combine",len(write_requests),"notify requests and",len(read_requests),"read requests")

all_requests = write_requests + read_requests
for r in all_requests:
    try:
        start_time = r.starting_time
        latest_mtu_updates = [mtu_update for mtu_update in mtu_updates if mtu_update[0] < start_time]
        latest_mtu_update = latest_mtu_updates[-1]
        r.set_mtu_size(latest_mtu_update[1])

        latest_data_updates = [update for update in size_updates if update[0] < start_time]
        latest_data_update = latest_data_updates[-1]
        r.set_data_size(latest_data_update[1])

        latest_conn_interval_updates = [update for update in connection_interval_updates if update[0] < start_time]
        latest_conn_interval_update= latest_conn_interval_updates[-1]
        r.set_conn_interval(latest_conn_interval_update[1])
    except:
        print(r.request_type,r.starting_time)
# Out:
# combine 0 notify requests and 210 read requests

# %%
# remove requests with not enough notification pakets
good_requests = []
for rq in all_requests:
    if "WRITE" in rq.request_type:
        expected_notifies = math.ceil(rq.data_size/(rq.mtu_size-3))
        is_good = len(rq.df[rq.df['Pakettype'].str.contains("NOTIFY")]) >= expected_notifies
        if is_good:
            good_requests += [rq]
            print("add Request","expected notify:",expected_notifies,"received:",len(rq.df[rq.df['Pakettype'].str.contains("NOTIFY")]))
            print("mtu:",rq.mtu_size,"data:",rq.data_size,"conn-int:",rq.conn_interval)
        else:
            print("do not add Request","expected notify:",expected_notifies,"received:",len(rq.df[rq.df['Pakettype'].str.contains("NOTIFY")]))
            print("mtu:",rq.mtu_size,"data:",rq.data_size,"conn-int:",rq.conn_interval)

    else:
        good_requests+=[rq]
        expected_responses = math.ceil(rq.data_size/(rq.mtu_size-1))
        received_responses = len(rq.df[rq.df['Pakettype'].str.contains("Rcvd")])

        print("add Request","expected responses",expected_responses,"received:",received_responses)
        print("mtu:",rq.mtu_size,"data:",rq.data_size,"conn-int:",rq.conn_interval)
print(len(good_requests))
# Out:
# add Request expected responses 1 received: 1
# mtu: 23 data: 20 conn-int: 36
# add Request expected responses 1 received: 1
# mtu: 23 data: 20 conn-int: 36
# add Request expected responses 1 received: 1
# mtu: 23 data: 20 conn-int: 36
# add Request expected responses 2 received: 2
# mtu: 23 data: 32 conn-int: 36
# add Request expected responses 2 received: 2
# mtu: 23 data: 32 conn-int: 36
# add Request expected responses 2 received: 1
# mtu: 23 data: 32 conn-int: 36
# add Request expected responses 3 received: 3
# mtu: 23 data: 64 conn-int: 36
# add Request expected responses 3 received: 1
# mtu: 23 data: 64 conn-int: 36
# add Request expected responses 3 received: 3
# mtu: 23 data: 64 conn-int: 36
# add Request expected responses 6 received: 6
# mtu: 23 data: 128 conn-int: 36
# add Request expected responses 6 received: 1
# mtu: 23 data: 128 conn-int: 36
# add Request expected responses 12 received: 1
# mtu: 23 data: 256 conn-int: 36
# add Request expected responses 12 received: 2
# mtu: 23 data: 256 conn-int: 36
# add Request expected responses 12 received: 7
# mtu: 23 data: 256 conn-int: 36
# add Request expected responses 24 received: 4
# mtu: 23 data: 512 conn-int: 36
# add Request expected responses 24 received: 4
# mtu: 23 data: 512 conn-int: 36
# add Request expected responses 1 received: 1
# mtu: 32 data: 20 conn-int: 36
# add Request expected responses 1 received: 1
# mtu: 32 data: 20 conn-int: 36
# add Request expected responses 1 received: 1
# mtu: 32 data: 20 conn-int: 36
# add Request expected responses 2 received: 2
# mtu: 32 data: 32 conn-int: 36
# add Request expected responses 2 received: 2
# mtu: 32 data: 32 conn-int: 36
# add Request expected responses 2 received: 2
# mtu: 32 data: 32 conn-int: 36
# add Request expected responses 2 received: 3
# mtu: 32 data: 32 conn-int: 36
# add Request expected responses 2 received: 3
# mtu: 32 data: 32 conn-int: 36
# add Request expected responses 2 received: 3
# mtu: 32 data: 32 conn-int: 36
# add Request expected responses 5 received: 2
# mtu: 32 data: 128 conn-int: 36
# add Request expected responses 5 received: 4
# mtu: 32 data: 128 conn-int: 36
# add Request expected responses 5 received: 5
# mtu: 32 data: 128 conn-int: 36
# add Request expected responses 9 received: 1
# mtu: 32 data: 256 conn-int: 36
# add Request expected responses 9 received: 1
# mtu: 32 data: 256 conn-int: 36
# add Request expected responses 17 received: 5
# mtu: 32 data: 512 conn-int: 36
# add Request expected responses 17 received: 12
# mtu: 32 data: 512 conn-int: 36
# add Request expected responses 17 received: 2
# mtu: 32 data: 512 conn-int: 36
# add Request expected responses 1 received: 1
# mtu: 64 data: 20 conn-int: 36
# add Request expected responses 1 received: 1
# mtu: 64 data: 20 conn-int: 36
# add Request expected responses 1 received: 1
# mtu: 64 data: 20 conn-int: 36
# add Request expected responses 1 received: 1
# mtu: 64 data: 32 conn-int: 36
# add Request expected responses 1 received: 1
# mtu: 64 data: 32 conn-int: 36
# add Request expected responses 2 received: 2
# mtu: 64 data: 64 conn-int: 36
# add Request expected responses 2 received: 2
# mtu: 64 data: 64 conn-int: 36
# add Request expected responses 2 received: 2
# mtu: 64 data: 64 conn-int: 36
# add Request expected responses 3 received: 3
# mtu: 64 data: 128 conn-int: 36
# add Request expected responses 3 received: 3
# mtu: 64 data: 128 conn-int: 36
# add Request expected responses 5 received: 6
# mtu: 64 data: 256 conn-int: 36
# add Request expected responses 9 received: 5
# mtu: 64 data: 512 conn-int: 36
# add Request expected responses 9 received: 4
# mtu: 64 data: 512 conn-int: 36
# add Request expected responses 9 received: 6
# mtu: 64 data: 512 conn-int: 36
# add Request expected responses 1 received: 1
# mtu: 128 data: 20 conn-int: 36
# add Request expected responses 1 received: 1
# mtu: 128 data: 20 conn-int: 36
# add Request expected responses 1 received: 1
# mtu: 128 data: 20 conn-int: 36
# add Request expected responses 1 received: 1
# mtu: 128 data: 32 conn-int: 36
# add Request expected responses 1 received: 1
# mtu: 128 data: 32 conn-int: 36
# add Request expected responses 1 received: 1
# mtu: 128 data: 32 conn-int: 36
# add Request expected responses 1 received: 1
# mtu: 128 data: 64 conn-int: 36
# add Request expected responses 1 received: 1
# mtu: 128 data: 64 conn-int: 36
# add Request expected responses 2 received: 2
# mtu: 128 data: 128 conn-int: 36
# add Request expected responses 2 received: 2
# mtu: 128 data: 128 conn-int: 36
# add Request expected responses 3 received: 3
# mtu: 128 data: 256 conn-int: 36
# add Request expected responses 3 received: 3
# mtu: 128 data: 256 conn-int: 36
# add Request expected responses 3 received: 1
# mtu: 128 data: 256 conn-int: 36
# add Request expected responses 5 received: 1
# mtu: 128 data: 512 conn-int: 36
# add Request expected responses 5 received: 3
# mtu: 128 data: 512 conn-int: 36
# add Request expected responses 5 received: 3
# mtu: 128 data: 512 conn-int: 36
# add Request expected responses 1 received: 1
# mtu: 256 data: 20 conn-int: 36
# add Request expected responses 1 received: 1
# mtu: 256 data: 20 conn-int: 36
# add Request expected responses 1 received: 1
# mtu: 256 data: 32 conn-int: 36
# add Request expected responses 1 received: 1
# mtu: 256 data: 32 conn-int: 36
# add Request expected responses 1 received: 1
# mtu: 256 data: 64 conn-int: 36
# add Request expected responses 1 received: 1
# mtu: 256 data: 64 conn-int: 36
# add Request expected responses 1 received: 1
# mtu: 256 data: 64 conn-int: 36
# add Request expected responses 1 received: 1
# mtu: 256 data: 128 conn-int: 36
# add Request expected responses 1 received: 1
# mtu: 256 data: 128 conn-int: 36
# add Request expected responses 1 received: 1
# mtu: 256 data: 128 conn-int: 36
# add Request expected responses 1 received: 1
# mtu: 23 data: 20 conn-int: 64
# add Request expected responses 1 received: 1
# mtu: 23 data: 20 conn-int: 64
# add Request expected responses 1 received: 1
# mtu: 23 data: 20 conn-int: 64
# add Request expected responses 1 received: 1
# mtu: 23 data: 20 conn-int: 64
# add Request expected responses 2 received: 2
# mtu: 23 data: 32 conn-int: 64
# add Request expected responses 2 received: 2
# mtu: 23 data: 32 conn-int: 64
# add Request expected responses 2 received: 4
# mtu: 23 data: 32 conn-int: 64
# add Request expected responses 3 received: 5
# mtu: 23 data: 64 conn-int: 64
# add Request expected responses 6 received: 5
# mtu: 23 data: 128 conn-int: 64
# add Request expected responses 6 received: 6
# mtu: 23 data: 128 conn-int: 64
# add Request expected responses 6 received: 9
# mtu: 23 data: 128 conn-int: 64
# add Request expected responses 12 received: 3
# mtu: 23 data: 256 conn-int: 64
# add Request expected responses 12 received: 12
# mtu: 23 data: 256 conn-int: 64
# add Request expected responses 24 received: 4
# mtu: 23 data: 512 conn-int: 64
# add Request expected responses 24 received: 5
# mtu: 23 data: 512 conn-int: 64
# add Request expected responses 24 received: 5
# mtu: 23 data: 512 conn-int: 64
# add Request expected responses 1 received: 1
# mtu: 32 data: 20 conn-int: 64
# add Request expected responses 1 received: 1
# mtu: 32 data: 20 conn-int: 64
# add Request expected responses 2 received: 2
# mtu: 32 data: 32 conn-int: 64
# add Request expected responses 2 received: 2
# mtu: 32 data: 32 conn-int: 64
# add Request expected responses 3 received: 2
# mtu: 32 data: 64 conn-int: 64
# add Request expected responses 3 received: 5
# mtu: 32 data: 64 conn-int: 64
# add Request expected responses 5 received: 2
# mtu: 32 data: 128 conn-int: 64
# add Request expected responses 5 received: 5
# mtu: 32 data: 128 conn-int: 64
# add Request expected responses 5 received: 2
# mtu: 32 data: 128 conn-int: 64
# add Request expected responses 9 received: 5
# mtu: 32 data: 256 conn-int: 64
# add Request expected responses 9 received: 5
# mtu: 32 data: 256 conn-int: 64
# add Request expected responses 9 received: 1
# mtu: 32 data: 256 conn-int: 64
# add Request expected responses 17 received: 4
# mtu: 32 data: 512 conn-int: 64
# add Request expected responses 17 received: 4
# mtu: 32 data: 512 conn-int: 64
# add Request expected responses 17 received: 8
# mtu: 32 data: 512 conn-int: 64
# add Request expected responses 1 received: 1
# mtu: 64 data: 20 conn-int: 64
# add Request expected responses 1 received: 1
# mtu: 64 data: 20 conn-int: 64
# add Request expected responses 1 received: 1
# mtu: 64 data: 20 conn-int: 64
# add Request expected responses 1 received: 1
# mtu: 64 data: 32 conn-int: 64
# add Request expected responses 1 received: 1
# mtu: 64 data: 32 conn-int: 64
# add Request expected responses 1 received: 1
# mtu: 64 data: 32 conn-int: 64
# add Request expected responses 2 received: 2
# mtu: 64 data: 64 conn-int: 64
# add Request expected responses 2 received: 1
# mtu: 64 data: 64 conn-int: 64
# add Request expected responses 2 received: 2
# mtu: 64 data: 64 conn-int: 64
# add Request expected responses 2 received: 5
# mtu: 64 data: 64 conn-int: 64
# add Request expected responses 2 received: 3
# mtu: 64 data: 64 conn-int: 64
# add Request expected responses 5 received: 1
# mtu: 64 data: 256 conn-int: 64
# add Request expected responses 5 received: 5
# mtu: 64 data: 256 conn-int: 64
# add Request expected responses 5 received: 4
# mtu: 64 data: 256 conn-int: 64
# add Request expected responses 9 received: 7
# mtu: 64 data: 512 conn-int: 64
# add Request expected responses 1 received: 1
# mtu: 128 data: 20 conn-int: 64
# add Request expected responses 1 received: 1
# mtu: 128 data: 32 conn-int: 64
# add Request expected responses 1 received: 1
# mtu: 128 data: 32 conn-int: 64
# add Request expected responses 1 received: 1
# mtu: 128 data: 32 conn-int: 64
# add Request expected responses 1 received: 1
# mtu: 128 data: 64 conn-int: 64
# add Request expected responses 1 received: 1
# mtu: 128 data: 64 conn-int: 64
# add Request expected responses 2 received: 1
# mtu: 128 data: 128 conn-int: 64
# add Request expected responses 2 received: 2
# mtu: 128 data: 128 conn-int: 64
# add Request expected responses 2 received: 2
# mtu: 128 data: 128 conn-int: 64
# add Request expected responses 3 received: 3
# mtu: 128 data: 256 conn-int: 64
# add Request expected responses 3 received: 1
# mtu: 128 data: 256 conn-int: 64
# add Request expected responses 3 received: 1
# mtu: 128 data: 256 conn-int: 64
# add Request expected responses 3 received: 3
# mtu: 128 data: 256 conn-int: 64
# add Request expected responses 3 received: 5
# mtu: 128 data: 256 conn-int: 64
# add Request expected responses 1 received: 1
# mtu: 256 data: 20 conn-int: 64
# add Request expected responses 1 received: 1
# mtu: 256 data: 20 conn-int: 64
# add Request expected responses 1 received: 1
# mtu: 256 data: 32 conn-int: 64
# add Request expected responses 1 received: 1
# mtu: 256 data: 32 conn-int: 64
# add Request expected responses 1 received: 1
# mtu: 256 data: 32 conn-int: 64
# add Request expected responses 1 received: 1
# mtu: 256 data: 64 conn-int: 64
# add Request expected responses 1 received: 1
# mtu: 256 data: 64 conn-int: 64
# add Request expected responses 1 received: 1
# mtu: 256 data: 128 conn-int: 64
# add Request expected responses 1 received: 1
# mtu: 256 data: 128 conn-int: 64
# add Request expected responses 1 received: 1
# mtu: 256 data: 128 conn-int: 64
# add Request expected responses 1 received: 1
# mtu: 23 data: 20 conn-int: 256
# add Request expected responses 2 received: 2
# mtu: 23 data: 32 conn-int: 256
# add Request expected responses 2 received: 2
# mtu: 23 data: 32 conn-int: 256
# add Request expected responses 2 received: 2
# mtu: 23 data: 32 conn-int: 256
# add Request expected responses 3 received: 3
# mtu: 23 data: 64 conn-int: 256
# add Request expected responses 3 received: 3
# mtu: 23 data: 64 conn-int: 256
# add Request expected responses 6 received: 4
# mtu: 23 data: 128 conn-int: 256
# add Request expected responses 6 received: 6
# mtu: 23 data: 128 conn-int: 256
# add Request expected responses 6 received: 6
# mtu: 23 data: 128 conn-int: 256
# add Request expected responses 12 received: 1
# mtu: 23 data: 256 conn-int: 256
# add Request expected responses 12 received: 2
# mtu: 23 data: 256 conn-int: 256
# add Request expected responses 24 received: 3
# mtu: 23 data: 512 conn-int: 256
# add Request expected responses 24 received: 5
# mtu: 23 data: 512 conn-int: 256
# add Request expected responses 24 received: 1
# mtu: 23 data: 512 conn-int: 256
# add Request expected responses 1 received: 1
# mtu: 32 data: 20 conn-int: 256
# add Request expected responses 1 received: 1
# mtu: 32 data: 20 conn-int: 256
# add Request expected responses 2 received: 2
# mtu: 32 data: 32 conn-int: 256
# add Request expected responses 2 received: 2
# mtu: 32 data: 32 conn-int: 256
# add Request expected responses 2 received: 3
# mtu: 32 data: 32 conn-int: 256
# add Request expected responses 2 received: 3
# mtu: 32 data: 32 conn-int: 256
# add Request expected responses 5 received: 2
# mtu: 32 data: 128 conn-int: 256
# add Request expected responses 5 received: 5
# mtu: 32 data: 128 conn-int: 256
# add Request expected responses 9 received: 2
# mtu: 32 data: 256 conn-int: 256
# add Request expected responses 9 received: 9
# mtu: 32 data: 256 conn-int: 256
# add Request expected responses 9 received: 9
# mtu: 32 data: 256 conn-int: 256
# add Request expected responses 17 received: 9
# mtu: 32 data: 512 conn-int: 256
# add Request expected responses 17 received: 3
# mtu: 32 data: 512 conn-int: 256
# add Request expected responses 17 received: 7
# mtu: 32 data: 512 conn-int: 256
# add Request expected responses 1 received: 1
# mtu: 64 data: 20 conn-int: 256
# add Request expected responses 1 received: 1
# mtu: 64 data: 32 conn-int: 256
# add Request expected responses 1 received: 1
# mtu: 64 data: 32 conn-int: 256
# add Request expected responses 1 received: 1
# mtu: 64 data: 32 conn-int: 256
# add Request expected responses 2 received: 1
# mtu: 64 data: 64 conn-int: 256
# add Request expected responses 2 received: 1
# mtu: 64 data: 64 conn-int: 256
# add Request expected responses 2 received: 1
# mtu: 64 data: 64 conn-int: 256
# add Request expected responses 2 received: 2
# mtu: 64 data: 64 conn-int: 256
# add Request expected responses 3 received: 3
# mtu: 64 data: 128 conn-int: 256
# add Request expected responses 3 received: 1
# mtu: 64 data: 128 conn-int: 256
# add Request expected responses 5 received: 1
# mtu: 64 data: 256 conn-int: 256
# add Request expected responses 5 received: 5
# mtu: 64 data: 256 conn-int: 256
# add Request expected responses 5 received: 4
# mtu: 64 data: 256 conn-int: 256
# add Request expected responses 9 received: 8
# mtu: 64 data: 512 conn-int: 256
# add Request expected responses 9 received: 7
# mtu: 64 data: 512 conn-int: 256
# add Request expected responses 9 received: 1
# mtu: 64 data: 512 conn-int: 256
# add Request expected responses 9 received: 9
# mtu: 64 data: 512 conn-int: 256
# add Request expected responses 1 received: 1
# mtu: 128 data: 20 conn-int: 256
# add Request expected responses 1 received: 1
# mtu: 128 data: 20 conn-int: 256
# add Request expected responses 1 received: 1
# mtu: 128 data: 20 conn-int: 256
# add Request expected responses 1 received: 1
# mtu: 128 data: 32 conn-int: 256
# add Request expected responses 1 received: 1
# mtu: 128 data: 32 conn-int: 256
# add Request expected responses 1 received: 1
# mtu: 128 data: 64 conn-int: 256
# add Request expected responses 1 received: 1
# mtu: 128 data: 64 conn-int: 256
# add Request expected responses 2 received: 2
# mtu: 128 data: 128 conn-int: 256
# add Request expected responses 2 received: 2
# mtu: 128 data: 128 conn-int: 256
# add Request expected responses 2 received: 2
# mtu: 128 data: 128 conn-int: 256
# add Request expected responses 3 received: 3
# mtu: 128 data: 256 conn-int: 256
# add Request expected responses 3 received: 1
# mtu: 128 data: 256 conn-int: 256
# add Request expected responses 5 received: 1
# mtu: 128 data: 512 conn-int: 256
# add Request expected responses 5 received: 5
# mtu: 128 data: 512 conn-int: 256
# add Request expected responses 5 received: 2
# mtu: 128 data: 512 conn-int: 256
# add Request expected responses 1 received: 1
# mtu: 256 data: 20 conn-int: 256
# add Request expected responses 1 received: 1
# mtu: 256 data: 20 conn-int: 256
# add Request expected responses 1 received: 1
# mtu: 256 data: 20 conn-int: 256
# add Request expected responses 1 received: 1
# mtu: 256 data: 20 conn-int: 256
# add Request expected responses 1 received: 1
# mtu: 256 data: 32 conn-int: 256
# add Request expected responses 1 received: 1
# mtu: 256 data: 64 conn-int: 256
# add Request expected responses 1 received: 1
# mtu: 256 data: 64 conn-int: 256
# 210

# %%
for rq in [rq for rq in all_requests if (rq.mtu_size == 32 and rq.data_size == 32 and rq.conn_interval == 36)]:
    #print(rq.request_type,rq.mtu_size,rq.data_size,rq.conn_interval)
    pprint.pprint(rq.df['Value'])
# Out:
# 5821     nan
# 5824    4461
# 5825     nan
# 5828      66
# Name: Value, dtype: object
# 5875     nan
# 5878    4461
# 5879     nan
# 5882      66
# Name: Value, dtype: object
# 5927     nan
# 5930    4461
# 5933     nan
# 5936      66
# Name: Value, dtype: object
# 6160     nan
# 6163    4461
# 6164     nan
# 6167    6667
# 6168     nan
# 6171    6b6c
# Name: Value, dtype: object
# 6201     nan
# 6204    4461
# 6205     nan
# 6208    6667
# 6209     nan
# 6212    6b6c
# Name: Value, dtype: object
# 6241     nan
# 6244    4461
# 6245     nan
# 6248    6667
# 6249     nan
# 6252    6b6c
# Name: Value, dtype: object

# %%
dataframe = pd.DataFrame.from_dict([r.as_dict() for r in good_requests])
#dataframe.set_index(["conn_interval","mtu_size","data_size","request_type"],inplace=True)
dataframe['duration'] = dataframe['duration'].apply(lambda dt:dt.seconds * 1_000_000 + dt.microseconds)
dataframe.to_csv("OTA_Output.csv")
dataframe = dataframe.drop(["starting_time","ending_time"],axis=1)
dataframe
# Out:
#     request_type  duration  data_size  mtu_size  conn_interval  \
# 0       READ Req     45228         20        23             36
# 1       READ Req     45227         20        23             36
# 2       READ Req     45229         20        23             36
# 3       READ Req    135228         32        23             36
# 4       READ Req    135231         32        23             36
# ..           ...       ...        ...       ...            ...
# 205     READ Req    320232         20       256            256
# 206     READ Req    320241         20       256            256
# 207     READ Req    320236         32       256            256
# 208     READ Req    640238         64       256            256
# 209     READ Req   8959913         64       256            256
#
#                                  data  read_requests  read_responses  notifies
# 0                Data Size 20mnopqrst              1               1         0
# 1                Data Size 20mnopqrst              1               1         0
# 2                Data Size 20mnopqrst              1               1         0
# 3    Data Size 32mnopqrstuvwxyzabcdef              2               2         0
# 4    Data Size 32mnopqrstuvwxyzabcdef              2               2         0
# ..                                ...            ...             ...       ...
# 205                                 D              1               1         0
# 206                                 D              1               1         0
# 207                               Dat              1               1         0
# 208                               Dat              1               1         0
# 209                               Dat              1               1         0
#
# [210 rows x 9 columns]

# %%
dfs =[(i,x) for i,x in dataframe.groupby("conn_interval")]
for interval,df in dfs:
    step = int(interval*1.25*1_000)
    # filtered:
    # df_sizes = [(s,x) for s,x in df[df["duration"] < df["duration"].max()*0.7].groupby("mtu_size")]
    # not filtered:
    df_sizes = [(s,x) for s,x in df.groupby("mtu_size")]
    for size,df_size in df_sizes:
        bigest_data_size = df_size["data_size"].max()
        biggest_duration_for_max_data = df_size[df_size["data_size"] == bigest_data_size]['duration'].mean()*1.5
        df_size = df_size[df_size['duration'] < biggest_duration_for_max_data]
        
        xticks = range(0,step*int(df_size['duration'].max()/step + 2),step*4)
        subplot = df_size.drop(["mtu_size","conn_interval"],axis=1).set_index(["data_size"]).plot.barh(figsize=(15,5))
        subplot.xaxis.set_major_locator(matplotlib.ticker.MultipleLocator(step*4))
        subplot.xaxis.set_minor_locator(matplotlib.ticker.MultipleLocator(step))
        subplot.set_aspect("auto")
        subplot.set_ylabel("Data Size")
        subplot.set_xlabel("Time in Microseconds")
        subplot.set_title("Interval:%d ms - MTU:%d Byte"%(int(interval*1.25),int(size)))

# %% [markdown]
# VGL Duration OTA / HCI
# Interval = 45
# MTU = 32
# SIZE = 128

# %%
df.columns
# Out:
# Index(['request_type', 'duration', 'data_size', 'mtu_size', 'conn_interval',
#        'data', 'read_requests', 'read_responses', 'notifies'],
#       dtype='object')

# %%
df_compare = df[df['data_size'] == 128]
df_compare
# Out:
#     request_type  duration  data_size  mtu_size  conn_interval  \
# 149     READ Req   2240267        128        23            256
# 150     READ Req   3520291        128        23            256
# 151     READ Req   3520286        128        23            256
# 163     READ Req    960257        128        32            256
# 164     READ Req   2880286        128        32            256
# 179     READ Req   1920288        128        64            256
# 180     READ Req    320234        128        64            256
# 195     READ Req    960242        128       128            256
# 196     READ Req    960255        128       128            256
# 197     READ Req    960241        128       128            256
#
#                                                   data  read_requests  \
# 149  Data Size 128nopqrstuvwxyzabcdefghijklmnopqrst...              4
# 150  Data Size 128nopqrstuvwxyzabcdefghijklmnopqrst...              6
# 151  Data Size 128nopqrstuvwxyzabcdefghijklmnopqrst...              6
# 163                                               Dafg              2
# 164                                       Dafgklpquvwx              5
# 179                                             Dalmwx              3
# 180                                                 Da              1
# 195                                                Dax              2
# 196                                                Dax              2
# 197                                                Dax              2
#
#      read_responses  notifies
# 149               4         0
# 150               6         0
# 151               6         0
# 163               2         0
# 164               5         0
# 179               3         0
# 180               1         0
# 195               2         0
# 196               2         0
# 197               2         0

# %% [markdown]
# ### Find Request

# %%
dataframe[dataframe["request_type"].str.contains("WRITE")]
# Out:
# Empty DataFrame
# Columns: [request_type, duration, data_size, mtu_size, conn_interval, data, read_requests, read_responses, notifies]
# Index: []

# %%
mtu_size = 23
data_size = 512
conn_int = 36
request_type = "WRITE"
match = None
for r in all_requests:
    if r.mtu_size == mtu_size and r.data_size == data_size and r.conn_interval == conn_int and request_type in r.request_type:
        print(r.request_type)
        match = r.df

# %%
match.drop(["Length","Info","No.","Request in Frame","Time"],axis=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-7e235476691f> in <module>
# ----> 1 match.drop(["Length","Info","No.","Request in Frame","Time"],axis=1)
#
# AttributeError: 'NoneType' object has no attribute 'drop'
